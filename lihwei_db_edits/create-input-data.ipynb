# %% [markdown]
# # Create input data
# - This notebook does all processing to turn input-data.xlsx, all other input data into a format to put into insertions.xlsx
# - Then, create all .sqlite databases to run with Temoa

# %%
import pandas as pd
import numpy as np
import sqlite3
import shutil
import os, subprocess
import re
import pathlib

import importlib
import lihwei_db_edits

import seaborn as sns

# %%
# read input data
input_data_filename = '../../../Paper 3 - Charging profiles/input_data/input-data.xlsx'
# Read all sheets into a dictionary
input_data_dict = pd.read_excel(input_data_filename, sheet_name=None)

input_params = input_data_dict['inputs'].set_index('parameter')['value'].to_dict()

truck_specs = input_data_dict['truck_specs']

# Display database_index
input_data_dict['database_index']
# Out:
#     db_id     db_path                                        db_path_old  \
# 0     aaa  aaa.sqlite                 canoe_on_16d_baseline_newtech_v3_1
# 1     wrn  wrn.sqlite    canoe_on_16d_baseline_newtech_atriprofiles_v3_1
# 2     ljv  ljv.sqlite            canoe_on_16d_baseline_newtech_flat_v3_1
# 3     rhl  rhl.sqlite  canoe_on_16d_baseline_newtech_simplemiddaypeak...
# 4     mid  mid.sqlite     canoe_on_16d_baseline_newtech_nolhhdtelec_v3_1
# ..    ...         ...                                                ...
# 195   tel         NaN                                                NaN
# 196   hjy         NaN                                                NaN
# 197   hzn         NaN                                                NaN
# 198   isi         NaN                                                NaN
# 199   oca         NaN                                                NaN
#
#             profile_name                      display_name     db_date  \
# ...

# %% [markdown]
# # eRoads input data
# - Large trucks have speed limit cap of 105 km/h, following distance at least 60 metres (https://www.ontario.ca/document/official-ministry-transportation-mto-truck-handbook/driver-conduct)
# - Truck headway: (60m / (105km/h\*1000/3600)) = 2.057 seconds
# - Maximum truck flow per day = (60sec\*60min\*24hr) / 2.057sec = 42,000 trucks/day

# %%
# join eRoads bins to get AADTT and length
eRoads_data = (input_data_dict['MTO iCorridor AADTT']
               .dropna(axis='columns', how='any')
               .rename(columns = {'LENGTH': 'eRoads_length_km'}))
eRoads_data_summary = (eRoads_data
                       .groupby('Bin').agg({'eRoads_length_km':'sum', 'AADTT19xLength':'sum'})
                       .assign(eRoads_length_weighted_aadtt19 = lambda x: x['AADTT19xLength'] / x['eRoads_length_km']).reset_index()
                       .drop(columns='AADTT19xLength')
                       .assign(eRoads_max_aadtt = input_params['eRoads_max_aadtt'])
)
print(eRoads_data_summary)

truck_specs = truck_specs.merge(eRoads_data_summary, how='left')
# Out:
#    Bin  eRoads_length_km  eRoads_length_weighted_aadtt19  eRoads_max_aadtt
# 0    1            838.85                    15832.635751             42000
# 1    2            838.87                     5871.444920             42000
# 2    3           2499.47                     1570.391483             42000
# 3    4           4176.97                      596.512280             42000
# 4    5           8426.22                       87.509192             42000

# %% [markdown]
# # Define truck specifications
# - From input-data.xlsx
# - Truck data from Islam et al (2023) Autonomie
# - Prepare truck specs, weights, energy consumption, costs with Autonomie Islam 2023 for each long-haul truck config
# - Filter to Purpose=Longhaul only
# - Output: data for each technology to construct tables 'MaxAnnualCapacityFactor', 'CostInvest'
# - Efficiency doesnt need to be recalculated, just reuse existing spreadsheet, but separate into non long-haul and long-haul
# - 'CostVariable' just reuse existing spreadsheet
#
# To be appended in sheet 'Autonomie 2023 MHDV', with column names:
# - Vehicle Manufacturing Cost ($ 2023USD)

# %% [markdown]
# ### Analyze Autonomie data

# %%
# Read the Excel file and select the relevant sheet
file_path = 'Autonomie HDT.xlsx'
autonomie_df = pd.read_excel(file_path, sheet_name='class8_longhaul_daycab')

# Calculate kWh/km depending on Powertrain
# if BEV, use Usable_Energy_kWh / Range
autonomie_df['kWh_per_km'] = np.where(
    autonomie_df['Powertrain'] == 'BEV',
    autonomie_df['Usable_Energy_kWh'] / (autonomie_df['Range'] * 1.60934),  # Convert miles to km
    # if FCEV, use kg H2 * 33.33 LHV / Range km
    #np.where(
    #    autonomie_df['Powertrain'] == 'FCEV',
    #    autonomie_df['H2_Mass_kg'] * 33.33 / (autonomie_df['Range'] * 1.60934),  # Convert miles to km
    # if ICE, use mpgde to calculate kWh/km
    # 1 gallon diesel = 37.656 kWh, 1 mile = 1.60934 km
    # 128,488 Btu/gal Low Sulfur Diesel https://afdc.energy.gov/fuels/properties
    37.656 / (autonomie_df['mpgde'] * 1.60934)
    #)
)
# Try: just use mpdge?
autonomie_df['kWh_per_km_mpdge'] = 37.656 / (autonomie_df['mpgde'] * 1.60934)
autonomie_df['kWh_per_km_DC_Whpm'] = (autonomie_df['DC_Whpm'] / 1.60934 / 1000)  # Convert Wh/mile to kWh/km

autonomie_df = autonomie_df.query('RegCode.isin(["DayCab", "Sleeper"])')

# %%
# Function to compute scaled vehicle cost and weight based on desired range
def compute_scaled_attributes(df, Powertrain, Year, Case, Purpose, RegCode, desired_range_km, 
                              eRoads_equipment_kg = 0, eRoads_equipment_cost = 0,
                              **kwargs):
    subset = df[(df['Powertrain'] == Powertrain) &
                (df['Year'] == Year) &
                (df['Case'] == Case) &
                (df['Purpose'] == Purpose) &
                (df['RegCode'] == RegCode)]

    if subset.empty:
        raise ValueError("No matching data found for the provided filters.")
    if subset.shape[0] > 1:
        raise ValueError("Multiple matches found for filter conditions.")

    row = subset.iloc[0].to_dict()
    desired_range_miles = desired_range_km / 1.60934
    scale_factor = desired_range_miles / row['Range']

    Pack_Energy_kWh = row['Pack_Energy_kWh']  # Default value
    H2_Mass_kg = row['H2_Mass_kg']  # Default value

    if Powertrain == 'BEV':
        scaled_battery_kg = row['Battery_kg'] * scale_factor
        scaled_battery_cost = row['Battery_Cost'] * scale_factor
        
        weight_minus_battery = row['CurbWeight'] - row['Battery_kg']
        cost_minus_battery = row['VehicleCost'] - row['Battery_Cost']

        vehicle_weight = weight_minus_battery + scaled_battery_kg + eRoads_equipment_kg
        vehicle_cost = cost_minus_battery + scaled_battery_cost + eRoads_equipment_cost

        Pack_Energy_kWh *= scale_factor

    elif Powertrain == 'FCEV':
        scaled_h2_tank_kg = row['H2_Tank_kg'] * scale_factor
        scaled_h2_storage_cost = row['H2_Storage_Cost'] * scale_factor
        scaled_battery_kg = row['Battery_kg']    # just copy the battery weight, no scaling

        weight_minus_tank = row['CurbWeight'] - row['H2_Tank_kg']
        cost_minus_tank = row['VehicleCost'] - row['H2_Storage_Cost']
        
        vehicle_weight = weight_minus_tank + scaled_h2_tank_kg
        vehicle_cost = cost_minus_tank + scaled_h2_storage_cost

        H2_Mass_kg *= scale_factor

    else:
        raise ValueError("Powertrain must be 'BEV' or 'FCEV'.")
    return {
            'CurbWeight': vehicle_weight,
            'VehicleCost': vehicle_cost,
            'PayloadCapacity': row['GVWR'] - vehicle_weight,
            'kWh_per_km': row['kWh_per_km'],
            'Pack_Energy_kWh': Pack_Energy_kWh, 
            'H2_Mass_kg': H2_Mass_kg,
            'Battery_kg': scaled_battery_kg
        }

# %%
compute_scaled_attributes(autonomie_df, 
                          **autonomie_df.query('Range >= 499').iloc[0].to_dict(), 
                          desired_range_km=1000)
# Out:
# {'CurbWeight': 20522.365678874936,
#  'VehicleCost': 382209.7582772525,
#  'PayloadCapacity': 15764.994321125065,
#  'kWh_per_km': 1.3261061056847827,
#  'Pack_Energy_kWh': 1473.4512285386477,
#  'H2_Mass_kg': 0.0,
#  'Battery_kg': 8840.707371231883}

# %% [markdown]
# ### [outdated] Get average payload from CFAF

# %%
# region = 'ON'
# long_haul_threshold = 600

# mean_weight_abvthreshold = (pd.read_csv('cfaf_province_longhaul_threshold_stats.csv').query(f'region == "{region}" and long_haul_threshold=={long_haul_threshold}')
#                             ['mean_weight_abvthreshold'].iloc[0])
# print(f"Mean weight above threshold for {region} with long haul threshold {long_haul_threshold} km: {round(mean_weight_abvthreshold)} kg")

# %% [markdown]
# ### Get weight distribution from Ontario CVS data
#
# Procedure:
# - Start with cargo weight distribution (% of truck carrying xxx kg of cargo)
# - Given a payload capacity, what is the % of trucks above this capacity?
# - For each cargo level, calculate the penalty (minimum 1)
# - Then take a weighted sum

# %%
weight_dist = pd.read_csv('../../../Paper 3 - Charging profiles/input_data/cargo_weight_distribution.csv')

def calculate_payload_penalty(weight_dist, payload_capacity):
    """
    Calculate weighted penalty for given payload capacity.
    
    Parameters:
    -----------
    weight_dist : pd.DataFrame
        DataFrame with columns: weight_bin, midpoint_kg, pct_trucks
    payload_capacity : float
        Payload capacity in kg
    
    Returns:
    --------
    float
        Weighted average penalty (minimum 1.0)
    """
    # Calculate penalty for each weight bin (minimum 1)
    weight_dist_copy = weight_dist.copy()
    weight_dist_copy['penalty'] = weight_dist_copy['midpoint_kg'].apply(
        lambda x: max(1, x / payload_capacity)
    )
    
    # Calculate weighted sum
    weighted_penalty = (weight_dist_copy['penalty'] * weight_dist_copy['pct_trucks']).sum()
    
    return round(float(weighted_penalty), 2)

# Example usage:
calculate_payload_penalty(weight_dist, 11_000)
# Out:
# 1.2

# %% [markdown]
# ### Get energy consumption, battery, H2 size
# - Energy consumption for BETs (kWh/km), H2FCETs (kgH2/100 km), ICE trucks (L/100 km)
# - BET battery size (kWh), H2FCET H2 tank size (kgH2). Check that battery and H2 tank size vs. energy consumption and range make sense

# %%
# expand 'Year', add 'Case'
truck_specs = (truck_specs.merge(autonomie_df[['Year']].drop_duplicates(), how='cross')
            .assign(Case=input_params['autonomie_tech_case'])
            )
truck_specs = truck_specs.assign(Purpose = "Longhaul", RegCode = "Sleeper")

# compute scaled attributes
truck_specs = pd.concat([truck_specs, 
                      truck_specs.apply(lambda x: compute_scaled_attributes(df=autonomie_df, **x), axis='columns', result_type='expand')], 
                      axis='columns')

# ===== Add payload capacity penalty =====
# [old] relative to mean_weight_abvthreshold
# truck_specs['PayloadCapacityPenalty'] = np.clip(mean_weight_abvthreshold / truck_specs['PayloadCapacity'], a_min=1, a_max=999)

# Based on weight distribution
truck_specs['PayloadCapacityPenalty'] = truck_specs['PayloadCapacity'].apply(lambda x: calculate_payload_penalty(weight_dist=weight_dist, payload_capacity=x))

truck_specs#.drop(columns='notes').query('Year==2030')
# Out:
#                   tech_veh              tech_supply  Bin Powertrain  \
# 0   T_HDV_T_LH_BEV_LRGBATT  T_HDV_T_LH_CHRG_LRGBATT  NaN        BEV
# 1   T_HDV_T_LH_BEV_LRGBATT  T_HDV_T_LH_CHRG_LRGBATT  NaN        BEV
# 2   T_HDV_T_LH_BEV_LRGBATT  T_HDV_T_LH_CHRG_LRGBATT  NaN        BEV
# 3   T_HDV_T_LH_BEV_LRGBATT  T_HDV_T_LH_CHRG_LRGBATT  NaN        BEV
# 4   T_HDV_T_LH_BEV_LRGBATT  T_HDV_T_LH_CHRG_LRGBATT  NaN        BEV
# 5   T_HDV_T_LH_BEV_FSTCHRG  T_HDV_T_LH_CHRG_FSTCHRG  NaN        BEV
# 6   T_HDV_T_LH_BEV_FSTCHRG  T_HDV_T_LH_CHRG_FSTCHRG  NaN        BEV
# 7   T_HDV_T_LH_BEV_FSTCHRG  T_HDV_T_LH_CHRG_FSTCHRG  NaN        BEV
# 8   T_HDV_T_LH_BEV_FSTCHRG  T_HDV_T_LH_CHRG_FSTCHRG  NaN        BEV
# 9   T_HDV_T_LH_BEV_FSTCHRG  T_HDV_T_LH_CHRG_FSTCHRG  NaN        BEV
# 10    T_HDV_T_LH_BEV_ERDS1    T_HDV_T_LH_CHRG_ERDS1  1.0        BEV
# 11    T_HDV_T_LH_BEV_ERDS1    T_HDV_T_LH_CHRG_ERDS1  1.0        BEV
# 12    T_HDV_T_LH_BEV_ERDS1    T_HDV_T_LH_CHRG_ERDS1  1.0        BEV
# ...

# %%
# Energy consumption, battery capacity for BETs, H2 tank capacity for H2FCETs
tech_case = 'Low'
years_to_check = [2023, 2050]
RegCode = 'Sleeper'

plot_data = (autonomie_df.query('Case==@tech_case and Year.isin(@years_to_check) and RegCode==@RegCode'))
             
print(plot_data.query('Powertrain=="BEV"')
 [['Year', 'Case', 'Powertrain', 'kWh_per_km', 'kWh_per_km_mpdge', 'kWh_per_km_DC_Whpm', 'Pack_Energy_kWh', 'Usable_Energy_kWh']]
 .assign(kWh_per_km_OC_penalty = lambda x: x['kWh_per_km'] * 1.08,    # Apply 8% penalty for eRoads OC pantograph drag (from Paper 1)
         implied_range_km = plot_data ['Usable_Energy_kWh'] / plot_data ['kWh_per_km'])
 .apply(lambda x: x.map(lambda y: f'{y:.4g}') if x.dtype == 'float64' else x)  # 3sf only for float columns
 )

# calculate kg H2 per 100 km for FCEV. 1 kgH2 = 120 MJ = 33.333 kWh LHV
print(plot_data.query('Powertrain=="FCEV"')
      .assign(kgH2_per_100km = 100*plot_data ['kWh_per_km'] / 33.33)
 [['Year', 'Case', 'Powertrain', 'kgH2_per_100km', 'H2_Mass_kg']]
 .assign(implied_range_km = lambda x: 100 * x['H2_Mass_kg'] / x['kgH2_per_100km'])
 .apply(lambda x: x.map(lambda y: f'{y:.3g}') if x.dtype == 'float64' else x)  # 3sf only for float columns
 )

# convert U.S. gallons per mile to liters per 100 km
print(plot_data.query('Powertrain=="Conv"')
 .assign(L_per_100km = 100*3.78541 / plot_data['mpgde'] / 1.60934)
 [['Year', 'Case', 'Powertrain', 'mpgde', 'L_per_100km']]
 .apply(lambda x: x.map(lambda y: f'{y:.3g}') if x.dtype == 'float64' else x)  # 3sf only for float columns
)
# Out:
#      Year Case Powertrain kWh_per_km kWh_per_km_mpdge kWh_per_km_DC_Whpm  \
# 125  2023  Low        BEV      1.519            1.775              1.583
# 129  2050  Low        BEV        1.2            1.128              1.006
#
#     Pack_Energy_kWh Usable_Energy_kWh kWh_per_km_OC_penalty implied_range_km
# 125            1359              1223                 1.641            804.7
# 129            1027             965.4                 1.296            804.7
#      Year Case Powertrain kgH2_per_100km H2_Mass_kg implied_range_km
# 141  2023  Low       FCEV           8.82       83.8              950
# 149  2050  Low       FCEV           5.28       51.4              974
#      Year Case Powertrain mpgde L_per_100km
# 130  2023  Low       Conv  6.98        33.7
# 139  2050  Low       Conv  10.3        22.9

# %%
# Investigate mpdge vs Wh/mile for BETs, H2FCETs, ICE trucks
# mpdge, DC_Whpm (this is weighted by drive cycle (ARB, EPA55, EPA65))
# kWh_per_km: calculated based on Usable kWh vs range for BETs, mpdge for H2FCETs and ICE
# kWh_per_km_mpdge: calculated based on mpgde for all powertrains, for comparison
# kWh_per_km_DC_Whpm: calculated based on DC_Whpm for BETs, for comparison

# compare mpdge vs DC_Whpm for BETs with scatterplot
import matplotlib.pyplot as plt
import itertools
# give all pairwise combinations of kWh_per_km, kWh_per_km_mpdge, kWh_per_km_DC_Whpm
for x,y in itertools.combinations(['kWh_per_km', 'kWh_per_km_mpdge', 'kWh_per_km_DC_Whpm'], 2):
    plot_data = autonomie_df.query('Powertrain=="BEV"')
    plt.figure(figsize=(4,3))
    plt.scatter(data=plot_data, x=x, y=y)
    # add line y=x for reference
    plt.plot([plot_data[[x,y]].min().min(), plot_data[[x,y]].max().max()], 
             [plot_data[[x,y]].min().min(), plot_data[[x,y]].max().max()], 
             color='red', linestyle='--')
    plt.xlabel(x, fontsize=8)
    plt.ylabel(y, fontsize=8)
    plt.title(f'Scatter plot of {x}\nvs {y} for BEVs', fontsize=9)
    plt.show()

# %% [markdown]
# ### Calculate CapacityToActivity for infra

# %%
def calc_CapacityToActvity_infra(tech_supply, charger_standard_kW, charger_fast_kW, eRoads_max_aadtt, kWh_per_km, **kwargs):
    if (tech_supply == 'T_HDV_T_LH_CHRG_LRGBATT'): # or (tech_supply == 'T_H2_HDV_T_LH_REFUEL'):
        return charger_standard_kW*60*60*24*365/1e12    # 60 seconds * 60 minutes * 24 hours * 365 days / 1e12 to convert to PJ
    elif tech_supply == 'T_HDV_T_LH_CHRG_FSTCHRG':
        return charger_fast_kW*60*60*24*365/1e12    # 60 seconds * 60 minutes * 24 hours * 365 days / 1e12 to convert to PJ
        # skip this
        # return ((charger_standard_kW*input_params['overnight_charging_share']) + (charger_fast_kW*(1-input_params['overnight_charging_share'])))*60*60*24*365/1e12
    elif 'CHRG_ERDS' in tech_supply:
        return eRoads_max_aadtt * 365 * kWh_per_km * 3.6 / 1e9  # convert to PJ
    else:
        return np.nan  # Default case if no conditions are met

# %%
# apply the function to calculate CapacityToActivity_infra and keep original columns
truck_specs['CapacityToActivity_infra'] = (truck_specs.apply(lambda x: calc_CapacityToActvity_infra(**x), axis='columns', result_type='expand'))

# %% [markdown]
# ### Export truck specs

# %%
truck_specs.to_csv('../../../Paper 3 - Charging profiles/input_data/truck_specs.csv', index=False)

# %% [markdown]
# # Output data for insertions.xlsx

# %%
truck_specs = pd.read_csv('../../../Paper 3 - Charging profiles/input_data/truck_specs.csv')

# %%
# output Pack_Energy_kWh for trucks
df_wide = (truck_specs[['tech_veh', 'Case', 'Year', 'Pack_Energy_kWh']]
      .pivot(index=['tech_veh', 'Case'], columns='Year', values='Pack_Energy_kWh'))
for y in [2040, 2045]:
    if y not in df_wide.columns and 2035 in df_wide.columns and 2050 in df_wide.columns:
        df_wide[y] = df_wide[2035] + (df_wide[2050] - df_wide[2035]) * ((y-2035)/(2050-2035))
df_wide = df_wide.round(2)
df_wide = df_wide.rename(columns={2023: 2021})
df_wide = df_wide.reindex(sorted(df_wide.columns), axis=1)
df_wide.to_csv('../../../Paper 3 - Charging profiles/input_data/truck_specs_Pack_Energy_kWh.csv')
display(df_wide)
# Out:
# Year                            2021     2025     2030     2035     2040  \
# tech_veh               Case
# T_HDV_T_LH_BEV_ERDS1   Low    679.13   635.63   589.72   547.28   535.98
# T_HDV_T_LH_BEV_ERDS2   Low    679.13   635.63   589.72   547.28   535.98
# T_HDV_T_LH_BEV_ERDS3   Low    679.13   635.63   589.72   547.28   535.98
# T_HDV_T_LH_BEV_ERDS4   Low    679.13   635.63   589.72   547.28   535.98
# T_HDV_T_LH_BEV_ERDS5   Low    679.13   635.63   589.72   547.28   535.98
# T_HDV_T_LH_BEV_FSTCHRG Low   1358.26  1271.27  1179.43  1094.55  1071.97
# T_HDV_T_LH_BEV_LRGBATT Low   2037.39  1906.90  1769.15  1641.83  1607.95
# T_HDV_T_LH_FCEV        Low     17.96    17.96    16.63    16.63    16.47
#
# Year                            2045     2050
# tech_veh               Case
# T_HDV_T_LH_BEV_ERDS1   Low    524.69   513.40
# T_HDV_T_LH_BEV_ERDS2   Low    524.69   513.40
# T_HDV_T_LH_BEV_ERDS3   Low    524.69   513.40
# T_HDV_T_LH_BEV_ERDS4   Low    524.69   513.40
# ...

# %%
# output costs for CostInvest for vehicle technologies only
(truck_specs.query('Case=="Low"').pivot(index='tech_veh', columns='Year', values='VehicleCost')
 .reset_index().style.hide())
# Out:
# <style type="text/css">
# </style>
# <table id="T_eaba0">
#   <thead>
#     <tr>
#       <th id="T_eaba0_level0_col0" class="col_heading level0 col0" >tech_veh</th>
#       <th id="T_eaba0_level0_col1" class="col_heading level0 col1" >2023</th>
#       <th id="T_eaba0_level0_col2" class="col_heading level0 col2" >2025</th>
#       <th id="T_eaba0_level0_col3" class="col_heading level0 col3" >2030</th>
#       <th id="T_eaba0_level0_col4" class="col_heading level0 col4" >2035</th>
#       <th id="T_eaba0_level0_col5" class="col_heading level0 col5" >2050</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_eaba0_row0_col0" class="data row0 col0" >T_HDV_T_LH_BEV_ERDS1</td>
#       <td id="T_eaba0_row0_col1" class="data row0 col1" >349278.772194</td>
#       <td id="T_eaba0_row0_col2" class="data row0 col2" >288181.391363</td>
#       <td id="T_eaba0_row0_col3" class="data row0 col3" >226549.577187</td>
# ...

# %%
# Calculate efficiency for BEVs, groupby RegCode, Year. Take the average. Use kwh_per_km, convert to PJ per billion km
(autonomie_df.query('Powertrain=="BEV" and Case=="Low"')
 .groupby(['RegCode', 'Year'])
 .agg(avg_kWh_per_km = ('kWh_per_km', 'mean'))
 .assign(avg_PJ_per_billion_km = lambda x: x['avg_kWh_per_km']*3.6,    # 1 kWh = 3.6 MJ
         bkm_per_PJ = lambda x: 1/x['avg_PJ_per_billion_km'])    
 .reset_index()
 .pivot(index='RegCode', columns='Year', values='bkm_per_PJ')
 ).style.format("{:.4f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_5f72e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Year</th>
#       <th id="T_5f72e_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_5f72e_level0_col1" class="col_heading level0 col1" >2025</th>
#       <th id="T_5f72e_level0_col2" class="col_heading level0 col2" >2030</th>
#       <th id="T_5f72e_level0_col3" class="col_heading level0 col3" >2035</th>
#       <th id="T_5f72e_level0_col4" class="col_heading level0 col4" >2050</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RegCode</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f72e_level0_row0" class="row_heading level0 row0" >DayCab</th>
# ...

# %%
# get payload penalty factors
(truck_specs.query('Case=="Low"').pivot(index='tech_veh', columns='Year', values='PayloadCapacityPenalty')
 .reset_index().style.hide())
# Out:
# <style type="text/css">
# </style>
# <table id="T_fc2fa">
#   <thead>
#     <tr>
#       <th id="T_fc2fa_level0_col0" class="col_heading level0 col0" >tech_veh</th>
#       <th id="T_fc2fa_level0_col1" class="col_heading level0 col1" >2023</th>
#       <th id="T_fc2fa_level0_col2" class="col_heading level0 col2" >2025</th>
#       <th id="T_fc2fa_level0_col3" class="col_heading level0 col3" >2030</th>
#       <th id="T_fc2fa_level0_col4" class="col_heading level0 col4" >2035</th>
#       <th id="T_fc2fa_level0_col5" class="col_heading level0 col5" >2050</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fc2fa_row0_col0" class="data row0 col0" >T_HDV_T_LH_BEV_ERDS1</td>
#       <td id="T_fc2fa_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_fc2fa_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_fc2fa_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_fc2fa_row0_col4" class="data row0 col4" >1.000000</td>
# ...

# %%
# CapacityToActivity for infrastructure
(truck_specs.groupby('tech_supply')['CapacityToActivity_infra']
 .mean()    # take the average value observed
 .reset_index()
 .style.hide())
# Out:
# <style type="text/css">
# </style>
# <table id="T_6e690">
#   <thead>
#     <tr>
#       <th id="T_6e690_level0_col0" class="col_heading level0 col0" >tech_supply</th>
#       <th id="T_6e690_level0_col1" class="col_heading level0 col1" >CapacityToActivity_infra</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6e690_row0_col0" class="data row0 col0" >T_H2_HDV_T_LH_REFUEL</td>
#       <td id="T_6e690_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_6e690_row1_col0" class="data row1 col0" >T_HDV_T_LH_CHRG_ERDS1</td>
#       <td id="T_6e690_row1_col1" class="data row1 col1" >0.074090</td>
#     </tr>
#     <tr>
#       <td id="T_6e690_row2_col0" class="data row2 col0" >T_HDV_T_LH_CHRG_ERDS2</td>
#       <td id="T_6e690_row2_col1" class="data row2 col1" >0.074090</td>
#     </tr>
#     <tr>
#       <td id="T_6e690_row3_col0" class="data row3 col0" >T_HDV_T_LH_CHRG_ERDS3</td>
# ...

# %%
# MaxCapacity for eRoads
(truck_specs[['tech_supply', 'eRoads_length_km']].drop_duplicates().dropna()
 # expand over all periods
 #.merge(pd.DataFrame({'period': [2021, 2025, 2030, 2035, 2040, 2045, 2050]}), how='cross')
 .style.format(precision=2).hide()
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_32e2f">
#   <thead>
#     <tr>
#       <th id="T_32e2f_level0_col0" class="col_heading level0 col0" >tech_supply</th>
#       <th id="T_32e2f_level0_col1" class="col_heading level0 col1" >eRoads_length_km</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_32e2f_row0_col0" class="data row0 col0" >T_HDV_T_LH_CHRG_ERDS1</td>
#       <td id="T_32e2f_row0_col1" class="data row0 col1" >838.85</td>
#     </tr>
#     <tr>
#       <td id="T_32e2f_row1_col0" class="data row1 col0" >T_HDV_T_LH_CHRG_ERDS2</td>
#       <td id="T_32e2f_row1_col1" class="data row1 col1" >838.87</td>
#     </tr>
#     <tr>
#       <td id="T_32e2f_row2_col0" class="data row2 col0" >T_HDV_T_LH_CHRG_ERDS3</td>
#       <td id="T_32e2f_row2_col1" class="data row2 col1" >2499.47</td>
#     </tr>
#     <tr>
#       <td id="T_32e2f_row3_col0" class="data row3 col0" >T_HDV_T_LH_CHRG_ERDS4</td>
# ...

# %% [markdown]
# # [unused] Create database from insertions.xlsx

# %%
importlib.reload(lihwei_db_edits)
# Out:
# <module 'lihwei_db_edits' from 'c:\\Users\\yeowl\\OneDrive - University of Toronto\\1UofT\\PhD Research\\CANOE\\CANOE-transportation\\lihwei_db_edits\\lihwei_db_edits.py'>

# %%
# create database from insertion.xlsx
lihwei_db_edits.xlsx_to_sqlite('insertions.xlsx', 
                               'insertions.sqlite', 
                               schema_ref_db='../db_processing/update_database/target_database/canoe_on_365d_vanilla4.sqlite')
# Out:
# Dropping empty table: Commodity
# Dropping empty table: TechOutputSplit
# Dropping empty table: TechInputSplit
# Dropping empty table: TechInputSplitAverage
# Dropping empty table: TimeSegmentFraction
# Dropping empty table: PlanningReserveMargin
# Dropping empty table: RampDown
# Dropping empty table: RampUp
# Dropping empty table: MinCapacity
# Dropping empty table: MinActivity
# Dropping empty table: MaxCapacity
# Dropping empty table: MaxActivity
# Dropping empty table: MinAnnualCapacityFactor
# Dropping empty table: MaxAnnualCapacityFactor
# Dropping empty table: LifetimeTech
# Dropping empty table: LifetimeProcess
# Dropping empty table: LoanLifetimeTech
# Dropping empty table: GrowthRateSeed
# Dropping empty table: ExistingCapacity
# Dropping empty table: EmissionLimit
# Dropping empty table: EmissionActivity
# Dropping empty table: Efficiency
# Dropping empty table: Demand
# Dropping empty table: CostVariable
# Dropping empty table: CostInvest
# ...

# %%
import db_processing.update_database.subset_replacement
importlib.reload(db_processing.update_database.subset_replacement)
from db_processing.update_database.subset_replacement import replace_subset

# use replace_subset() to add rows to existing database
replace_subset(
    target_path='../db_processing/update_database/target_database/canoe_on_365d_vanilla4',
    source_path='insertions',
    output_path='canoe_on_365d_newtech',
    sql_instructions_path='modifications.sql'
)
# Out:
# Tables in source_conn: ['Commodity', 'MaxCapacity', 'MinAnnualCapacityFactor', 'MaxAnnualCapacityFactor', 'LifetimeTech', 'ExistingCapacity', 'Efficiency', 'Demand', 'CostInvest', 'CostFixed', 'CapacityToActivity', 'Technology']
# 'references' not in source_tables. Will not replace references.
# Done. Saved to: canoe_on_365d_newtech.sqlite

# %%
# clean up table LifetimeTech
with sqlite3.connect("canoe_on_365d_newtech.sqlite") as conn:
    cursor = conn.cursor()
    cursor.execute("DELETE FROM LifetimeTech WHERE lifetime IS NULL OR lifetime = ''")
    conn.commit()
print("Cleaned LifetimeTech table")
# Out:
# Cleaned LifetimeTech table

# %% [markdown]
# # [skip] Convert database to v3.1

# %%
# Add missing columns to the database

db_path_list = ['canoe_on_365d_newtech.sqlite']

for db_path in db_path_list:
    with sqlite3.connect(db_path) as conn:
        cursor = conn.cursor()

        # Add column seas_stor and set all to 0
        # Check if seas_stor column exists in Technology table
        cursor.execute("PRAGMA table_info(Technology)")
        columns = [row[1] for row in cursor.fetchall()]
        
        if 'seas_stor' not in columns:
            cursor.execute("ALTER TABLE Technology ADD COLUMN seas_stor INTEGER NOT NULL DEFAULT 0;")
            cursor.execute("UPDATE Technology SET seas_stor = 0;")
            
        # ==========
        # remove rows in Efficiency table where input_comm='R_elc' and output_comm='R_elc' and notes='arbitrarily small non-zero efficiency'
        cursor.execute("""
                DELETE FROM Efficiency WHERE 
                       input_comm='R_elc' AND output_comm='R_elc' AND notes='arbitrarily small non-zero efficiency';
                """)
        
        # ==========
        # Set all demand techs where output_comm are demand commodities, set annual=1
        cursor.execute("""UPDATE Technology SET annual = 1 WHERE tech IN 
                       (SELECT DISTINCT tech FROM Efficiency WHERE output_comm IN
                       (SELECT name FROM Commodity WHERE flag='d'))
                       """)
        # Also set annual=1 for specific technologies
        tech_exact = ["H2_distribution", "I_H2_SMR", "I_H2_SMR_CCS", "T_LDV_M_BEV_N"]
        tech_like = ["T_LDV_C_BEV%", "T_LDV_LTF_BEV%", "T_LDV_LTP_BEV%"]
        # Update for exact matches
        cursor.execute(f"UPDATE Technology SET annual = 1 WHERE tech IN ({','.join(['?'] * len(tech_exact))})", tech_exact)
        # Update for LIKE patterns
        for pattern in tech_like: cursor.execute("UPDATE Technology SET annual = 1 WHERE tech LIKE ?", (pattern,))
        
        # Set H2 compression technologies to NOT annual (annual=0)
        cursor.execute("UPDATE Technology SET annual = 0 WHERE tech IN ('H2_COMP_10_100', 'H2_COMP_100_700')")
        conn.commit()
        
        # ==========
        # Moving rows from TechInputSplit to TechInputSplitAverage for annual and demand technologies
        # List of additional techs to move
        extra_techs = ["I_PULPPAPER_GEN","I_SMELTING_GEN", "I_STEEL_GEN", "I_MANUF-OTH_GEN", "I_CHEMICAL_GEN",
                       "I_CEMENT_GEN", "I_MINING_GEN", "C_OTHER", "I_REFINERY"]
        placeholders = ','.join(['?'] * len(extra_techs))

        # Move annual technologies (Technology WHERE annual=1) in TechInputSplit to TechInputSplitAverage
        cursor.execute("""
            INSERT INTO TechInputSplitAverage
            SELECT tis.* FROM TechInputSplit tis
            JOIN Technology t ON tis.tech = t.tech WHERE t.annual = 1;
        """)
        # Also move rows where tech is in extra_techs
        cursor.execute(f"INSERT INTO TechInputSplitAverage SELECT * FROM TechInputSplit WHERE tech IN ({placeholders});", extra_techs)

        # Remove those rows from TechInputSplit
        cursor.execute("DELETE FROM TechInputSplit WHERE tech IN (SELECT tech FROM Technology WHERE annual = 1);")
        cursor.execute(f"DELETE FROM TechInputSplit WHERE tech IN ({placeholders});", extra_techs)

        conn.commit()
        
        # ==========
        # Switch commodities to annual commodities that are produced by annual technologies AND are orginally flag = 'p'
        cursor.execute("""UPDATE Commodity SET flag = 'a' WHERE name IN 
                       (SELECT DISTINCT output_comm FROM Efficiency WHERE tech IN (SELECT tech FROM Technology WHERE annual=1))
                       AND flag = 'p'
                       """)
        # also switch "T_elc_ldv_bev_chrg", "h2" to annual
        cursor.execute("""UPDATE Commodity SET flag = 'a' WHERE name IN ('T_elc_ldv_bev_chrg', 'h2', 'h2_700')""")
        # switch h2_10 and h2_100 to not annual
        cursor.execute("""UPDATE Commodity SET flag = 'p' WHERE name IN ('h2_10', 'h2_100')""")
    
        conn.commit()
    conn.close()
conn.close()

# %%
# Use db_migration_v3_to_v3_1.py to convert databases to v3.1. Uses the 'temoa' conda environment

# temoa working directory
temoa_wd = "C:/Users/yeowl/OneDrive - University of Toronto/1UofT/PhD Research/CANOE/temoa-1.0.0-dev-operator/temoa"

script_path = "temoa/utilities/db_migration_v3_to_v3_1.py"

for db_path in db_path_list:
    full_db_path = os.path.join(os.getcwd(), db_path)
    print(f"Running migration for {full_db_path}...")
    result = subprocess.run(f"conda run -n temoa python {script_path} --source \"{full_db_path}\"",
                            cwd=temoa_wd, capture_output=True, text=True, shell=True)
    print(result.stdout)
    if result.stderr:
        print("Error:", result.stderr)
# Out:
# Running migration for c:\Users\yeowlih\OneDrive - University of Toronto\1UofT\PhD Research\CANOE\CANOE-transportation\lihwei_db_edits\canoe_on_365d_newtech.sqlite...
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[21], line 11
#       9 full_db_path = os.path.join(os.getcwd(), db_path)
#      10 print(f"Running migration for {full_db_path}...")
# ---> 11 result = subprocess.run(f"conda run -n temoa python {script_path} --source \"{full_db_path}\"",
#      12                         cwd=temoa_wd, capture_output=True, text=True, shell=True)
#      13 print(result.stdout)
#      14 if result.stderr:
#
# File c:\Users\yeowlih\Miniconda3\envs\paper-3-profiles\Lib\subprocess.py:554, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     551     kwargs['stdout'] = PIPE
#     552     kwargs['stderr'] = PIPE
# ...

# %% [markdown]
# # ~ Do time series aggregation here ~
# Reduce from 365 days to xx days

# %%
# Temporary: transfer LimitAnnualCapacityFactor table from canoe_on_365d_newtech_v3_1.sqlite to canoe_on_16d_newtech_v3_1.sqlite
'''
db_source = 'canoe_on_365d_newtech_v3_1.sqlite'   # database to copy from
db_target = 'canoe_on_16d_newtech_v3_1.sqlite'   # database to overwrite

# Read table from source
with sqlite3.connect(db_source) as conn_src:
    df = pd.read_sql_query("SELECT * FROM LimitAnnualCapacityFactor", conn_src)

# Replace table in target
with sqlite3.connect(db_target) as conn_tgt:
    cursor = conn_tgt.cursor()
    cursor.execute("DROP TABLE IF EXISTS LimitAnnualCapacityFactor")
    conn_tgt.commit()
    df.to_sql('LimitAnnualCapacityFactor', conn_tgt, if_exists='replace', index=False)
'''

# %% [markdown]
# # Begin: make a copy of database

# %%
origin_db = 'canoe_dataset_ON_16d_bevsplit_growthlim_H2.sqlite'
target_db = 'ON_16d_bevsplit_growthlim_newtech.sqlite'
shutil.copyfile(origin_db, target_db)
print(f"Copied {origin_db} to {target_db}")
# Out:
# Copied canoe_dataset_ON_16d_bevsplit_growthlim_H2.sqlite to ON_16d_bevsplit_growthlim_newtech.sqlite

# %% [markdown]
# # Misc. fixes to database

# %% [markdown]
# ### [skip] Pad num_days in TimeSeriesSequential so that sum of num_days equals days_per_period in MetaData

# %%
# No longer needed with the new database creation process
# Skip this for 2026 May

# target_db = 'canoe_on_16d_newtech_v3_1.sqlite'

# with sqlite3.connect(target_db) as conn:
#     cursor = conn.cursor()
#     days_per_period = cursor.execute("SELECT value FROM MetaData WHERE element = 'days_per_period'").fetchone()[0]

#     df = pd.read_sql_query("SELECT period, sequence, seas_seq, season, num_days FROM TimeSeasonSequential", conn)
#     sum_days = df.groupby('period')['num_days'].sum()

#     for period, sum_day in sum_days.to_dict().items():
#         if sum_day == 363 and days_per_period == 365:
#             print(f"Warning: period {period} has sum of num_days = {sum_day}, which does not match days_per_period = {days_per_period}")
#             cursor.execute(f"""UPDATE TimeSeasonSequential SET num_days = num_days + 1
#             WHERE period = {period} AND (sequence = 0 OR sequence = {df.query('period==@period').sequence.max()})
#             """)
#             #conn.commit()
#         else:
#             print(f'period: {period}, sum of num_days: {sum_day}, days_per_period: {days_per_period}')
    
#     # Update TimeSegmentFraction calculation
#     TimeSegmentFraction = (df.groupby(['period', 'season']).agg({'num_days':'sum'}).reset_index()
#                         .assign(segfrac=lambda x: x['num_days']/x.groupby('period')['num_days'].transform('sum')/24)
#                         .to_dict(orient='records'))
#     TimeSegmentFraction_script = ''
#     for row in TimeSegmentFraction:
#         # Update segfrac column where period and season match
#         TimeSegmentFraction_script += f"""UPDATE TimeSegmentFraction SET segfrac = {row['segfrac']} WHERE period = {row['period']} AND season = '{row['season']}'; """
#     cursor.executescript(TimeSegmentFraction_script)
#     conn.commit()
        
# conn.close()

# %% [markdown]
# ### [skip] Fix I_IMP_NG in EmissionActivity
# - Replace output_comm with 'I_ng' WHERE output_comm LIKE 'I_ea_ng' AND tech LIKE 'I_IMP_NG'

# %%
# Skip this for 2026 May
"""target_db = 'canoe_on_16d_newtech_v3_1.sqlite'

with sqlite3.connect(target_db) as conn:
    cursor = conn.cursor()
    cursor.execute("UPDATE EmissionActivity SET output_comm = 'I_ng' WHERE output_comm LIKE 'I_ea_ng' AND tech LIKE 'I_IMP_NG';")
    conn.commit()
conn.close()"""
# Out:
# 'target_db = \'canoe_on_16d_newtech_v3_1.sqlite\'\n\nwith sqlite3.connect(target_db) as conn:\n    cursor = conn.cursor()\n    cursor.execute("UPDATE EmissionActivity SET output_comm = \'I_ng\' WHERE output_comm LIKE \'I_ea_ng\' AND tech LIKE \'I_IMP_NG\';")\n    conn.commit()\nconn.close()'

# %% [markdown]
# ### Add minimum seasonal capacity factor for H2 electrolyzers
# - Use LimitSeasonalCapacityFactor. This is a workaround for electrolyzer minimum operating capacity because of current Temoa limitations.
# - Minimum operating level: 18% for alkaline, 7.6% for PEM. From Martinez Lopez et al (2023) DOI: 10.1016/j.rser.2023.113407.

# %%
#target_db = 'canoe_on_16d_newtech_v3_1.sqlite'
target_db = 'ON_16d_bevsplit_growthlim_newtech.sqlite'

min_seasonal_cap_fac = {'I_H2_ELC_ALK': 0.18,   # alkaline electrolyzer minimum capacity factor
                        'I_H2_ELC_PEM': 0.076}   # PEM electrolyzer minimum capacity factor

notes = "From Martinez Lopez et al (2023) DOI: 10.1016/j.rser.2023.113407. Workaround for minimum operating capacity."

with sqlite3.connect(target_db) as conn:
    cursor = conn.cursor()
    # Get all (period, season) combinations from TimeSeason
    combos = cursor.execute("SELECT DISTINCT period, season FROM TimeSeason").fetchall()
    # Add rows for each tech and (period, season) combo
    for tech, min_factor in min_seasonal_cap_fac.items():
        for period, season in combos:
            cursor.execute("""
                INSERT OR IGNORE INTO LimitSeasonalCapacityFactor (region, period, season, tech, operator, factor, notes)
                VALUES ('ON', ?, ?, ?, 'ge', ?, ?)
            """, (period, season, tech, min_factor, notes))
    conn.commit()

# PASSED: ON_16d_bevsplit_growthlim_newtech_electrolyzer_seasonal.sqlite

# %% [markdown]
# # Create and modify database from insertions_v3_1.xlsx
# - Compatible with database v3.1

# %%
importlib.reload(lihwei_db_edits)

# create database from insertion.xlsx
lihwei_db_edits.xlsx_to_sqlite('insertions_v3_1.xlsx', 
                               'insertions_v3_1.sqlite', 
                               schema_ref_db='ON_16d_bevsplit_growthlim_newtech.sqlite'
                               #schema_ref_db='canoe_on_16d_newtech_v3_1.sqlite'
                               )
# Out:
# Sheet 'Overview' does not match any defined schema and will be skipped.
# Sheet '_ExistingCapacity' does not match any defined schema and will be skipped.
# Sheet '_LimitActivity' does not match any defined schema and will be skipped.
# c:\Users\yeowl\miniconda3\envs\paper-3-profiles\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():
# c:\Users\yeowl\miniconda3\envs\paper-3-profiles\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():
# c:\Users\yeowl\miniconda3\envs\paper-3-profiles\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():
# ...

# %% [markdown]
# ### Prepare database for insertions

# %%
# Mapping technologies from T_HDV_T to T_HDV_T_LH
T_HDV_T_LH_mapping = {
    'T_HDV_T_BEV': ['T_HDV_T_LH_BEV_LRGBATT',
                    'T_HDV_T_LH_BEV_FSTCHRG',
                    'T_HDV_T_LH_BEV_ERDS1',
                    'T_HDV_T_LH_BEV_ERDS2',
                    'T_HDV_T_LH_BEV_ERDS3',
                    'T_HDV_T_LH_BEV_ERDS4',
                    'T_HDV_T_LH_BEV_ERDS5'],
    'T_HDV_T_DSL': ['T_HDV_T_LH_DSL'],
    'T_HDV_T_FCEV': ['T_HDV_T_LH_FCEV']
}

# %%
#target_db = 'canoe_on_16d_newtech_v3_1.sqlite'
target_db = 'ON_16d_bevsplit_growthlim_newtech.sqlite'

with sqlite3.connect(target_db) as conn:
    cursor = conn.cursor()
    # DELETE FROM Efficiency WHERE (tech LIKE 'T_HDV_T_DSL%' OR tech LIKE 'T_HDV_T_BEV%' OR tech LIKE 'T_HDV_T_FC%') AND region = 'ON';
    cursor.execute("""
        DELETE FROM Efficiency WHERE (tech LIKE 'T_HDV_T_DSL%' OR tech LIKE 'T_HDV_T_BEV%' OR tech LIKE 'T_HDV_T_FC%') AND region = 'ON';
    """)
    cursor.execute("""
        DELETE FROM CostInvest WHERE (tech LIKE 'T_HDV_T_DSL%' OR tech LIKE 'T_HDV_T_BEV%' OR tech LIKE 'T_HDV_T_FC%') AND region = 'ON';
    """)
    conn.commit()

    tables_copy = ['CostVariable', 'CapacityToActivity', 'LifetimeTech', 'LifetimeSurvivalCurve']

    for table in tables_copy:
        # check if table has any rows where tech contains "LH"
        cursor.execute(f"""
            SELECT COUNT(*) FROM {table} WHERE tech LIKE 'T_HDV_T_LH%';
        """)

        if cursor.fetchone()[0] == 0:
            # No rows found, duplicate rows from T_HDV_T
            # extract rows from table where tech is in T_HDV_T_mapping keys
            for base_tech, new_techs in T_HDV_T_LH_mapping.items():
                cursor.execute(f"""
                    SELECT * FROM {table} WHERE tech = '{base_tech}';
                """)
                rows = cursor.fetchall()
                columns = [description[0] for description in cursor.description]
                for new_tech in new_techs:
                    for row in rows:
                        row_dict = dict(zip(columns, row))
                        row_dict['tech'] = new_tech
                        placeholders = ', '.join(['?'] * len(row_dict))
                        cursor.execute(f"""
                            INSERT INTO {table} ({', '.join(row_dict.keys())}) VALUES ({placeholders});
                        """, tuple(row_dict.values()))
                conn.commit()
        else: print(f"Rows with T_HDV_T_LH% already exist in {table}, skipping duplication.")

# ON_16d_bevsplit_growthlim_newtech_a.sqlite

# %% [markdown]
# ### Disaggregate HDV trucks for long-haul and non long-haul
# This applies to tables: Demand, ExistingCapacity, LimitAnnualCapacityFactor
#
# Recalculate LACF using the formulas:
# $$ACF_0=\frac{D_0}{S_0}$$
# $$ACF=\frac{D_0×C_D}{S_0×c_S}=ACF_0 \frac{c_D}{c_S}$$
# Where c_D and c_S are constants [0,1] to disaggregate HDTs into long-haul and non long-haul segments.

# %%
# Read CFAF disaggregation factor
CFAF_disagg_factor = pd.read_excel('insertions_v3_1.xlsx', sheet_name='CFAF', header=1)

print(CFAF_disagg_factor)
CFAF_disagg_factor = CFAF_disagg_factor.iloc[:,[1,4]].dropna()
CFAF_disagg_factor.columns = ['attribute', 'prop']
CFAF_disagg_factor = CFAF_disagg_factor.set_index('attribute')
CFAF_disagg_factor = CFAF_disagg_factor.to_dict(orient='index')
CFAF_disagg_factor
# Out:
#                                           Unnamed: 0 Unnamed: 1  \
# 0                                   Number of trucks  Shipments
# 1                                   Freight activity    TonneKm
# 2                                                NaN        NaN
# 3  Source: Canadian Freight Analysis Framework, 2...        NaN
# 4  Notes: All of ON meaning either origin or dest...        NaN
#
#    All of Ontario  above long-haul threshold  proportion
# 0    2.482934e+07               8.837758e+06       0.356
# 1    1.143687e+11               8.676632e+10       0.759
# 2             NaN                        NaN         NaN
# 3             NaN                        NaN         NaN
# 4             NaN                        NaN         NaN
# {'Shipments': {'prop': 0.356}, 'TonneKm': {'prop': 0.759}}

# %%
target_db = 'ON_16d_bevsplit_growthlim_newtech.sqlite'

with sqlite3.connect(target_db) as conn:
    cursor = conn.cursor()
    
    # Disaggregate demand
    cursor.execute(f"SELECT COUNT(*) FROM Demand WHERE commodity LIKE 'T_D_tkm_hdv_t_lh'")
    if cursor.fetchone()[0] == 0:
        df = pd.read_sql_query("SELECT * FROM Demand WHERE commodity = 'T_D_tkm_hdv_t';", conn)
        # replace commodity name and adjust value
        df['commodity'] = 'T_D_tkm_hdv_t_lh'
        df['demand'] *= CFAF_disagg_factor['TonneKm']['prop']
        df['notes'] += " Ontario long-haul/short-haul split from Canadian Freight Analysis Framework 2017 data."
        # write back to database
        df.to_sql('Demand', conn, if_exists='append', index=False)
        # adjust original rows
        cursor.execute("""
            UPDATE Demand SET demand = demand * ? WHERE commodity = 'T_D_tkm_hdv_t';
        """, (1 - CFAF_disagg_factor['TonneKm']['prop'],))
    else: print("Disaggregated demand rows already exist, skipping disaggregation.")
    conn.commit()

    # Disaggregate Existing Capacity
    cursor.execute(f"SELECT COUNT(*) FROM ExistingCapacity WHERE tech LIKE 'T_HDV_T_LH%'")
    if cursor.fetchone()[0] == 0:
        df = pd.read_sql_query("SELECT * FROM ExistingCapacity WHERE tech LIKE 'T_HDV_T%';", conn)
        # create new rows for T_HDV_T_LH and adjust values
        new_rows = []
        for _, row in df.iterrows():
            if row['tech'] in T_HDV_T_LH_mapping:
                if row['notes'] is None: row['notes'] = ''
                row['notes'] += " Ontario long-haul/short-haul split from Canadian Freight Analysis Framework 2017 data."
                for new_tech in T_HDV_T_LH_mapping[row['tech']]:
                    new_row = row.copy()
                    new_row['tech'] = new_tech
                    new_row['capacity'] *= CFAF_disagg_factor['Shipments']['prop']
                    new_rows.append(new_row)
                # adjust original row
                row['capacity'] *= (1 - CFAF_disagg_factor['Shipments']['prop'])
                cursor.execute("""
                    UPDATE ExistingCapacity SET capacity = ?, notes = ? WHERE tech = ? and vintage = ? and region = ?;
                """, (row['capacity'], row['notes'], row['tech'], row['vintage'], row['region']))
        # write new rows to database
        if new_rows:
            df_new = pd.DataFrame(new_rows)
            df_new.to_sql('ExistingCapacity', conn, if_exists='append', index=False)
        conn.commit()
    else: print("Disaggregated existing capacity rows already exist, skipping disaggregation.")

    # Disaggregate LimitAnnualCapacityFactor
    cursor.execute(f"SELECT COUNT(*) FROM LimitAnnualCapacityFactor WHERE tech LIKE 'T_HDV_T_LH%'")
    if cursor.fetchone()[0] == 0:
        adj_fac = CFAF_disagg_factor['TonneKm']['prop'] / CFAF_disagg_factor['Shipments']['prop']
        adj_fac_inv = (1 - CFAF_disagg_factor['TonneKm']['prop']) / (1 - CFAF_disagg_factor['Shipments']['prop'])

        df = pd.read_sql_query("SELECT * FROM LimitAnnualCapacityFactor WHERE tech LIKE 'T_HDV_T%';", conn)
        # create new rows for T_HDV_T_LH and adjust values
        new_rows = []
        for _, row in df.iterrows():
            if row['tech'] in T_HDV_T_LH_mapping:
                if row['notes'] is None: row['notes'] = ''
                row['notes'] += " Ontario long-haul/short-haul split from Canadian Freight Analysis Framework 2017 data."
                for new_tech in T_HDV_T_LH_mapping[row['tech']]:
                    new_row = row.copy()
                    new_row['tech'] = new_tech
                    new_row['factor'] *= adj_fac
                    if new_row['tech'] == "T_HDV_T_LH_DSL": new_row['output_comm'] = "T_D_tkm_hdv_t_lh"
                    else: new_row['output_comm'] = "T_annual_tkm_hdv_t_lh"
                    new_rows.append(new_row)
                # adjust original row
                row['factor'] *= adj_fac_inv
                cursor.execute("""
                    UPDATE LimitAnnualCapacityFactor SET factor = ?, notes = ? WHERE tech = ? and vintage = ? and region = ? and operator = ?;
                """, (row['factor'], row['notes'], row['tech'], row['vintage'], row['region'], row['operator']))
        # write new rows to database
        if new_rows:
            df_new = pd.DataFrame(new_rows)
            df_new.to_sql('LimitAnnualCapacityFactor', conn, if_exists='append', index=False)
        conn.commit()
    else: print("Disaggregated annual capacity factor rows already exist, skipping disaggregation.")

conn.close()

# ON_16d_bevsplit_growthlim_newtech_b.sqlite

# %% [markdown]
# ### Upsert insertions database

# %%
# Upsert insertions database into target database
lihwei_db_edits.upsert_database(src_db='insertions_v3_1.sqlite', 
                                dest_db=target_db)
# Out:
# ...
# INSERT INTO CapacityToActivity (region, tech, c2a, notes, data_source, dq_cred, dq_geog, dq_struc, dq_tech, dq_time, data_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) ON CONFLICT(region, tech) DO UPDATE SET c2a=excluded.c2a, notes=excluded.notes, data_source=excluded.data_source, dq_cred=excluded.dq_cred, dq_geog=excluded.dq_geog, dq_struc=excluded.dq_struc, dq_tech=excluded.dq_tech, dq_time=excluded.dq_time, data_id=excluded.data_id; UPDATE SET c2a=excluded.c2a, notes=excluded.notes, data_source=excluded.data_source, dq_cred=excluded.dq_cred, dq_geog=excluded.dq_geog, dq_struc=excluded.dq_struc, dq_tech=excluded.dq_tech, dq_time=excluded.dq_time, data_id=excluded.data_id
# INSERT INTO Commodity (name, flag, description, data_id) VALUES (?, ?, ?, ?) ON CONFLICT(name) DO UPDATE SET flag=excluded.flag, description=excluded.description, data_id=excluded.data_id; UPDATE SET flag=excluded.flag, description=excluded.description, data_id=excluded.data_id
# ...

# %% [markdown]
# ### Troubleshooting
# - [FAILED] a: Remove techs LIKE I_H2_STOR_%, N_%, I_FT_RWGS
# - [PASSED] b: Remove techs LIKE I_H2_STOR_%, N_%, I_FT_RWGS. Removed LimitAnnualCapacityFactor, LimitActivityShare, LimitGrowthCapacity, LimitCapacity, LimitCapacityShare, LimitTechInputSplitAnnual, TechGroup, TechGroupMember, StorageDuration, EmissionActivity
# - [FAILED] b: Remove techs LIKE N_%, I_FT_RWGS. Removed LimitAnnualCapacityFactor, LimitActivityShare, LimitGrowthCapacity, LimitCapacityShare, LimitTechInputSplitAnnual, TechGroup, TechGroupMember, EmissionActivity
# - [PASSED] b: Remove techs LIKE I_H2_STOR_%. Removed LimitAnnualCapacityFactor, LimitActivityShare, LimitGrowthCapacity, LimitCapacity, LimitCapacityShare, LimitTechInputSplitAnnual, TechGroup, TechGroupMember, StorageDuration, EmissionActivity
# - [???] b: Only remove techs LIKE I_H2_STOR_%. Replace all tables
# - [FAILED] c: removed LimitActivityShare, LimitCapacity, LimitCapacityShare, LimitTechInputSplitAnnual
# - [FAILED] d: removed LimitActivityShare, LimitCapacity, LimitCapacityShare

# %%
# # remove techs LIKE 'I_H2_STOR_%', or 'N_%', or 'I_FT_%'
# # make a copy of target_db
# target_db_copy = target_db.replace('.sqlite', '_b.sqlite')
# shutil.copyfile(target_db, target_db_copy)
# with sqlite3.connect(target_db_copy) as conn:
#     cursor = conn.cursor()
#     for table in ['Technology', 'LifetimeTech', 'Efficiency', 'CapacityToActivity', 'LimitAnnualCapacityFactor', 'LimitTechInputSplitAnnual',
#                   'CostInvest', 'CostFixed', 'CostVariable', 'StorageDuration', 'EmissionActivity']:
#         print(f"Cleaning table {table}...")
#         cursor.execute(f"DELETE FROM {table} WHERE tech LIKE 'I_H2_STOR_%';")
#         # tech LIKE 'I_H2_STOR_%' OR 
#         # tech LIKE 'N_%' OR tech LIKE 'I_FT_%' or tech LIKE 'E_N_ELC'
#     for table in ['LimitGrowthCapacity', 'LimitCapacity']:
#         print(f"Cleaning table {table}...")
#         cursor.execute(f"DELETE FROM {table} WHERE tech_or_group LIKE 'I_H2_STOR_%';")
#         # tech_or_group LIKE 'I_H2_STOR_%' OR 
#         # tech_or_group LIKE 'N_%' OR tech_or_group LIKE 'I_FT_%'
#     #cursor.execute("DELETE FROM Commodity WHERE name LIKE 'N_elc' OR name LIKE 'N_co2';")
#     conn.commit()
# conn.close()

# %%
conn.close()

# %% [markdown]
# ### Apply payload capacity penalty
# This will modify tables: LimitAnnualCapacityFactor, Efficiency, CostVariable

# %%
# Read truck_specs
truck_specs = pd.read_csv('../../../Paper 3 - Charging profiles/input_data/truck_specs.csv')

# %%
# create df with all combinations of tech_veh and vintage_list
payload_capacity_penalty = pd.DataFrame({'vintage': list(range(2025, 2046, 5))})
payload_capacity_penalty = payload_capacity_penalty.merge(pd.DataFrame({'tech': truck_specs.tech_veh.unique()}), how='cross')

payload_capacity_penalty = (payload_capacity_penalty
                            .merge(truck_specs
                                   .query('Case=="Low"')
                                   [['tech_veh', 'Year', 'PayloadCapacityPenalty']]
                                   .assign(tech = lambda x: x['tech_veh'], 
                                           vintage = lambda x: x['Year']-5)
                                   .drop_duplicates(), how='left'))

# Interpolate missing values for each tech group by vintage
payload_capacity_penalty = payload_capacity_penalty.sort_values(['tech', 'vintage'])
payload_capacity_penalty['PayloadCapacityPenalty'] = (payload_capacity_penalty
                                                     .groupby('tech')['PayloadCapacityPenalty']
                                                     .apply(lambda group: group.interpolate(method='linear')).values)
payload_capacity_penalty = payload_capacity_penalty[['tech', 'vintage', 'PayloadCapacityPenalty']]

(payload_capacity_penalty
 .pivot(index='tech', columns='vintage', values='PayloadCapacityPenalty')
 .reset_index().style.hide())
# Out:
# <style type="text/css">
# </style>
# <table id="T_0b195">
#   <thead>
#     <tr>
#       <th id="T_0b195_level0_col0" class="col_heading level0 col0" >tech</th>
#       <th id="T_0b195_level0_col1" class="col_heading level0 col1" >2025</th>
#       <th id="T_0b195_level0_col2" class="col_heading level0 col2" >2030</th>
#       <th id="T_0b195_level0_col3" class="col_heading level0 col3" >2035</th>
#       <th id="T_0b195_level0_col4" class="col_heading level0 col4" >2040</th>
#       <th id="T_0b195_level0_col5" class="col_heading level0 col5" >2045</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0b195_row0_col0" class="data row0 col0" >T_HDV_T_LH_BEV_ERDS1</td>
#       <td id="T_0b195_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_0b195_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_0b195_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_0b195_row0_col4" class="data row0 col4" >1.000000</td>
# ...

# %%
target_db = 'ON_16d_bevsplit_growthlim_newtech.sqlite'

with sqlite3.connect(target_db) as conn:
    cursor = conn.cursor()

    notes_str = "Payload capacity penalty applied."
    add_notes_sql = f"notes = COALESCE(notes, '') || ' {notes_str}'"

    # Look if notes_str is in notes column
    cursor.execute(f"SELECT COUNT(*) FROM Efficiency WHERE notes LIKE ?;", (f"%{notes_str}%",))
    if cursor.fetchone()[0] > 0: print("Efficiency: Payload capacity penalty already applied, skipping updates.")
    else:
        # In Efficiency, match tech and divide efficiency by PayloadCapacityPenalty
        # concatenate notes column with "text"
        for _, row in payload_capacity_penalty.iterrows():
            cursor.execute(f"""UPDATE Efficiency SET efficiency = efficiency / ?, {add_notes_sql}
                        WHERE tech = ? AND region = 'ON' AND vintage = ?;
                        """, (row['PayloadCapacityPenalty'], row['tech'], row['vintage']))
        conn.commit()

    # Look if notes_str is in notes column
    cursor.execute(f"SELECT COUNT(*) FROM LimitAnnualCapacityFactor WHERE notes LIKE ?;", (f"%{notes_str}%",))
    if cursor.fetchone()[0] > 0: print("LimitAnnualCapacityFactor: Payload capacity penalty already applied, skipping updates.")
    else:
        # In LimitAnnualCapacityFactor, match tech and set factor = factor / PayloadCapacityPenalty
        for _, row in payload_capacity_penalty.iterrows():
            cursor.execute(f"""UPDATE LimitAnnualCapacityFactor SET factor = factor / ?, {add_notes_sql}
                        WHERE tech = ? AND region = 'ON' AND vintage = ?;
                        """, (row['PayloadCapacityPenalty'], row['tech'], row['vintage']))
        conn.commit()
    
    # Look if notes_str is in notes column
    cursor.execute(f"SELECT COUNT(*) FROM CostVariable WHERE notes LIKE ?;", (f"%{notes_str}%",))
    if cursor.fetchone()[0] > 0: print("CostVariable: Payload capacity penalty already applied, skipping updates.")
    else:
        # In CostVariable, match tech and set cost = cost * PayloadCapacityPenalty
        for _, row in payload_capacity_penalty.iterrows():
            cursor.execute(f"""UPDATE CostVariable SET cost = cost * ?, {add_notes_sql}
                        WHERE tech = ? AND region = 'ON' AND vintage = ?;
                        """, (row['PayloadCapacityPenalty'], row['tech'], row['vintage']))
        conn.commit()

# %% [markdown]
# # [skip] Update constraints
# Skip this for 2026 May

# %%
# import model_constraints.update_constraints
# importlib.reload(model_constraints.update_constraints)
# from model_constraints.update_constraints import update_constraints

# %%
# # To-do: Modify update_constraints to handle v3.1 database: convert GroupGrowthRateMax and GroupGrowthRateSeed tables
# # Add baseline constraints to database
# update_constraints(db_source_path='canoe_on_16d_newtech_v3_1.sqlite',
#                   db_target_path='canoe_on_16d_baseline_newtech_v3_1.sqlite',
#                   constraints_path='../model_constraints/trn_constraints_baseline.xlsx')

# '''
# update_constraints(db_source_path='canoe_on_16d.sqlite',
#                    db_target_path='canoe_on_16d_baseline.sqlite',
#                    constraints_path='../model_constraints/trn_constraints_baseline.xlsx')
# '''

# %% [markdown]
# ### [skip] Remove growth, new capacity constraints, time season sequential
# - Because of infeasibility: conflict between LimitNewCapacityShare and LimitGrowthCapacity especially for Freight / Pass Light-T
#
# Troubleshooting log for LimitNewCapacityShare:
# - All constraints, BarHomogeneous=1: Infeasible
# - Loosen constraints (99%), BarHomogeneous off: Infeasible
# - Keep LimitNewCapacityShare, Remove LimitGrowthCapacity, BarHomogeneous off: Works
# - Keep LimitNewCapacityShare, increase seed by 2x, Barhomogeneous off: Infeasible
# - Constrain Cars, Freight LT, Pass LT, BarHomogeneous off: Infeasible
# - Constrain Cars, Motorcycles, Heavy trucks, Medium trucks, BarHomogeneous off: Works
# - Keep LimitNewCapacityShare, remove LimitGrowthCapacity for Freight Light-T, Pass Light-T, BarHomogeneous off: Works **\[Selected\]**
#
# Skip this for 2026 May

# %%
# # Clear rows from LimitNewCapacityShare, LimitGrowthCapacity
# target_db = 'canoe_on_16d_baseline_newtech_v3_1.sqlite'
# with sqlite3.connect(target_db) as conn:
#     cursor = conn.cursor()
#     #cursor.execute("DELETE FROM LimitNewCapacityShare WHERE super_group NOT IN ('Cars', 'Motorcycles', 'Heavy trucks', 'Medium trucks');")
#     #cursor.execute("UPDATE LimitNewCapacityShare SET share = share*0.99 WHERE operator IS 'ge';")
    
#     #cursor.execute("UPDATE LimitGrowthCapacity SET seed = seed * 2 WHERE seed_units IS 'k units';")
#     cursor.execute("DELETE FROM LimitGrowthCapacity WHERE tech_or_group LIKE '%Light-T%';")

#     # time season sequential
#     #cursor.execute("DELETE FROM TimeSeasonSequential;")    
#     conn.commit()

# %% [markdown]
# ### Ensure discount rate / loan rate is set

# %%
# In MetaDataReal table, where element = 'global_discount_rate' or 'default_loan_rate', set value to 0.03
discount_rate = 0.03

#target_db = 'canoe_on_16d_baseline_newtech_v3_1.sqlite'
target_db = 'ON_16d_bevsplit_growthlim_newtech.sqlite'

with sqlite3.connect(target_db) as conn:
    cursor = conn.cursor()
    cursor.execute("UPDATE MetaDataReal SET value = ? WHERE element IN ('global_discount_rate', 'default_loan_rate');", (discount_rate,))
    conn.commit()

# %% [markdown]
# # Database edits to reduce matrix coefficient range
# These are necessary to prevent numerical instability and suboptimal termination

# %% [markdown]
# ### Scale units for eRoads and chargers
# - Instead of km eRoads, 1x charger, 1x H2 station, ...
# - Turn it into 1000 km of eRoads, 1000 chargers, 1000 H2 stations for long-haul HDTs only
# - For tech LIKE 'T_HDV_T_LH_CHRG_%' OR tech LIKE 'T_H2_HDV_T_LH_REFUEL'
# - Tables:
#     - CapacityToActivity: c2a x1000; notes [PJ/<1000 >{km|charger}]
#     - CostInvest: cost x1000; units M$/<1000 >{km|charger|station}
#     - CostFixed: cost x1000; units M$/<1000 >{km|charger|station}
#     - LimitCapacity: capacity div 1000; units <1000 >km

# %%
def scale_units(target_db, like_patterns, scale_factor, table_updates, print_messages=False):
    """
    Scale numeric values and update text columns in specified tables for technologies matching LIKE patterns.
    table_updates: dict with table names as keys and dicts with keys 'set', 'where_col', 'regex', 'repl', 'text_col' as values.
    """
    # Ensure like_patterns is a tuple/list
    if isinstance(like_patterns, str):
        like_patterns = (like_patterns,)
    elif not isinstance(like_patterns, (tuple, list)):
        like_patterns = tuple(like_patterns)
        
    with sqlite3.connect(target_db) as conn:
        cursor = conn.cursor()
        for table, cfg in table_updates.items():
            where_col = cfg['where_col']    #'tech' if table != 'LimitCapacity' else 'tech_or_group'
            # Build WHERE clause for variable number of patterns
            where_clause = " OR ".join([f"{where_col} LIKE ?" for _ in like_patterns])
            # Scale values
            sql = f"UPDATE {table} SET {cfg['set']} WHERE {where_clause}"
            if print_messages:
                print('sql', sql, (scale_factor, *like_patterns))
            cursor.execute(sql, (scale_factor, *like_patterns))
            # Update notes/units column if applicable
            if cfg['text_col']:
                select_sql = f"SELECT rowid, {cfg['text_col']} FROM {table} WHERE {where_clause}"
                if print_messages:
                    print('select_sql', select_sql)
                rows = cursor.execute(select_sql, like_patterns).fetchall()
                for rowid, val in rows:
                    new_val = re.sub(cfg['regex'], cfg['repl'], val) if val else val
                    cursor.execute(f"UPDATE {table} SET {cfg['text_col']} = ? WHERE rowid = ?", (new_val, rowid))
        conn.commit()
    print(f"Scaled units in {target_db} for patterns {like_patterns} by factor {scale_factor}.")

def check_scaling_required(target_db, sql_query):
    """
    Checks if scaling is required by running a user-provided SQL query.
    Returns True if any rows are found, else False. Prints the result.
    """
    with sqlite3.connect(target_db) as conn:
        df = pd.read_sql_query(sql_query, conn)
        if df.empty:
            print("No rows found; no scaling needed.")
            return False
        else:
            print("Rows found; scaling needed. Sample rows:")
            print(df.head())
            return True

# %%
#target_db = 'canoe_on_16d_baseline_newtech_v3_1.sqlite'
target_db = 'ON_16d_bevsplit_growthlim_newtech.sqlite'

like_patterns = ('T_HDV_T_LH_CHRG_%', 'T_H2_HDV_T_LH_REFUEL')
scale_factor = 1000

table_updates = {
    'CapacityToActivity': {'set': 'c2a = c2a * ?', 'where_col':'tech', 'text_col': 'notes', 'regex': r'\[PJ/(km|charger|H2 station)', 'repl': rf"[PJ/{scale_factor} \1"},
    'CostInvest': {'set': 'cost = cost * ?', 'where_col':'tech', 'text_col': 'units', 'regex': r'M\$/(km|charger|station)', 'repl': rf'M$/{scale_factor} \1'},
    'CostFixed': {'set': 'cost = cost * ?', 'where_col':'tech', 'text_col': 'units', 'regex': r'M\$/(km|charger|station)', 'repl': rf'M$/{scale_factor} \1'},
    'LimitCapacity': {'set': 'capacity = capacity / ?', 'where_col':'tech_or_group', 'text_col': 'units', 'regex': r'\bkm\b', 'repl': rf'{scale_factor} km'}
}

# Check if c2a values are <0.1 and require scaling
if check_scaling_required(target_db, "SELECT * FROM CapacityToActivity WHERE c2a < 0.1 AND tech LIKE '%_HDV_T_LH_%'"):
    scale_units(target_db, like_patterns, scale_factor, table_updates)
# Out:
# Rows found; scaling needed. Sample rows:
#   region                   tech       c2a  \
# 0     ON   T_H2_HDV_T_LH_REFUEL  0.056940
# 1     ON  T_HDV_T_LH_CHRG_ERDS1  0.079789
# 2     ON  T_HDV_T_LH_CHRG_ERDS2  0.079789
# 3     ON  T_HDV_T_LH_CHRG_ERDS3  0.079789
# 4     ON  T_HDV_T_LH_CHRG_ERDS4  0.079789
#
#                                                notes data_source dq_cred  \
# 0  [PJ/H2 station] total PJ of electricity/H2 a c...        None    None
# 1  [PJ/km of eRoads] max theoretical AADTT*365*(k...        None    None
# 2  [PJ/km of eRoads] max theoretical AADTT*365*(k...        None    None
# 3  [PJ/km of eRoads] max theoretical AADTT*365*(k...        None    None
# 4  [PJ/km of eRoads] max theoretical AADTT*365*(k...        None    None
#
#   dq_geog dq_struc dq_tech dq_time data_id
# 0    None     None    None    None    None
# 1    None     None    None    None    None
# 2    None     None    None    None    None
# 3    None     None    None    None    None
# ...

# %% [markdown]
# ### [skip] Scale units for R_D_app demand commodity, R_APP technology
# Skip this for 2026 May
#
# - scale commodities LIKE 'R_D_app%' divide by 1000 (units 1000 kunity) so that efficiency (originally kunity/PJ) is lower in magnitude by 1000x
# - Instead of kunity, turn it into 1000 kunity
# - Demand: commodity LIKE 'R_D_app%' divide by 1000, update units
# - Efficiency: output_comm LIKE 'R_D_app%' divide by 1000, update units
# - For tech like 'R_APP_%', scale ExistingCapacity by 1000, update units

# %%
# target_db = 'canoe_on_16d_baseline_newtech_v3_1.sqlite'

# like_patterns = ('R_D_app_%', 'R_APP_%')
# scale_factor = 1000

# table_updates = {
#     'Demand': {'set': 'demand = demand / ?', 'where_col': 'commodity', 'text_col': 'units', 'regex': r'\(kunity\)', 'repl': rf"({scale_factor} kunity)"},
#     'Efficiency': {'set': 'efficiency = efficiency / ?', 'where_col': 'output_comm', 'text_col': 'notes', 'regex': r'\(kunity/PJ\)', 'repl': rf'({scale_factor} kunity/PJ)'},
#     'ExistingCapacity': {'set': 'capacity = capacity / ?', 'where_col': 'tech', 'text_col': 'units', 'regex': r'\(kunit\)', 'repl': rf'({scale_factor} kunit)'}
# }

# # Check if Efficiency values are >10 and require scaling
# if check_scaling_required(target_db, "SELECT * FROM Efficiency WHERE efficiency > 10 AND output_comm LIKE 'R_D_app_%'"):
#     scale_units(target_db, like_patterns, scale_factor, table_updates)

# %% [markdown]
# ### [skip] DemandSpecificDistribution cut-off
# Skip this for 2026 May
#
# - DSD: Groupby [region, period, demand_name], cut off at 1e-3 replace with zero, redistribute to other season-tod to maintain sum=1 for each group

# %%
# target_db = 'canoe_on_16d_baseline_newtech_v3_1.sqlite'
# dsd_cutoff = 1e-3

# with sqlite3.connect(target_db) as conn:
#     df = pd.read_sql_query("SELECT * FROM DemandSpecificDistribution", conn)

#     # Clip values below cutoff
#     df.loc[df['dsd'] < dsd_cutoff, 'dsd'] = 0
#     # Rescale so sum=1 for each group
#     sums = df.groupby(['region', 'period', 'demand_name'])['dsd'].transform('sum')
#     df['dsd'] = df['dsd'] / sums.where(sums > 0, 1)
#     # Overwrite table
#     conn.execute("DELETE FROM DemandSpecificDistribution")
#     df.to_sql('DemandSpecificDistribution', conn, if_exists='append', index=False)
#     print(f"Edited DemandSpecificDistribution in {target_db} with cutoff={dsd_cutoff}")

# %% [markdown]
# ### [skip] CapacityFactorProcess cut-off
# Skip this for 2026 May
#
# - For tech LIKE 'E_SOL_%' or 'E_WND_%'
# - Cut-off at 1e-3, no need to redistribute

# %%
# target_db = 'canoe_on_16d_baseline_newtech_v3_1.sqlite'
# capfacprocess_cutoff = 1e-3

# with sqlite3.connect(target_db) as conn:
#     conn.execute("UPDATE CapacityFactorProcess SET factor = 0 WHERE factor < ? AND (tech LIKE 'E_SOL_%' OR tech LIKE 'E_WND_%')", (capfacprocess_cutoff,))
#     conn.commit()
# print(f"Edited CapacityFactorProcess in {target_db} with cutoff={capfacprocess_cutoff}")

# %% [markdown]
# # Database edits for 2026 May

# %% [markdown]
# ### Remove existing H2 transportation import technologies, remove H2 SMR and SMR + CCS

# %%
# Remove technologies F_T_H2, F_IMP_H2, I_H2_SMR, I_H2_SMR_CCS
# Tables: Technology, Efficiency, CostVariable, CostInvest, CostFixed, LifetimeTech, CapacityToActivity, LimitAnnualCapacityFactor, LimitTechInputSplitAnnual, EmissionActivity

target_db = 'ON_16d_bevsplit_growthlim_newtech.sqlite'

with sqlite3.connect(target_db) as conn:
    for table in ['Technology', 'Efficiency', 'CostVariable', 'CostInvest', 'CostFixed', 'LifetimeTech', 'CapacityToActivity', 'LimitAnnualCapacityFactor', 'LimitTechInputSplitAnnual', 'EmissionActivity']:
        conn.execute(f"DELETE FROM {table} WHERE tech IN ('F_T_H2', 'F_IMP_H2', 'I_H2_SMR', 'I_H2_SMR_CCS');")
    # Remove F_h2 from Commodity table
    conn.execute("DELETE FROM Commodity WHERE name = 'F_h2';")
    conn.commit()

# %% [markdown]
# ### [skip] Adjust periods and vintages with new periods
# Already fixed in insertions

# %%
# # Tables: Demand, Efficiency, CostInvest, CostFixed, CostVariable, CostEmission, LimitAnnualCapacityFactor, LimitActivityShare, LimitCapacity,LimitCapacityShare, LimitTechInputSplitAnnual
# # where period or vintage is 2021 or 2050

# target_db = 'canoe_dataset_ON_16d_bevsplit_growthlim.sqlite'

# with sqlite3.connect(target_db) as conn:
#     for table in ['Demand', 'Efficiency', 'CostInvest', 'CostFixed', 'CostVariable', 'CostEmission', 
#                   'LimitAnnualCapacityFactor', 'LimitActivityShare', 'LimitCapacity', 'LimitCapacityShare', 'LimitTechInputSplitAnnual']:
#         # check if table contains 'period' and/or 'vintage' column
#         cursor = conn.execute(f"PRAGMA table_info({table})")
#         columns = [row[1] for row in cursor.fetchall()]
#         if 'period' in columns and 'vintage' in columns: conn.execute(f"DELETE FROM {table} WHERE period IN (2021, 2050) OR vintage IN (2021, 2050)")
#         elif 'period' in columns: conn.execute(f"DELETE FROM {table} WHERE period IN (2021, 2050)")
#         elif 'vintage' in columns: conn.execute(f"DELETE FROM {table} WHERE vintage IN (2021, 2050)")
#     conn.commit()

# %% [markdown]
# ### Electricity sector edits for Ontario
# - Set existing CANDU nuclear lifetime to 100 years (lasts forever) in line with IESO and CER projections
# - Extend CostFixed and CostVariable for E_NUC_CANDU-EXS for all vintages, for all periods
# - In ExistingCapacity, increase total E_NUC_CANDU-EXS to 12.2 GW, raise total E_HYD_DLY-EXS and E_HYD_ROR-EXS to 8.9 GW, to match IESO year in review 2024.

# %%
target_db = 'ON_16d_bevsplit_growthlim_newtech.sqlite'

with sqlite3.connect(target_db) as conn:
    conn.execute("UPDATE LifetimeTech SET lifetime = 100, notes = 'Assuming 100-year lifetime, no retirement' WHERE tech = 'E_NUC_CANDU-EXS'")
    
    # Extend CostFixed and CostVariable for E_NUC_CANDU-EXS to period 2045
    for table in ['CostFixed', 'CostVariable']:
        df = pd.read_sql_query(f"SELECT * FROM {table} WHERE tech = 'E_NUC_CANDU-EXS'", conn)
        periods = df['period'].unique()
        vintages = df['vintage'].unique()
        # cross existing_periods with existing_vintages
        df_cross = pd.MultiIndex.from_product([periods, vintages], names=['period', 'vintage']).to_frame(index=False)
        df_cross = df_cross.query('period >= vintage')
        df_filled = (df_cross.merge(df, on=['period', 'vintage'], how='left')
                     .groupby('vintage')[['region', 'period', 'vintage', 'tech', 'cost', 'units', 'notes',]].apply(lambda x: x.ffill().bfill())
                     .reset_index(drop=True))
        # remove rows in table
        conn.execute(f"DELETE FROM {table} WHERE tech = 'E_NUC_CANDU-EXS'")
        df_filled.to_sql(table, conn, if_exists='append', index=False)
    conn.commit()  
    
    # In ExistingCapacity, calculate total E_NUC_CANDU-EXS, calculate total for tech like E_HYD_% 
    # Increase all values by the same factor to reach 12.2 GW total E_NUC_CANDU-EXS, 8.9 GW total for E_HYD_%
    
    total_nuclear = conn.execute("SELECT SUM(capacity) FROM ExistingCapacity WHERE tech = 'E_NUC_CANDU-EXS'").fetchone()[0]
    total_hydro = conn.execute("SELECT SUM(capacity) FROM ExistingCapacity WHERE tech LIKE 'E_HYD_%'").fetchone()[0]
    if total_nuclear > 0:
        conn.execute("UPDATE ExistingCapacity SET capacity = capacity * ? WHERE tech = 'E_NUC_CANDU-EXS'", (12.2 / total_nuclear,))
    if total_hydro > 0:
        conn.execute("UPDATE ExistingCapacity SET capacity = capacity * ? WHERE tech LIKE 'E_HYD_%'", (8.9 / total_hydro,))
    conn.commit()

# ON_16d_bevsplit_growthlim_newtech_elc_ontario.sqlite

# %% [markdown]
# # Create profiles for CapacityFactorTech
# adjust_average_capacity_factor() adjusts profiles to match avg_capacity_factor

# %%
def adjust_average_capacity_factor(hourly_profile, avg_capacity_factor=None, threshold=0.0001, max_iter=40, 
                                   cutoff_lower = 0.001):
    """
    Iteratively adjusts an hourly profile (ranges from 0 to 1) such that the mean matches avg_capacity_factor.
    Stops when the mean is within a specified threshold of avg_capacity_factor, or when max_iter is reached.
    If avg_capacity_factor is None or np.nan, returns the original profile.

    Parameters:
    hourly_profile: np.array or pd.Series representing the hourly profile (values between 0 and 1). Can be a nested array.
    avg_capacity_factor: Desired average capacity factor (float). If a list or single dimensional array, it will be applied to each nested array in hourly_profile. len(avg_capacity_factor) must match number of nested arrays in hourly_profile.
    cutoff_lower: Lower cutoff for capacity factor values. Values below this will be set to 0.

    If hourly_profile is a 1D array, and avg_capacity_factor is a single value, returns a 1D array of adjusted profiles.
    """
    if avg_capacity_factor is None: return hourly_profile

    # If hourly_profile is 1D array, convert to 2D for uniform processing
    if isinstance(hourly_profile, (np.ndarray, pd.Series)) and hourly_profile.ndim == 1: hourly_profile = hourly_profile.reshape(1, -1)
    # If avg_capacity_factor is a single value, convert to list for uniform processing
    if isinstance(avg_capacity_factor, (float, int)): avg_capacity_factor = np.array([avg_capacity_factor])
    
    # Ensure hourly_profile and avg_capacity_factor have compatible shapes
    if hourly_profile.shape[0] != len(avg_capacity_factor):
        raise ValueError("Length of avg_capacity_factor must match number of nested arrays in hourly_profile.")
    
    if np.any(avg_capacity_factor <= cutoff_lower):
        print(f'Warning: Some average capacity factors are <= cutoff_lower {cutoff_lower}, returning profile with all zeroes for those cases.')
        hourly_profile = np.where(avg_capacity_factor[:, None] <= cutoff_lower, 0, hourly_profile)

    # For each nested array, adjust the profile iteratively. If hourly_profile is all zeroes, leave it as all zeroes. If hourly_profile is 1D, this loop runs once.
    def _adjust_single_profile(profile, target_avg, threshold, max_iter, cutoff_lower):
        for i in range(max_iter):
            scaling_factor = target_avg / (profile.mean())
            if abs(scaling_factor - 1) <= threshold:
                return profile
            profile = np.clip(profile * scaling_factor, a_min=0, a_max=1)
            profile[profile < cutoff_lower] = 0
        print(f'Reached iteration limit. Final mean: {profile.mean()}, target: {target_avg}')
        return profile
    
    adjusted_profiles = []
    for i in range(hourly_profile.shape[0]):
        profile = hourly_profile[i]
        target_avg = avg_capacity_factor[i]
        if np.all(profile == 0):
            adjusted_profiles.append(profile)
            continue
        adjusted_profile = _adjust_single_profile(profile, target_avg, threshold, max_iter, cutoff_lower)
        adjusted_profiles.append(adjusted_profile)
    
    adjusted_profiles = np.array(adjusted_profiles)
    return adjusted_profiles.squeeze()  # remove single-dimensional entries

# %%
# write a test case for adjust_average_capacity_factor(). Generate 5 sinusoidal profiles (each of length 10) with random noise, and adjust them to target five random average capacity factors.

# First, create a sinusoidal profile with noise
def generate_sinusoidal_profile(length=10, noise_level=0.1):
    x = np.linspace(0, 2 * np.pi, length)
    profile = (np.sin(x - np.pi/2) + 1) / 2  # Normalize to [0, 1]
    noise = np.random.normal(0, noise_level, length)
    profile += noise
    profile = np.clip(profile, 0, 1)  # Ensure values are within [0, 1]
    return profile

# Generate n profiles and n random target average capacity factors between 0.2 and 0.8
n = 3
profiles = np.array([generate_sinusoidal_profile(length=10, noise_level=0.1) for _ in range(n)])
target_avg_cap_factors = np.random.uniform(0.2, 0.8, size=n)

print(profiles)
print(target_avg_cap_factors)

# Test adjust_average_capacity_factor()
adjusted_profiles = adjust_average_capacity_factor(profiles, target_avg_cap_factors, threshold=0.0001, max_iter=50, cutoff_lower=0.01)

print('adjusted_profiles:', adjusted_profiles)

# Plot profiles and target averages
import matplotlib.pyplot as plt

# Plot adjusted profiles and target averages next to each other as subplots
plt.figure(figsize=(12, 8))
for i in range(n):
    plt.subplot(2, 5, i+1)
    plt.plot(profiles[i], label=f'Adjusted Profile {i+1} (mean: {profiles[i].mean():.2f})')
    plt.hlines(target_avg_cap_factors[i], 0, 9, colors='r', linestyles='dashed', label=f'Target avg {i+1}: {target_avg_cap_factors[i]:.2f}')
    plt.ylim(0, 1.2)
    plt.title(f'Profile {i+1}')

# Plot adjusted profiles and target averages next to each other as subplots
plt.figure(figsize=(12, 8))
for i in range(n):
    plt.subplot(2, 5, i+1)
    plt.plot(adjusted_profiles[i], label=f'Adjusted Profile {i+1} (mean: {adjusted_profiles[i].mean():.2f})')
    plt.hlines(target_avg_cap_factors[i], 0, 9, colors='r', linestyles='dashed', label=f'Target avg {i+1}: {target_avg_cap_factors[i]:.2f}')
    plt.ylim(0, 1.2)
    plt.title(f'Profile {i+1}')
# Out:
# [[0.         0.05592928 0.54637722 0.83412113 1.         0.86913935
#   0.82618823 0.46919814 0.14649785 0.        ]
#  [0.03560071 0.12265491 0.51240554 0.78652502 1.         0.89071883
#   0.66952876 0.30329763 0.08771728 0.14362167]
#  [0.         0.22972928 0.26832713 0.77186318 0.88883146 0.91323769
#   0.66989875 0.38397015 0.17117464 0.        ]]
# [0.65401083 0.5321517  0.25096927]
# Reached iteration limit. Final mean: 0.6536458359204864, target: 0.6540108314231733
# adjusted_profiles: [[0.         0.1482199  1.         1.         1.         1.
#   1.         1.         0.38823846 0.        ]
#  [0.04442851 0.15306929 0.63946526 0.98155736 1.         1.
#   0.83554987 0.37850547 0.10946828 0.17923512]
#  [0.         0.13417398 0.15671715 0.45080867 0.51912429 0.53337881
#   0.39125608 0.22425875 0.09997499 0.        ]]

# %%
def add_capacity_factor_meta_and_adjust(df, cf_note, region='ON',
                                        seasonal_capacity_factor_df=None, 
                                        grouping_cols=['period', 'season', 'tech']):
    """
    Adds metadata columns to the capacity factor dataframe and adjusts the hourly profiles
    df should have columns: period, season, tod, tech, factor, avg_capacity_factor
    cf_note: string to add to notes column
    seasonal_capacity_factor_df: optional dataframe with columns season, factor
    grouping_cols: list of columns to group by when adjusting profiles
    """
    if seasonal_capacity_factor_df is None:
        # Set seasonal capaciy factor to 1 throughout
        seasonal_capacity_factor_df = pd.DataFrame({
            'season': df['season'].unique(),
            'factor': [1.0] * len(df['season'].unique())})
    
    # Keep only relevant columns
    seasonal_capacity_factor_df = seasonal_capacity_factor_df[['season', 'factor']]

    # Check if all seasons in df are present in seasonal_capacity_factor_df
    missing_seasons = set(df['season'].unique()) - set(seasonal_capacity_factor_df['season'].unique())
    if missing_seasons: raise ValueError(f"The following seasons are missing in seasonal_capacity_factor_df: {missing_seasons}")
    
    # Helper function to apply adjustment per group in grouped df
    def adjust_group(group, profile_col='factor', avg_col='avg_capacity_factor'):
        adjusted = adjust_average_capacity_factor(
            group[profile_col].values, 
            group[avg_col].iloc[0]
        )
        return pd.Series(adjusted, index=group.index)
    
    # First, adjust seasonal capacity factor to match avg_capacity_factor
    seasonal_capacity_factor_df = (df[grouping_cols + ['avg_capacity_factor']].drop_duplicates()
                                   .merge(seasonal_capacity_factor_df.rename(columns={'factor':'seasonal_factor'}), how='left'))
    
    seasonal_capacity_factor_df['seasonal_factor'] = (seasonal_capacity_factor_df
                                                      .groupby(['period', 'tech'], group_keys=False)
                                                      .apply(adjust_group, profile_col='seasonal_factor', avg_col='avg_capacity_factor',
                                                             include_groups=False)
    )
    # Merge back to main df
    df = df.merge(seasonal_capacity_factor_df[grouping_cols + ['seasonal_factor']], 
                  on=grouping_cols, how='left')

    df['notes'] = cf_note
    df['region'] = region

    # Adjust hourly profile to match seasonal_factor per 'period', 'season', 'tech'    
    df['factor'] = (df.groupby(grouping_cols, group_keys=False)
                    .apply(adjust_group, profile_col='factor', avg_col='seasonal_factor', include_groups=False))
    
    return df #[['region', 'period', 'season', 'tod', 'tech', 'factor', 'notes']]

# %%
def create_CapacityFactorTech_single_day(profile_name, input_data_dict, season_list, period_list, seasonal_capacity_factor_df=None, avg_capacity_factor_df=None):
    """
    Create a DataFrame with technology-specific capacity factors for each season.
    Only for a single day profile which is repeated across all seasons in season_list and periods in period_list.
    Returns a DataFrame to be inserted into CapacityFactorTech.

    seasonal_capacity_factor_df: input to add_capacity_factor_meta_and_adjust
    avg_capacity_factor_df: optional DataFrame with columns 'tech', 'avg_capacity_factor' to override the avg_capacity_factor from input_data_dict['truck_specs']
    """
    hourly_profile = input_data_dict['sample_profiles'].set_index('tod')[profile_name]
    hourly_profile.name = 'factor'

    if avg_capacity_factor_df is None:
        print('Using avg_capacity_factor from truck_specs')
        avg_capacity_factor_df = input_data_dict['truck_specs'][['tech_supply', 'avg_capacity_factor']].rename(columns={'tech_supply': 'tech'})

    df = (hourly_profile.reset_index()
        .merge(pd.DataFrame({'season': season_list}), how='cross')
        .merge(pd.DataFrame({'period': period_list}), how='cross')
        .merge(avg_capacity_factor_df, how='cross')
        )
    
    df = add_capacity_factor_meta_and_adjust(df, cf_note=profile_name, region='ON', seasonal_capacity_factor_df=seasonal_capacity_factor_df)
    
    # Adjust the capacity factor to match the average capacity factor for each technology
    #df['factor'] = df.groupby(['tech'])[['factor', 'avg_capacity_factor']].apply(
    #    lambda x: adjust_average_capacity_factor(x['factor'], x['avg_capacity_factor'].iloc[0])
    #    ).reset_index(level=0, drop=True)
    
    return df

# %%
#target_db = 'canoe_on_16d_baseline_newtech_v3_1.sqlite'
target_db = 'ON_16d_bevsplit_growthlim_newtech.sqlite'

# get list of seasons from sqlite database
with sqlite3.connect(target_db) as conn:
    season_list = pd.read_sql_query(f"SELECT DISTINCT season FROM TimeSeason", conn)['season'].tolist()

# 365d season list
#season_list = ['D{:03d}'.format(i) for i in range(1, 366)]

print('seasons:', season_list)

# get list of periods in CapacityFactorTech from sqlite database
with sqlite3.connect(target_db) as conn:
    period_list = pd.read_sql_query(f"SELECT DISTINCT period FROM CapacityFactorTech", conn)['period'].tolist()

print('periods:', period_list)
# Out:
# seasons: ['D025', 'D064', 'D081', 'D087', 'D097', 'D154', 'D169', 'D213', 'D223', 'D244', 'D255', 'D314', 'D335', 'D339', 'D346', 'D363']
# periods: [2025, 2030, 2035, 2040, 2045]

# %% [markdown]
# ### Load index of daily freight activity
# - Use aggregated daily VKT
# - For now, use classif = "longhaul"

# %%
daily_activity_csv = '../../../Paper 3 - Charging profiles/ATRI_Data/daily_vkt_summary/Tolerance_4/aggregated_daily_vkt_summary.csv'

daily_activity_df = pd.read_csv(daily_activity_csv)

# For now, use only classif = "longhaul". Only keep season and total_vkt columns 
daily_activity_df = (daily_activity_df.query('classif=="longhaul"')[['season', 'total_vkt']]
                     # Filter to season_list
                     .query('season.isin(@season_list)')
                     )

# Normalize total_vkt to [0,1] range, divide by maximum total_vkt
daily_activity_df['factor'] = daily_activity_df['total_vkt'] / daily_activity_df['total_vkt'].max()

daily_activity_df.plot(x='season', y='factor', kind='bar', figsize=(8,2), legend=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 15
#      12 daily_activity_df['factor'] = daily_activity_df['total_vkt'] / daily_activity_df['total_vkt'].max()
#      14 daily_activity_df.plot(x='season', y='factor', kind='bar', figsize=(8,2), legend=False)
# ---> 15 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### Load capacity factor profiles for long-haul HDT techs
# - From "Paper 3 - Charging profiles/ATRI_Data/Profiles/Tolerance_4"
# - "2019-eroads_dist_km_normalized_canoe.csv" and "2019-charging_kw_normalized_canoe.csv"
# - Adjust capacity factors to match annual average capacity factor
# - Filter to selected seasons after time series aggregation
# - Insert into CapacityFactorTech

# %%
tolerance = 99
base_dir = f'../../../Paper 3 - Charging profiles/ATRI_Data/Profiles/Tolerance_{tolerance}'
output_filename = 2019
charge_strat_list = ['minimum', 'immediate', 'delayed']
#db_id_list = ['wrn', 'iyw', 'jmo']
db_id_list = ['aum', 'xlv', 'bxl']

atri_profiles_dict_list = [{'charge_strat': charge_strat, 'db_id': db_id} for charge_strat, db_id in zip(charge_strat_list, db_id_list)]

for profile_dict in atri_profiles_dict_list:
    print(base_dir + f"/profilestats-{output_filename}-{profile_dict['charge_strat']}.csv")

    profile_dict['eroads_csv'] = os.path.join(base_dir, '2019-eroads_dist_km_normalized_canoe.csv')
    profile_dict['charging_csv'] = os.path.join(base_dir, f"profile-{output_filename}-{profile_dict['charge_strat']}-normalized-canoe.csv")

    profile_dict['charging_stats_df'] = pd.read_csv(os.path.join(base_dir, f"profilestats-{output_filename}-{profile_dict['charge_strat']}.csv"))    # This contains prop_midshift, prop_delay
# Out:
# ../../../Paper 3 - Charging profiles/ATRI_Data/Profiles/Tolerance_99/profilestats-2019-minimum.csv
# ../../../Paper 3 - Charging profiles/ATRI_Data/Profiles/Tolerance_99/profilestats-2019-immediate.csv
# ../../../Paper 3 - Charging profiles/ATRI_Data/Profiles/Tolerance_99/profilestats-2019-delayed.csv

# %%
# Get prop_midshift and prop_delay for BEVs under 'minimum' charge strategy
for profile_dict in atri_profiles_dict_list:
    if profile_dict['charge_strat'] == 'minimum':
        BEV_charging_stats_df = (profile_dict['charging_stats_df']
            .query('tech_veh.str.contains("BEV")')    # only keep BEVs, exclude FCEV
            # Take the average across unique tech_veh and tech_supply
            .groupby(['tech_veh', 'tech_supply'])[['prop_midshift', 'prop_delay']].mean()
            .reset_index())

        display(BEV_charging_stats_df)
# Out:
#                    tech_veh              tech_supply  prop_midshift  \
# 0  T_HDV_T_LH_BEV_FSTCHRG_N  T_HDV_T_LH_CHRG_FSTCHRG       0.443177
# 1  T_HDV_T_LH_BEV_LRGBATT_N  T_HDV_T_LH_CHRG_LRGBATT       0.212087
#
#    prop_delay
# 0    0.008500
# 1    0.059634

# %%
# Adjust avg_capacity_factor for fast-charging based on prop_midshift from BEV charging stats

# Merge avg_capacity_factor from truck_specs
avg_capacity_factor_df = (truck_specs[['tech_supply', 'avg_capacity_factor']]
            .drop_duplicates()
            .rename(columns={'tech_supply': 'tech'}))

# Get values
temp1 = avg_capacity_factor_df.set_index('tech').to_dict(orient='index')
avg_fstchrg = temp1['T_HDV_T_LH_CHRG_FSTCHRG']['avg_capacity_factor']
avg_lrgbatt = temp1['T_HDV_T_LH_CHRG_LRGBATT']['avg_capacity_factor']
temp2 = BEV_charging_stats_df.set_index('tech_supply').to_dict(orient='index')

# Calculate new average capacity factors based on prop_midshift
for tech in ['T_HDV_T_LH_CHRG_FSTCHRG']:
    temp1[tech]['avg_capacity_factor'] = ((avg_fstchrg * temp2[tech]['prop_midshift']) + avg_lrgbatt * (1 - temp2[tech]['prop_midshift']))

# convert back to avg_capacity_factor_df
avg_capacity_factor_df = pd.DataFrame(temp1).T.reset_index().rename(columns={'index':'tech'})

# %%
# Load ATRI profiles
# Merge avg_capacity_factor from truck_specs
# Filter to selected seasons after time series aggregation
# Adjust so that profile average equals avg_capacity_factor

def load_atri_profile(csv_path, note):
    df = pd.read_csv(csv_path)
    df['cf_tech_notes'] = note
    df['region'] = 'ON'
    return df

for profile_dict in atri_profiles_dict_list:
    print(profile_dict['charge_strat'])

    # Load both profile sets
    # columns in eroads_csv and charging_csv: ['tech', 'factor', 'season', 'tod']
    atri_eroads = pd.read_csv(profile_dict['eroads_csv'])
    atri_charging = pd.read_csv(profile_dict['charging_csv'])

    # Keep only techs present in truck_specs
    valid_techs = set(truck_specs['tech_supply'].unique())
    atri_eroads = atri_eroads[atri_eroads['tech'].isin(valid_techs)].copy()
    atri_charging = atri_charging[atri_charging['tech'].isin(valid_techs)].copy()

    atri_eroads = atri_eroads.merge(avg_capacity_factor_df, on='tech', how='left')
    atri_charging = atri_charging.merge(avg_capacity_factor_df, on='tech', how='left')

    # Filter to selected seasons from time series aggregation
    atri_eroads = atri_eroads.query('season.isin(@season_list)')
    atri_charging = atri_charging.query('season.isin(@season_list)')

    print('season_list:', season_list, '\nselected seasons:', atri_eroads.season.unique())

    # Duplicate dataframe for each period in period_list
    atri_eroads = atri_eroads.merge(pd.DataFrame({'period': period_list}), how='cross')
    atri_charging = atri_charging.merge(pd.DataFrame({'period': period_list}), how='cross')

    profiles_atri = pd.concat([
        add_capacity_factor_meta_and_adjust(atri_eroads, 
                                            f'ATRI GPS, eRoads, 2019, tolerance={tolerance}, charg_strat={profile_dict["charge_strat"]}', 
                                            seasonal_capacity_factor_df=daily_activity_df),
        add_capacity_factor_meta_and_adjust(atri_charging, 
                                            f'ATRI GPS, charging/refueling, 2019, tolerance={tolerance}, charg_strat={profile_dict["charge_strat"]}', 
                                            seasonal_capacity_factor_df=daily_activity_df)
    ], ignore_index=True)

    # Sanity checks
    # Mean factor per tech matches avg_capacity_factor (within tolerance)
    print('Check that mean factor per tech matches avg_capacity_factor:')
    display(profiles_atri.groupby('tech').factor.mean().reset_index()
    .merge(avg_capacity_factor_df, on='tech', how='left')
    .merge(truck_specs[['tech_supply', 'avg_capacity_factor']].drop_duplicates(), left_on='tech', right_on='tech_supply', how='left', suffixes=('', '_original'))    
    .drop(columns=['tech_supply']).round(3)
    )

    # Each tech should have 24*365 = 8760 entries
    #display(profiles_atri.groupby(['tech']).factor.count())

    # Save profiles_atri to profile_dict
    profile_dict['profiles_df'] = profiles_atri
# Out:
# minimum
# season_list: ['D025', 'D064', 'D081', 'D087', 'D097', 'D154', 'D169', 'D213', 'D223', 'D244', 'D255', 'D314', 'D335', 'D339', 'D346', 'D363']
# selected seasons: ['D025' 'D064' 'D081' 'D087' 'D097' 'D154' 'D169' 'D213' 'D223' 'D244'
#  'D255' 'D314' 'D335' 'D339' 'D346' 'D363']
# ...
# Check that mean factor per tech matches avg_capacity_factor:
#                       tech  factor  avg_capacity_factor  \
# 0     T_H2_HDV_T_LH_REFUEL   0.500                0.500
# 1    T_HDV_T_LH_CHRG_ERDS1   0.377                0.377
# 2    T_HDV_T_LH_CHRG_ERDS2   0.140                0.140
# 3    T_HDV_T_LH_CHRG_ERDS3   0.037                0.037
# 4    T_HDV_T_LH_CHRG_ERDS4   0.014                0.014
# 5    T_HDV_T_LH_CHRG_ERDS5   0.002                0.002
# 6  T_HDV_T_LH_CHRG_FSTCHRG   0.147                0.147
# 7  T_HDV_T_LH_CHRG_LRGBATT   0.200                0.200
#
#    avg_capacity_factor_original
# 0                         0.500
# 1                         0.377
# ...

# %%
# for profile_dict in atri_profiles_dict_list:
#     print(profile_dict['charge_strat'])
#     (profile_dict['profiles_df'].query('period==2050 and season=="D289" and tech.str.contains("FSTCHRG|LRGBATT")')
#     .pivot_table(index='tod', columns='tech', values='factor')
#     .plot()
#     )

# %%
# Add profiles to sqlite database
for profile_dict in atri_profiles_dict_list:
    print(f"Inserting profiles for charge_strat={profile_dict['charge_strat']}...")
    lihwei_db_edits.insert_profiles_CapacityFactorTech('ON_16d_bevsplit_growthlim_newtech.sqlite', 
                                       profiles_df=profile_dict['profiles_df'],
                                       new_db_path=f'{profile_dict["db_id"]}.sqlite')
# Out:
# Inserting profiles for charge_strat=minimum...
# Copying database from ON_16d_bevsplit_growthlim_newtech.sqlite to aum.sqlite for insertion of profiles.
# Inserting profiles for charge_strat=immediate...
# Copying database from ON_16d_bevsplit_growthlim_newtech.sqlite to xlv.sqlite for insertion of profiles.
# Inserting profiles for charge_strat=delayed...
# Copying database from ON_16d_bevsplit_growthlim_newtech.sqlite to bxl.sqlite for insertion of profiles.

# %% [markdown]
# ### Testing simple profiles

# %%
lihwei_db_edits.insert_profiles_CapacityFactorTech('ON_16d_bevsplit_growthlim_newtech.sqlite',
                                   profiles_df=create_CapacityFactorTech_single_day('flat', input_data_dict, season_list, period_list, 
                                                                                    seasonal_capacity_factor_df=daily_activity_df, avg_capacity_factor_df=avg_capacity_factor_df),
                                   new_db_path='roa.sqlite')
# Out:
# ...
# Copying database from ON_16d_bevsplit_growthlim_newtech.sqlite to roa.sqlite for insertion of profiles.

# %%
lihwei_db_edits.insert_profiles_CapacityFactorTech('ON_16d_bevsplit_growthlim_newtech.sqlite',
                                   profiles_df=create_CapacityFactorTech_single_day('simple_midday_peak', input_data_dict, season_list, period_list,
                                                                                    seasonal_capacity_factor_df=daily_activity_df, avg_capacity_factor_df=avg_capacity_factor_df),
                                   new_db_path='xuw.sqlite')
# Out:
# Reached iteration limit. Final mean: 0.7947224003952029, target: 0.7949488284745376
# ...
# Reached iteration limit. Final mean: 0.7947224003952029, target: 0.7949488284745376
# ...
# Reached iteration limit. Final mean: 0.7947224003952029, target: 0.7949488284745376
# ...
# Reached iteration limit. Final mean: 0.7947224003952029, target: 0.7949488284745376
# ...
# Reached iteration limit. Final mean: 0.7947224003952029, target: 0.7949488284745376
# ...
# Copying database from ON_16d_bevsplit_growthlim_newtech.sqlite to xuw.sqlite for insertion of profiles.

# %% [markdown]
# ### Plotting cap fac profiles

# %%
print(input_data_dict['sample_profiles'].columns.tolist())
# Out:
# ['tod', 'flat', 'simple_midday_peak']

# %%
#season_list = ["D222", "D007", "D185", "D217", "D295", "D248", "D332", "D214", "D160", "D067", "D290", "D054"]
df = create_CapacityFactorTech_single_day('simple_midday_peak', input_data_dict, season_list, period_list,
                                          seasonal_capacity_factor_df=daily_activity_df)   # flat, simple_midday_peak

# %%
df.query('season=="D222"').groupby(['tech', 'avg_capacity_factor']).factor.mean()
# Out:
# Series([], Name: factor, dtype: float64)

# %%
sns.relplot(df.query('~tech.str.contains("H2")'), 
            hue='tech', x='tod', y='factor', kind='line', aspect=1.5, height=5)

# %% [markdown]
# # Create a baseline database without truck electrification
# LimitCapacity: period all, operator 'le', capacity 0
# T_HDV_T_LH_BEV% OR T_HDV_T_LH_FCEV%

# %%
new_db_path = 'uez.sqlite'
shutil.copy('ON_16d_bevsplit_growthlim_newtech.sqlite', new_db_path)

with sqlite3.connect(new_db_path) as conn:
    cursor = conn.cursor()
    # Get all periods from the database
    period_list = [row[0] for row in cursor.execute("SELECT DISTINCT period FROM LimitCapacity").fetchall()]
    # Get all techs matching the patterns
    techs = [row[0] for row in cursor.execute(
        "SELECT tech FROM Technology WHERE tech LIKE 'T_HDV_T_LH_BEV%' OR tech LIKE 'T_HDV_T_LH_FCEV%'"
    ).fetchall()]
    # Insert LimitCapacity rows for each period and tech
    for period in period_list:
        for tech in techs:
            cursor.execute(
                "INSERT OR IGNORE INTO LimitCapacity (region, period, tech_or_group, operator, capacity) VALUES ('ON', ?, ?, 'le', 0)",
                (period, tech)
            )
    conn.commit()

# %% [markdown]
# # Check Wind and Solar capacity factors

# %%
target_db = 'ON_16d_bevsplit_growthlim_newtech.sqlite'
with sqlite3.connect(target_db) as conn:
    # get CapacityFactorProcess rows where tech like 'E_SOL_%' or 'E_WND_%'
    df = pd.read_sql_query("SELECT * FROM CapacityFactorProcess WHERE tech LIKE 'E_SOL_%' OR tech LIKE 'E_WND_%'", conn)

plot_df = (df.query('period==2045')
           .groupby(['season', 'tod', 'tech']).factor.mean().reset_index()
           # extract E_WND or E_SOL from tech column
           .assign(tech1 = lambda x: x['tech'].str.extract(r'(E_SOL|E_WND)')[0],
                   tod = lambda x: x['tod'].str.replace('H','').astype(int)))

#g = sns.relplot(data=plot_df, x='tod', y='factor', hue='tech', row='tech1', col='season', kind='line', aspect=0.6, height=3, legend=None)
#g.set_titles(row_template='{row_name}', col_template='{col_name}')

# %% [markdown]
# ### Rearrange seasons so low VRE (wind+solar) are together, positively correlated

# %%
# Rearrange seasons so low wind+solar and high wind+solar are paired
season_means = (plot_df.groupby(['season', 'tech1']).factor.mean().reset_index())

# Sort each tech from low to high factor
sol = (season_means.query("tech1 == 'E_SOL'").sort_values('factor').reset_index(drop=True))
wnd = (season_means.query("tech1 == 'E_WND'").sort_values('factor').reset_index(drop=True))
lh_hdt = (daily_activity_df.sort_values('factor', ascending=False).reset_index(drop=True))    # opposite order for trucks

# Pair by rank (low with low, high with high); keep solar seasons fixed
pair_count = min(len(sol), len(wnd))
paired = (pd.DataFrame({
    'rank': range(1, pair_count + 1),
    'season_sol': sol.loc[:pair_count - 1, 'season'].values,
    'factor_sol': sol.loc[:pair_count - 1, 'factor'].values,
    'season_wnd': wnd.loc[:pair_count - 1, 'season'].values,
    'factor_wnd': wnd.loc[:pair_count - 1, 'factor'].values,
    'season_hdt': lh_hdt.loc[:pair_count - 1, 'season'].values,
    'factor_hdt': lh_hdt.loc[:pair_count - 1, 'factor'].values,
})
    .assign(new_season=lambda x: x['season_sol'])
    .sort_values('rank')
    .reset_index(drop=True))

# Keep track of old season -> new season (lh_hdt unchanged, solar and wind moved to match lh_hdt season)
season_mapping = (pd.concat([
    pd.DataFrame({
        'old_season': paired['season_sol'],
        'new_season': paired['season_hdt'],
        'tech1': 'E_SOL',
    }),
    pd.DataFrame({
        'old_season': paired['season_wnd'],
        'new_season': paired['season_hdt'],
        'tech1': 'E_WND',
    }),
    pd.DataFrame({
        'old_season': paired['season_hdt'],
        'new_season': paired['season_hdt'],
        'tech1': 'HDT',
    })
], ignore_index=True)
    .sort_values(['new_season', 'tech1'])
    .reset_index(drop=True)
    .set_index(['old_season', 'tech1']).to_dict(orient='index'))

display(paired)
# Out:
#     rank season_sol  factor_sol season_wnd  factor_wnd season_hdt  factor_hdt  \
# 0      1       D339    0.031101       D154    0.119580       D169    1.000000
# 1      2       D363    0.054272       D314    0.192217       D064    0.931033
# 2      3       D335    0.059443       D255    0.293712       D087    0.854085
# 3      4       D025    0.151571       D025    0.299342       D339    0.847638
# 4      5       D087    0.179840       D213    0.303322       D255    0.838011
# 5      6       D346    0.200253       D244    0.341952       D213    0.769538
# 6      7       D314    0.203885       D363    0.475563       D346    0.744963
# 7      8       D255    0.211158       D335    0.531820       D025    0.742742
# 8      9       D223    0.255867       D339    0.546321       D081    0.725283
# 9     10       D169    0.260586       D081    0.550752       D154    0.670072
# 10    11       D097    0.274392       D097    0.581856       D097    0.430946
# ...

# %%
# Replace season column in plot_df using season_mapping
plot_df['new_season'] = plot_df.apply(lambda r: season_mapping[(r['season'], r["tech1"])]['new_season'], axis=1)

# %%
# g = sns.relplot(data=plot_df.sort_values(['tech1','new_season']), x='tod', y='factor', hue='tech', row='tech1', col='new_season', kind='line', aspect=0.6, height=3, legend=None)
# g.set_titles(row_template='{row_name}', col_template='{col_name}')

# %%
# Scatterplot of average capacity factor of wind and solar
(plot_df.groupby(['season', 'tech1']).factor.mean().reset_index()
 .pivot(index='season', columns='tech1', values='factor')
 .plot.scatter(x='E_SOL', y='E_WND', s=10, figsize=(3,3), title='Original seasons: \nE_WND vs. E_SOL')
 )
plt.xlim(0,1)
plt.ylim(0,1)

(plot_df.groupby(['new_season', 'tech1']).factor.mean().reset_index()
 .pivot(index='new_season', columns='tech1', values='factor')
 .plot.scatter(x='E_SOL', y='E_WND', s=10, figsize=(3,3), title='After swapping seasons: \nE_WND vs. E_SOL')
 )
plt.xlim(0,1)
plt.ylim(0,1)

(plot_df.query('tech1=="E_SOL"').groupby('new_season').factor.mean().reset_index()
 .rename(columns={'factor':'E_SOL'})
 .merge(daily_activity_df[['total_vkt', 'season']], left_on='new_season', right_on='season')
 .plot.scatter(x='E_SOL', y='total_vkt', figsize=(3,3), title='After swapping seasons: \ntotal_vkt vs. E_SOL')
)
plt.xlim(0,1)
# Out:
# (0.0, 1.0)

# %% [markdown]
# ### Create database with swapped seasons to off-sync VRE with long-haul HDT demand

# %%
# make a copy of the database to edit
new_db_path = 'gkl.sqlite'
shutil.copy('wrn.sqlite', new_db_path)

with sqlite3.connect(new_db_path) as conn:
    mapping_df = pd.DataFrame([
        {'old_season': k[0], 'tech1': k[1], 'new_season': v['new_season']}
        for k, v in season_mapping.items()
        if k[1] in ['E_SOL', 'E_WND']
    ])

    for table in ['CapacityFactorTech', 'CapacityFactorProcess']:
        df = pd.read_sql_query(f"SELECT * FROM {table}", conn)
        table_info = pd.read_sql_query(f"PRAGMA table_info({table})", conn)

        cols = table_info['name'].tolist()
        pk_cols = table_info.loc[table_info['pk'] > 0, 'name'].tolist()

        df['tech1'] = df['tech'].str.extract(r'(E_SOL|E_WND)', expand=False)
        df = df.merge(
            mapping_df,
            how='left',
            left_on=['season', 'tech1'],
            right_on=['old_season', 'tech1']
        )
        df['season'] = df['new_season'].fillna(df['season'])
        df = df.drop(columns=['tech1', 'old_season', 'new_season'])

        if pk_cols: df = df.drop_duplicates(subset=pk_cols)
        else: df = df.drop_duplicates()

        temp_table = f"{table}_temp"
        conn.execute(f"DROP TABLE IF EXISTS {temp_table}")
        df.to_sql(temp_table, conn, if_exists='replace', index=False)

        col_list = ", ".join([f'"{c}"' for c in cols])
        with conn:
            conn.execute(
                f"INSERT OR REPLACE INTO {table} ({col_list}) "
                f"SELECT {col_list} FROM {temp_table}"
            )
            conn.execute(f"DROP TABLE IF EXISTS {temp_table}")
    conn.execute("VACUUM")
    conn.commit()

# %% [markdown]
# # Post sqlite edits

# %%
#db_path_list = [f'{db_id}.sqlite' for db_id in ['wrn', 'ljv', 'rhl', 'iyw', 'jmo', 'gkl']]
db_path_list = [f'{db_id}.sqlite' for db_id in ['uez','aum','xlv','bxl','roa','xuw']]

# %% [markdown]
# ### Midshift/offshift energy split, schedule delays
# - Incorporate midshift and offshift energy split for non-eRoads technologies:
#     - `prop_midshift`: proportion of energy via midshift chargers. Offshift = 1 - midshift
#     - Update parameters as a linear combination of midshift and offshift chargers (CapacityToActivity, CostInvest, CostFixed, utilization rates via CapacityFactorTech)
#     - Works on tech_supply, only for `T_HDV_T_LH_CHRG_FSTCHRG`. Using parameters for `T_HDV_T_LH_CHRG_FSTCHRG` and `T_HDV_T_LH_CHRG_LRGBATT`
#     - Only do this for `T_HDV_T_LH_CHRG_FSTCHRG` because `T_HDV_T_LH_CHRG_LRGBATT` doesn't have fast chargers. Mid-shift charging is done by regular overnight chargers (see charger kW in `truck_specs`)
#     - Take average of prop_midshift across all Years
#     - CapacityToActivity, CostInvest, CostFixed:
#         - FSTCHRG_new = prop_midshift*FSTCHRG + (1-prop_midshift)*LRGBATT
#     - CapacityFactorTech:
#         - Rescale evenly across all tod such that for avg(factor),FSTCHRG_new = prop_midshift*avg_capacity_factor_FSTCHRG + (1-prop_midshift)*avg_capacity_factor_LRGBATT
#     - Update `notes`
#
# - Modify freight transport efficiency / fleet size to represent schedule delays due to charging/refueling
#     - `prop_delay`: proportion of time spent with delays.
#     - Take average of prop_delay across all Years
#     - Adjust annual average capacity factors (LimitAnnualCapacityFactor) for trucks (tech_veh), add note to 'notes'
#     - new_capfac = old_capfac * (1 - prop_delay)
#     - E.g. if prop_delay = 0.667, we'll need 3x as many trucks to move the same amount of freight. So capacity factor is divided by 3.
#     - [to-do] **Future**: include labour cost to CostVariable ($/Btkm) and multiply by charging time penalty
#
# Input:
# - DataFrame with columns: tech_supply, tech_veh, Year, prop_midshift, prop_delay
# - The db_path to sqlite to edit the database
#
# Steps:
# - Load the DataFrame that has prop_midshift and prop_delay
# - Take average of prop_midshift and prop_delay across Years
# - Interpolate Year to match period and vintage in database tables.
# - Tables changed: CapacityToActivity, CostInvest, CostFixed, CapacityFactorTech, LimitAnnualCapacityFactor

# %%
# Create sample dataframe: cross product (Cartesian product) of the technologies and years
df = pd.DataFrame({
    'tech_veh': ['T_HDV_T_LH_BEV_LRGBATT_N', 'T_HDV_T_LH_BEV_FSTCHRG_N'],
    'tech_supply': ['T_HDV_T_LH_CHRG_LRGBATT', 'T_HDV_T_LH_CHRG_FSTCHRG'],
    'prop_midshift': [0, 0.5],
    'prop_delay': [0, 0.667]
})

df = (df.merge(pd.DataFrame({'Year': [2023,2050]}), how='cross')
      .assign(Case="Low"))

# take average prop_midshift and prop_delay across all Year
df = (df.groupby(['tech_veh', 'tech_supply', 'Case'])
      .agg({'prop_midshift':'mean', 'prop_delay':'mean'}).reset_index())
#df

# %%
def apply_midshift_delay_adjustments(df, db_path):
    """
    Applies midshift/offshift energy split and schedule delay adjustments to the database.
    
    Parameters:
    -----------
    df : pd.DataFrame
        Input dataframe with columns: tech_supply, tech_veh, prop_midshift, prop_delay
        (already averaged across Year)
    db_path : str
        Path to the SQLite database to modify
    """
    # Check that df is unique on tech_supply and tech_veh
    if not (df['tech_supply'].is_unique and df['tech_veh'].is_unique):
        raise ValueError("Input dataframe must be unique on tech_supply and tech_veh.")
    
    with sqlite3.connect(db_path) as conn:
        cursor = conn.cursor()
        
        # ===== Handle midshift/offshift energy split (tech_supply) =====
        for _, row in df.iterrows():
            tech_supply = row['tech_supply']
            prop_midshift = row['prop_midshift']
            
            # Only process FSTCHRG techs
            if '_FSTCHRG' not in tech_supply: continue
            
            tech_fstchrg = tech_supply.replace('_LRGBATT', '_FSTCHRG')
            tech_lrgbatt = tech_supply.replace('_FSTCHRG', '_LRGBATT')
            
            # Process CapacityToActivity, CostInvest, CostFixed
            for table_name, param_col in [
                ('CapacityToActivity', 'c2a'),
                ('CostInvest', 'cost'),
                ('CostFixed', 'cost')
            ]:
                try:
                    df_fstchrg = pd.read_sql_query(
                        f"SELECT * FROM {table_name} WHERE tech = ?", 
                        conn, params=(tech_fstchrg,)
                    )
                    df_lrgbatt = pd.read_sql_query(
                        f"SELECT * FROM {table_name} WHERE tech = ?", 
                        conn, params=(tech_lrgbatt,)
                    )
                    
                    if len(df_fstchrg) == 0 or len(df_lrgbatt) == 0: continue
                    
                    merge_cols = [c for c in df_fstchrg.columns if c in ['region', 'period', 'vintage']]
                    
                    df_merged = df_fstchrg.merge(
                        df_lrgbatt[[*merge_cols, param_col, 'notes']],
                        on=merge_cols, suffixes=('_fstchrg', '_lrgbatt')
                    )

                    # Blend parameters
                    df_merged[param_col] = (
                        prop_midshift * df_merged[f'{param_col}_fstchrg'] +
                        (1 - prop_midshift) * df_merged[f'{param_col}_lrgbatt']
                    )

                    # Update notes
                    note_suffix = f"; midshift-offshift blend (prop_midshift={prop_midshift:.3f})"
                    df_merged['notes'] = df_merged['notes_fstchrg'].fillna('') + note_suffix
                    df_merged['notes'] = df_merged['notes'].str.lstrip('; ')
                    
                    # Replace FSTCHRG records
                    cursor.execute(f"DELETE FROM {table_name} WHERE tech = ?", (tech_fstchrg,))
                    cols_to_keep = [c for c in df_merged.columns if c in df_fstchrg.columns]

                    # if df_merged is empty, print warning
                    if df_merged.empty: print(f"Warning: No records to insert for {table_name} and {tech_supply} after blending.")
                    
                    df_merged[cols_to_keep].to_sql(table_name, conn, if_exists='append', index=False)
                    conn.commit()
                    
                except Exception as e: print(f"Skipping {table_name} for {tech_supply}: {e}")
            
            # ===== CapacityFactorTech rescaling =====
            # if prop_midshift == 0 or prop_midshift == 1: continue
            
            # try:
            #     df_cft_fstchrg = pd.read_sql_query(
            #         "SELECT * FROM CapacityFactorTech WHERE tech = ?",
            #         conn, params=(tech_fstchrg,)
            #     )
            #     df_cft_lrgbatt = pd.read_sql_query(
            #         "SELECT * FROM CapacityFactorTech WHERE tech = ?",
            #         conn, params=(tech_lrgbatt,)
            #     )
                
            #     if len(df_cft_fstchrg) == 0 or len(df_cft_lrgbatt) == 0: continue
                
            #     # Calculate scale factor to match blended average
            #     avg_fstchrg = df_cft_fstchrg['factor'].mean()
            #     avg_lrgbatt = df_cft_lrgbatt['factor'].mean()
            #     blended_avg = (prop_midshift * avg_fstchrg) + ((1 - prop_midshift) * avg_lrgbatt)
            #     scale_factor = blended_avg / avg_fstchrg if avg_fstchrg > 0 else 1
                
            #     print('avg_fstchrg:', round(avg_fstchrg, 3), 'avg_lrgbatt:', round(avg_lrgbatt, 3), 'prop_midshift:', round(prop_midshift, 3), 
            #           'blended_avg:', round(blended_avg, 3), 'scale_factor:', round(scale_factor, 3))
                
            #     df_cft_fstchrg['factor'] *= scale_factor
            #     df_cft_fstchrg['notes'] = df_cft_fstchrg['notes'] + (
            #         f"; rescaled for midshift-offshift blend (prop_midshift={prop_midshift:.2f})"
            #     )
                
            #     cursor.execute("DELETE FROM CapacityFactorTech WHERE tech = ?", (tech_fstchrg,))
            #     df_cft_fstchrg.to_sql('CapacityFactorTech', conn, if_exists='append', index=False)
            #     conn.commit()
                
            # except Exception as e: print(f"Skipping CapacityFactorTech for {tech_supply}: {e}")
        
        # ===== Handle schedule delays (tech_veh) =====
        for _, row in df[df['prop_delay'] > 0].iterrows():
            tech_veh = row['tech_veh']
            prop_delay = row['prop_delay']
            
            try:
                df_limacf = pd.read_sql_query(
                    "SELECT * FROM LimitAnnualCapacityFactor WHERE tech = ?",
                    conn, params=(tech_veh,)
                )
                
                if len(df_limacf) == 0: continue
                
                # Adjust capacity factor
                multiplier = 1 - prop_delay
                df_limacf['factor'] *= multiplier
                
                # Update notes
                note_suffix = f"; schedule delay adjustment (prop_delay={prop_delay:.3f}, capfac_multiplier={multiplier:.3f})"
                df_limacf['notes'] = df_limacf['notes'].fillna('') + note_suffix
                df_limacf['notes'] = df_limacf['notes'].str.lstrip('; ')
                
                cursor.execute("DELETE FROM LimitAnnualCapacityFactor WHERE tech = ?", (tech_veh,))
                df_limacf.to_sql('LimitAnnualCapacityFactor', conn, if_exists='append', index=False)
                conn.commit()
                
            except Exception as e: print(f"Skipping LimitAnnualCapacityFactor for {tech_veh}: {e}")

# %%
for db_path in db_path_list:
    print(db_path)
    apply_midshift_delay_adjustments(BEV_charging_stats_df, db_path)
# Out:
# uez.sqlite
# aum.sqlite
# xlv.sqlite
# bxl.sqlite
# roa.sqlite
# xuw.sqlite

# %% [markdown]
# ### LimitAnnualCapacityFactor instead of cf_fixed
# - For HDV_T_LH charging, eroads, h2 refueling: cf_fixed to 0 or NULL
# - Add MaxAnnualCapacityFactor for HDV_T_LH charging, eroads, h2 refueling: equal to long-run average utilization
# - Set MinAnnualCapacityFactor as 99.9% of Max values
# - Note: Do not set LimitSeasonalCapacityFactor, as capacity factor is already seasonally-adjusted

# %%
for db_path in db_path_list:
    with sqlite3.connect(db_path) as conn:
        cursor = conn.cursor()

        # set cf_fixed to NULL for technologies with HDV_T_LH in their name
        # cursor.execute("""UPDATE Technology SET cf_fixed = NULL WHERE tech LIKE '%HDV_T_LH%'""")
        
        # Query the Efficiency table for unique combinations of tech and output_comm
        df_tech_output_comm = pd.read_sql_query("SELECT DISTINCT tech, output_comm FROM Efficiency", conn)

        # Query the LimitAnnualCapacityFactor table for unique combinations of period and region
        df_period_region = pd.read_sql_query("SELECT DISTINCT vintage, region FROM LimitAnnualCapacityFactor", conn)
        df_period_region = df_period_region.query('vintage >= 2025')  # filter to only include future vintages

        # Calculate average capacity factor for each technology
        df_avg = (pd.read_sql_query("SELECT tech, AVG(factor) as avg_factor FROM CapacityFactorTech WHERE tech LIKE '%HDV_T_LH%' GROUP BY tech", conn)
                  .merge(df_tech_output_comm, how='left'))
        #df_seasonal_avg = (pd.read_sql_query("SELECT tech, season, AVG(factor) as avg_factor FROM CapacityFactorTech WHERE tech LIKE '%HDV_T_LH%' GROUP BY tech, season", conn)
        #                   .merge(df_tech_output_comm[['tech']].drop_duplicates(), how='left'))

        # Do not add to LimitSeasonalCapacityFactor
        for (df, table_name) in [(df_avg, 'LimitAnnualCapacityFactor'),]:
            df_output = (df.merge(df_period_region, how='cross'))
            
            # Remove rows from table_name where tech is in df_output
            tech_list = df_output['tech'].unique().tolist()
            placeholders = ','.join(['?' for _ in tech_list])
            cursor.execute(f"DELETE FROM {table_name} WHERE tech IN ({placeholders})", tech_list)
            
            # Add df_output to the LimitAnnualCapacityFactor table. Apply 99.5% factor for MinAnnualCapacityFactor
            # Create two copies of df_output for Min and Max capacity factors
            df_min = df_output.copy().assign(operator = 'ge', factor = lambda x: x['avg_factor'] * 0.995)
            df_max = df_output.copy().assign(operator = 'le', factor = lambda x: x['avg_factor'] * 1.005)

            # Combine and insert into LimitAnnualCapacityFactor
            df_combined = pd.concat([df_min, df_max], ignore_index=True)
            df_combined.drop(columns='avg_factor').to_sql(table_name, conn, if_exists='append', index=False)

        conn.commit()
    conn.close()
conn.close()

# %% [markdown]
# ### Add curtailment for wind and solar
# - In Technology table, tech starts with "E_SOL_PV" or "E_WND_ON", set curtail=1
# - Outputs will be in OutputCurtailment

# %%
for db_path in db_path_list:
#for db_path in db_path_list[0:1]:
    # Copy the schema reference file
    #new_db_path = db_path.replace('.sqlite', '_curtail.sqlite')
    #shutil.copy(db_path, new_db_path)
    #print(f"Copied {db_path} to {new_db_path}")
    #db_path = new_db_path
    
    with sqlite3.connect(db_path) as conn:
        cursor = conn.cursor()
        # set curtail = 1 for solar and wind technologies
        cursor.execute("""
            UPDATE Technology
            SET curtail = 1
            WHERE (tech LIKE 'E_SOL_PV%') OR (tech LIKE 'E_WND_ON%')
            """)

        conn.commit()
    conn.close()
conn.close()

# %% [markdown]
# ### Make flat profile into annual tech
# - Technology: tech contains "\_LH\_", set annual = 1
# - Commodity: name == 'T_annual_tkm_hdv_t_lh' set flag = 'a' (commodity is balanced on an annual basis)
# - CapacityFactorTech: remove rows where tech contains "\_LH\_"
# - This also removes seasonal variation in long-haul HDT energy demand. This represents a situation without any seasonal, daily or hourly information

# %%
db_path = 'roa.sqlite'

with sqlite3.connect(db_path) as conn:
    cursor = conn.cursor()

    cursor.execute("""UPDATE Technology SET annual = 1
            WHERE tech LIKE '%_T_LH_%'
            """)
    cursor.execute("""UPDATE Commodity SET flag = 'a'
            WHERE name LIKE '%T_annual_tkm_hdv_t_lh%' OR name LIKE 'T_elc_hdv_t_lh_chrg_%' OR name like 'T_h2_hdv_t_lh'
            """)

    cursor.execute("DELETE FROM CapacityFactorTech WHERE tech LIKE '%_T_LH_%'")

    conn.commit()
conn.close()

# %% [markdown]
# ### [unused] Try: make E_BAT_% tech have seas_stor=1
# Decided not to do this for short duration battery storage (2 or 4 hours only). seas_stor = 1 for long duration energy storage instead.

# %%
# for db_path in db_path_list:
#     with sqlite3.connect(db_path) as conn:
#         cursor = conn.cursor()
#         # set seas_stor = 1 for tech LIKE E_BAT_%
#         cursor.execute("""UPDATE Technology SET seas_stor = 1 WHERE tech LIKE 'E_BAT_%'""")
#         conn.commit()
#     conn.close()
# conn.close()

# %% [markdown]
# ### Update categories in Technology table for MGA
# - In Technology table, 'category' shall be the type of technology.
# - Clear category column, then only define categories for electricity system, long-haul heavy trucks, heavy trucks, LDVs.

# %%
mapping_startswith = {'E_BIO': 'Biomass',
        'E_NG_CCS': 'Natural Gas +CCS',
        'E_NG': 'Natural Gas',
        'E_HYD': 'Hydro',
        'E_SOL': 'Solar',
        'E_WND': 'Wind',
        'E_NUC': 'Nuclear',
        'E_BAT': 'Battery',
        'E_PUMP': 'Pumped Storage',
        'E_INT_IN': 'Inter-tie (in)',
        'T_HDV_T_BEV': 'heavy trucks, battery electric',
        'T_HDV_T_FCEV': 'heavy trucks, fuel cell electric',
        'T_HDV_T_DSL': 'heavy trucks, diesel'    
        }

mapping_contains = {
    '_ERDS': 'heavy trucks long-haul, eRoads',
    '_LRGBATT_': 'heavy trucks long-haul, large batteries',
    '_FSTCHRG_': 'heavy trucks long-haul, fast chargers',
    '_LH_FCEV_': 'heavy trucks long-haul, fuel cell electric',
    '_T_LH_DSL_': 'heavy trucks long-haul, diesel',
    'T_LDV_C_BEV|T_LDV_LTF_BEV|T_LDV_LTP_BEV': 'light-duty vehicles, battery electric',
}

# %%
def update_technology_categories(db_path, 
                                 mapping_startswith=mapping_startswith, 
                                 mapping_contains=mapping_contains):
    """
    Clears Technology.category and updates it using mapping_startswith (prefix match)
    and mapping_contains (substring match; '|' in keys treated as OR).

    Precedence: mapping_startswith first, then mapping_contains (contains overrides).
    """
    with sqlite3.connect(db_path) as conn:
        cursor = conn.cursor()
        # Clear all categories
        cursor.execute("UPDATE Technology SET category = NULL")
        conn.commit()

        techs = pd.read_sql_query("SELECT tech FROM Technology", conn)['tech'].tolist()

        updates = []
        for tech in techs:
            category = None

            # Prefix matches (in insertion order)
            for prefix, cat in mapping_startswith.items():
                if tech.startswith(prefix):
                    category = cat
                    break

            # Contains matches (override if any)
            for key, cat in mapping_contains.items():
                tokens = [t for t in key.split('|') if t]  # support 'a|b' syntax
                if any(t in tech for t in tokens):
                    category = cat
                    break

            if category: updates.append((category, tech))

        if updates:
            cursor.executemany("UPDATE Technology SET category = ? WHERE tech = ?", updates)
            conn.commit()
        print(f"Updated categories for {len(updates)} technologies in {db_path}.")

# %%
for db_path in db_path_list:
    print(db_path)
    try: update_technology_categories(db_path)
    except: print('Error')
# Out:
# uez.sqlite
# Updated categories for 74 technologies in uez.sqlite.
# aum.sqlite
# Updated categories for 74 technologies in aum.sqlite.
# xlv.sqlite
# Updated categories for 74 technologies in xlv.sqlite.
# bxl.sqlite
# Updated categories for 74 technologies in bxl.sqlite.
# roa.sqlite
# Updated categories for 74 technologies in roa.sqlite.
# xuw.sqlite
# Updated categories for 74 technologies in xuw.sqlite.

# %% [markdown]
# ### Test db to induce truck mix changes
# - More solar (cost invest = 0, Free solar)
# - ~~No wind, no natural gas: MaxCapacity, max_cap = 0 WHERE tech LIKE (('E_WND_%' OR 'E_NG_%') AND period >= 2040)~~
# - Night peak for eroads (flipped), day peak for plug-in fast chargers and large batteries

# %%
# Make a copy of 'rhl.sqlite' database
new_db_path = 'cqh.sqlite'
shutil.copy('rhl.sqlite', new_db_path)    # Make a copy

# get CapacityFactorTech
with sqlite3.connect(new_db_path) as conn:
    df_capfactech = pd.read_sql_query("SELECT * FROM CapacityFactorTech", conn)
conn.close()

# %%
# Flip tod for specific technologies
def flip_tod(tod):
    match = re.match(r'H(\d{2})', tod)
    if match:
        num = int(match.group(1))
        flipped_num = num + 12
        if flipped_num > 24:
            flipped_num -= 24
        return f'H{flipped_num:02d}'
    return tod

# Only flip for the specified techs
#techs_to_flip = ['T_HDV_T_LH_CHRG_FSTCHRG', 'T_HDV_T_LH_CHRG_LRGBATT']
mask = df_capfactech['tech'].str.contains("ERDS")
df_capfactech.loc[mask, 'tod'] = df_capfactech.loc[mask, 'tod'].apply(flip_tod)

# %%
sns.relplot(df_capfactech.query('season=="D050" and tech.str.contains("LH")').sort_values(by='tod'), 
            kind='line', hue='tech', x='tod', y='factor', aspect=1.5, height=5)

# %%
# Check that average capacity factor is unchanged
print(df_capfactech.groupby('tech').factor.mean())
# Out:
# tech
# E_HYD_ROR-EXS              0.680265
# E_INT_IN                   0.065549
# E_SOL_PV-EXS               0.160749
# E_WND_ON-EXS               0.221993
# T_H2_HDV_T_LH_REFUEL       0.499966
# T_HDV_T_LH_CHRG_ERDS1      0.376891
# T_HDV_T_LH_CHRG_ERDS2      0.139771
# T_HDV_T_LH_CHRG_ERDS3      0.037129
# T_HDV_T_LH_CHRG_ERDS4      0.014141
# T_HDV_T_LH_CHRG_ERDS5      0.002092
# T_HDV_T_LH_CHRG_FSTCHRG    0.080000
# T_HDV_T_LH_CHRG_LRGBATT    0.200000
# T_LDV_BEV_CHRG             0.416958
# Name: factor, dtype: float64

# %%
# Put the flipped data back into CapacityFactorTech
# Set solar CostInvest to zero (free solar)

with sqlite3.connect(new_db_path) as conn:
    cursor = conn.cursor()
    # Remove all rows from CapacityFactorTech
    cursor.execute("DELETE FROM CapacityFactorTech")
    conn.commit()
    # Insert updated df_capfactech back into CapacityFactorTech
    df_capfactech.to_sql('CapacityFactorTech', conn, if_exists='append', index=False)

    # Set solar CostInvest to zero (free solar)
    cursor.execute("""UPDATE CostInvest SET cost = 0 WHERE tech LIKE 'E_SOL_PV%'""")
    
    '''
    # Set max capacity for wind (rows already exist)
    cursor.execute("""UPDATE MaxCapacity SET max_cap = 1 WHERE (tech LIKE 'E_WND_%' AND period >= 2025)""")
    # Set max capacity = 0 for natural gas (add new rows)
    # 1. Get all E_NG_ techs
    df_ng_techs = pd.read_sql_query("SELECT tech FROM Technology WHERE (tech LIKE 'E_NG_%') AND (tech NOT LIKE '%_BYPASS') AND (tech NOT LIKE '%EXS')", conn)
    # 2. Create all combinations with periods
    df_ng_maxcap = df_ng_techs.merge(pd.DataFrame({'period': list(range(2025, 2051, 5))}), how='cross')
    df_ng_maxcap['region'] = 'ON'
    df_ng_maxcap['max_cap'] = 1
    df_ng_maxcap.to_sql('MaxCapacity', conn, if_exists='append', index=False)
    '''

    conn.commit()
conn.close()

# %% [markdown]
# ### Test db for identical tech but different time-of-day demand
# - Use simple midday peak sqlite
# - Create multiple duplicates of FSTCHRG tech and commodity
#     - Loop through all tables in sqlite. If rows contain '_fstchrg|_FSTCHRG' in any column, duplicate the rows, append _Hxx
# - Change CapFacTech profile:
#     - tech 1: 100% at H15 (lowest LCOE in 2050)
#     - tech 2: 100% at H05 (highest LCOE in 2050)
#     - tech 3: 100% at H02 (lowest LCOE in 2025)
#     - tech 4: 100% at H18 (highest LCOE in 2025)
#     - 0% everywhere else
# - Set LimitAnnualCapacityFactor to 1/24 (1 of 24 hours)
# - Make new (FSTCHRG_Hxx|FSTCHRG_N_Hxx) techs 'free' (CostInvest=0) because 1/24 capacity factor makes the tech very expensive due to low utilisation
# - Remove all other BEV, FCEV for LH HDT
#     - Set LimitCapacity = 0 for tech starts with T_HDV_T_LH_BEV_{ERDS, LRG}%, T_HDV_T_LH_FCEV_N, periods 2021 - 2050
# - Set CostInvest = 0 for FSTCHRG_Hxx and FSTCHRG_N_Hxx to encourage usage
#
# Troubleshooting:
# - Remove LimitAnnualCapacityFactor for FSTCHRG_Hxx: net capacity still zero
# - ~~Force electrification: LimitCapacity = 0 for T_HDV_T_LH_DSL_N after 2025: infeasible model~~
# - ~~Also allow regular FSTCHRG: net capacity still zero~~
# - Set T_elc_hdv_t_lh_chrg to annual commodity: Works

# %%
# Make a copy of 'rhl.sqlite' database
new_db_path = 'xcc.sqlite'
shutil.copy('rhl.sqlite', new_db_path)    # Make a copy

# List of peak TODs to set capacity factor to 100%
tod_peak_list = ['H02', 'H05', 'H15', 'H18']

with sqlite3.connect(new_db_path) as conn:
    cursor = conn.cursor()
    # Loop through specific tables in sqlite. If rows contain '_fstchrg|_FSTCHRG' in any column, duplicate the rows, append _Hxx
    # tables to check
    tables = ['Efficiency', 'CostVariable', 'CostFixed', 'CostInvest', 
              'CapacityToActivity', 'ExistingCapacity', 'CapacityFactorTech', 'LimitAnnualCapacityFactor',
              'LifetimeTech', 'Technology', 'Commodity']

    for table in tables:
        # Get column names
        columns = [row[1] for row in cursor.execute(f"PRAGMA table_info({table});").fetchall()]
        # Build WHERE clause to check for '_fstchrg' or '_FSTCHRG' in any column
        where_clause = " OR ".join([f"{col} LIKE '%_fstchrg%' OR {col} LIKE '%_FSTCHRG%'" for col in columns])
        # Select rows matching the condition
        rows = cursor.execute(f"SELECT * FROM {table} WHERE {where_clause}").fetchall()
        if rows:
            for row in rows:
                row_dict = dict(zip(columns, row))
                for tod_peak in tod_peak_list:
                    new_row = row_dict.copy()
                    # Append _Hxx to relevant columns
                    for col in columns:
                        if isinstance(new_row[col], str) and ('_fstchrg' in new_row[col].lower()): new_row[col] = f"{new_row[col]}_{tod_peak}"
                    # Insert new row
                    placeholders = ','.join(['?'] * len(columns))
                    sql = f"INSERT INTO {table} ({', '.join(columns)}) VALUES ({placeholders})"
                    cursor.execute(sql, tuple(new_row[col] for col in columns))

    for tod_peak in tod_peak_list:
        # Update CapacityFactorTech to set factor = 1.0 for the new TODs, and zero for non-peak TODs
        # Set factor = 0.0 for non-peak TODs
        cursor.execute(f"""UPDATE CapacityFactorTech SET factor = 0.0 WHERE tech LIKE '%_FSTCHRG_{tod_peak}' AND tod != '{tod_peak}'""")
        # Set factor = 1.0 for peak TOD
        cursor.execute(f"""UPDATE CapacityFactorTech SET factor = 1.0 WHERE tech LIKE '%_FSTCHRG_{tod_peak}' AND tod == '{tod_peak}'""")

    # Try deleting rows in LimitAnnualCapacityFactor and LimitSeasonalCapacityFactor where tech contains '_FSTCHRG_H'
    cursor.execute("""DELETE FROM LimitAnnualCapacityFactor WHERE tech LIKE '%_FSTCHRG_H%'""")
    cursor.execute("""DELETE FROM LimitSeasonalCapacityFactor WHERE tech LIKE '%_FSTCHRG_H%'""")

    # # Set LimitAnnualCapacityFactor to 1/24 (1 of 24 hours) if tech contains '_FSTCHRG_H'
    # # if operator is 'le', set factor to (1/24)*1.005, if 'ge', set to (1/24)*0.995
    # cursor.execute("""UPDATE LimitAnnualCapacityFactor 
    #                   SET factor = CASE 
    #                       WHEN operator = 'le' THEN (1.0/24)*1.005
    #                       WHEN operator = 'ge' THEN (1.0/24)*0.995
    #                       ELSE factor
    #                   END
    #                   WHERE tech LIKE '%_FSTCHRG_H%'""")
    
    # Set CostInvest=0 for technologies with '_FSTCHRG_H' or '_FSTCHRG_N_H' in their name
    cursor.execute("""UPDATE CostInvest SET cost = 0 WHERE tech LIKE '%_FSTCHRG_H%' OR tech LIKE '%_FSTCHRG_N_H%'""")

    # Create rows in LimitCapacity, set to 0 for techs starting with T_HDV_T_LH_BEV_{ERDS, LRG}%, T_HDV_T_LH_FCEV_N, for all periods in table
    # Get all periods and selected techs from the database
    period_list = [row[0] for row in cursor.execute("SELECT DISTINCT period FROM LimitCapacity").fetchall()]
    techs = [row[0] for row in cursor.execute(
        """SELECT tech FROM Technology WHERE tech LIKE 'T_HDV_T_LH_BEV_ERDS%' 
        OR tech LIKE 'T_HDV_T_LH_BEV_LRG%' OR tech LIKE 'T_HDV_T_LH_FCEV_N%' OR tech LIKE 'T_HDV_T_LH_BEV_FSTCHRG_N'"""
        ).fetchall()]
    print('periods:', period_list)
    print('techs to set LimitCapacity to 0:', techs)
    # Insert LimitCapacity rows for each period and tech
    for period in period_list:
        for tech in techs:
            cursor.execute(
                "INSERT OR IGNORE INTO LimitCapacity (region, period, tech_or_group, operator, capacity) VALUES ('ON', ?, ?, 'le', 0)",
                (period, tech)
            )

    # Force electrification: LimitCapacity = 0 for T_HDV_T_LH_DSL_N after 2030
    for period in [2030, 2035, 2040, 2045, 2050]:
        cursor.execute(
                "INSERT OR IGNORE INTO LimitCapacity (region, period, tech_or_group, operator, capacity) VALUES ('ON', ?, 'T_HDV_T_LH_DSL_N', 'le', 0)",
                (period,))
        
    # Try deleting rows in LimitCapacity where tech contains '_FSTCHRG'
    #cursor.execute("""DELETE FROM LimitCapacity WHERE tech_or_group LIKE '%_FSTCHRG%'""")

    # Try setting 'T_elc_hdv_t_lh_chrg%' to annual commodities in Commodity table
    #cursor.execute("""UPDATE Commodity SET flag = 'a' WHERE name LIKE 'T_elc_hdv_t_lh_chrg_%'""")

    conn.commit()
# Out:
# periods: [2021, 2025, 2030, 2035, 2040, 2045, 2050]
# techs to set LimitCapacity to 0: ['T_HDV_T_LH_BEV_ERDS1_N', 'T_HDV_T_LH_BEV_ERDS2_N', 'T_HDV_T_LH_BEV_ERDS3_N', 'T_HDV_T_LH_BEV_ERDS4_N', 'T_HDV_T_LH_BEV_ERDS5_N', 'T_HDV_T_LH_BEV_FSTCHRG_N', 'T_HDV_T_LH_BEV_LRGBATT_N', 'T_HDV_T_LH_FCEV_N']

# %% [markdown]
# ### Test db for demand flexibility: without CapacityFactorTech for long-haul HDTs

# %%
# Make a copy of 'rhl.sqlite' database
new_db_path = 'htl.sqlite'
shutil.copy('xuw.sqlite', new_db_path)    # Make a copy

with sqlite3.connect(new_db_path) as conn:
    cursor = conn.cursor()
    
    # Query the Efficiency table for unique combinations of tech and output_comm
    df_tech_output_comm = pd.read_sql_query("SELECT DISTINCT tech, output_comm FROM Efficiency", conn)

    # Query the LimitAnnualCapacityFactor table for unique combinations of period and region
    df_period_region = pd.read_sql_query("SELECT DISTINCT vintage, region FROM LimitAnnualCapacityFactor", conn)
    df_period_region = df_period_region.query('vintage >= 2025')  # filter to only include future vintages

    # Calculate seasonal average capacity factor for each technology
    df_seasonal_avg = (pd.read_sql_query("SELECT tech, season, AVG(factor) as avg_factor FROM CapacityFactorTech WHERE tech LIKE '%HDV_T_LH%' GROUP BY tech, season", conn)
                       .merge(df_tech_output_comm[['tech']].drop_duplicates(), how='left'))

    # Add to LimitSeasonalCapacityFactor
    df_output = (df_seasonal_avg.merge(df_period_region, how='cross'))
    
    # Remove rows from table_name where tech is in df_output
    tech_list = df_output['tech'].unique().tolist()
    placeholders = ','.join(['?' for _ in tech_list])
    cursor.execute(f"DELETE FROM LimitSeasonalCapacityFactor WHERE tech IN ({placeholders})", tech_list)
    
    # Add df_output to the LimitSeasonalCapacityFactor table. Apply 99.5% factor for MinAnnualCapacityFactor
    # Create two copies of df_output for Min and Max capacity factors
    df_min = df_output.copy().assign(operator = 'ge', factor = lambda x: x['avg_factor'] * 0.995)
    df_max = df_output.copy().assign(operator = 'le', factor = lambda x: x['avg_factor'] * 1.005)

    # Combine and insert into LimitSeasonalCapacityFactor
    df_combined = pd.concat([df_min, df_max], ignore_index=True)
    df_combined.drop(columns='avg_factor').rename(columns={'vintage': 'period'}).to_sql('LimitSeasonalCapacityFactor', conn, if_exists='append', index=False)

    # Remove CapacityFactorTech and LimitAnnualCapacityFactor for tech LIKE T_HDV_T_LH_CHRG% or T_H2_HDV_T_LH_REFUEL
    cursor.execute("DELETE FROM CapacityFactorTech WHERE tech LIKE 'T_HDV_T_LH_CHRG%' OR tech LIKE 'T_H2_HDV_T_LH_REFUEL'")
    cursor.execute("DELETE FROM LimitAnnualCapacityFactor WHERE tech LIKE 'T_HDV_T_LH_CHRG%' OR tech LIKE 'T_H2_HDV_T_LH_REFUEL'")

    conn.commit()

# update Technology categories for MGA
update_technology_categories(new_db_path)
# Out:
# Updated categories for 74 technologies in htl.sqlite.

# %% [markdown]
# ### Test db to use H2, DAC and e-diesel
# - Start with ATRI profiles
# - Long-haul trucks can only be diesel and H2FCETs (no BEVs)
# - Only allow H2 produced with PEM
# - Gradually phase out petroleum diesel

# %%
db_path = 'aum.sqlite'

# create a copy of the database
new_db_path = 'myh.sqlite'
shutil.copy(db_path, new_db_path)

with sqlite3.connect(new_db_path) as conn:
    cursor = conn.cursor()

    # Get all periods from the database
    period_list = [row[0] for row in cursor.execute("SELECT DISTINCT period FROM LimitCapacity").fetchall()]
    # Get all techs matching the pattern
    techs = [row[0] for row in cursor.execute("SELECT tech FROM Technology WHERE tech LIKE 'T_HDV_T_LH_BEV_%'").fetchall()]
    # Add or update LimitCapacity rows for each period and tech
    for period in period_list:
        for tech in techs:
            cursor.execute("""INSERT INTO LimitCapacity (region, period, tech_or_group, operator, capacity)
                           VALUES ('ON', ?, ?, 'le', 0)
                           ON CONFLICT(region, period, tech_or_group, operator) DO UPDATE SET capacity=0
                           """, (period, tech))
    conn.commit()

    # Only use H2 PEM
    for period in period_list:
        for tech in ["I_H2_ELC_ALK", "I_H2_SMR", "I_H2_SMR_CCS"]:
            cursor.execute("""INSERT INTO LimitCapacity (region, period, tech_or_group, operator, capacity)
                           VALUES ('ON', ?, ?, 'le', 0)
                           ON CONFLICT(region, period, tech_or_group, operator) DO UPDATE SET capacity=0
                           """, (period, tech))
    conn.commit()

    # Remove petroleum diesel
    for period in list(range(2040,2051,5)):
        cursor.execute("""INSERT INTO LimitActivity (region, period, tech_or_group, operator, activity)
                       VALUES ('ON', ?, ?, 'le', 0)""", (period, "T_IMP_DSL"))
    conn.commit()

conn.close()

# %%
# Try shutting off wind and solar on D204
# D204 has the highest long-haul HDT activity

# create a copy of the database
new_db_path = 'fnh.sqlite'
shutil.copy('soe.sqlite', new_db_path)

with sqlite3.connect(new_db_path) as conn:
    cursor = conn.cursor()
    cursor.execute("""UPDATE CapacityFactorProcess SET factor = 0 WHERE vintage >= 2030 AND season = 'D204' AND (tech LIKE 'E_SOL_PV%' OR tech LIKE 'E_WND_ON%')""")
    conn.commit()

conn.close()

# %% [markdown]
# ### Create database to get equivalent electricity, H2 and e-diesel costs
# Fuels and locations:
# - Electricity at the eRoads / charger head
# - H2 at the pump
# - E-diesel at the pump
#
# Cost ranges (convert to M$/PJ):
# - Electricity: 1 kWh = 3.6 MJ
# - H2: 1 kgH2 = 120 MJ LHV
# - E-diesel: 1 litre diesel = 36.1 MJ LHV (129488 Btu/gal)
#
# Electricity (tech='T_elc_bypass_{i}'):
# - input_comm: E_ethos
# - output_comm: commodity name LIKE 'T_elc_hdv_t_lh_chrg_%'
#
# H2 (tech='T_h2_bypass_{i}'):
# - input_comm: F_ethos
# - output_comm: commodity name = 'T_h2_hdv_t_lh'
#
# E-diesel (tech='T_ediesel_bypass_{i}'):
# - input_comm: F_ethos
# - output_comm: commodity name = 'T_dsl_rdsl04'
#
# Tables:
# - CostVariable
# - Efficiency
# - Technology: flag='p', annual='1', sector='transportation', unlim_cap=1
# - LimitActivity
#
# In CostVariable:
# - Notes column, add the \$/kWh, \$/kgH2 and \$/L e-diesel numbers
# - Expand period-vintage grid so each vintage has a cost across all subsequent periods

# %%
# Generate cost bins
# conversion (multiply) is to M$/PJ
n_bins = 20
bins = {'elc': {'cost': np.linspace(0, 0.4, n_bins), # in $/kWh
                'conversion': 1000/3.6, 'common_units': '$/kWh'},
        'h2': {'cost': np.linspace(0, 7, n_bins), # in $/kgH2
                'conversion': 1000/120, 'common_units': '$/kgH2'},
        'ediesel': {'cost': np.linspace(0, 4.0, n_bins), # in $/litre
                'conversion': 1000/36.1, 'common_units': '$/litre'},
}
# print(bins)

# generate tech names for each bin
tech_bins = {}
for fuel, cost_bins in bins.items():
    tech_bins[f'{fuel}'] = [f"T_{fuel.upper()}_BYPASS_{i}" for i in range(len(cost_bins['cost']))]
# print(tech_bins)

# Combine into a single dataframe
bypass_tech_df = pd.DataFrame({
    'tech': sum(tech_bins.values(), []),
    'fuel': sum([[fuel]* (len(cost_bins['cost'])) for fuel, cost_bins in bins.items()], []),
    # CostVariable is just values in bins.
    'CostVariable': sum([list(cost_bins['cost']*cost_bins['conversion']) for cost_bins in bins.values()], []),
    'CostVariable_common_units': sum([list(cost_bins['cost'].round(2).astype(str) + ' ' + cost_bins['common_units']) for cost_bins in bins.values()], []),
    'LimitActivity': 1/n_bins,    # Limit activity to 1 PJ for each fuel
})

# %%
# Prepare Efficiency, CostVariable, LimitActivity, Technology tables

with sqlite3.connect('xlv.sqlite') as conn:
    cursor = conn.cursor()
    commodities = pd.read_sql_query("SELECT name FROM Commodity", conn)['name'].tolist()
conn.close()

input_output_comms = {
    'elc': {'input_comm': 'E_ethos',
            'output_comm': [comm for comm in commodities if 'T_elc_hdv_t_lh_chrg_' in comm]},
    'h2': {'input_comm': 'F_ethos', 'output_comm': 'T_h2_hdv_t_lh'},
    'ediesel': {'input_comm': 'F_ethos', 'output_comm': 'T_dsl_rdsl04'},
}

# turn input_output_comms into a dataframe, unpack list as multiple rows, use pd.DataFrame()
efficiency_df = pd.DataFrame([
    {'fuel': fuel, 'input_comm': comms['input_comm'], 'output_comm': comm}
    for fuel, comms in input_output_comms.items()
    for comm in ([comms['output_comm']] if isinstance(comms['output_comm'], str) else comms['output_comm'])
]).assign(efficiency=1, region='ON')

costvariable_df = (bypass_tech_df[['tech', 'CostVariable', 'CostVariable_common_units']]
                   .rename(columns={'CostVariable': 'cost', 'CostVariable_common_units': 'notes'})
                   .assign(region='ON'))
limitactivity_df = (bypass_tech_df[['tech', 'LimitActivity']]
                    .rename(columns={'tech': 'tech_or_group', 'LimitActivity': 'activity'})
                    .assign(operator='le', region='ON'))
technology_df = bypass_tech_df[['tech']].assign(annual=1, unlim_cap=1, flag='p', sector='transportation')
lifetimetech_df = bypass_tech_df[['tech']].assign(lifetime=5, region='ON')

# copy efficiency_df for vintages 2025 - 2045
vintages = list(range(2025, 2050, 5))
efficiency_df = efficiency_df.merge(pd.DataFrame({'vintage': vintages}), how='cross')
costvariable_df = (costvariable_df.merge(pd.DataFrame({'vintage': vintages}), how='cross')
                   .assign(period=lambda x: x['vintage']))
limitactivity_df = limitactivity_df.merge(pd.DataFrame({'period': vintages}), how='cross')

# merge with bypass_tech_df to get tech names for each fuel
efficiency_df = (efficiency_df.merge(bypass_tech_df[['fuel', 'tech']], on='fuel', how='left')
                 .drop(columns='fuel'))

# %%
# create a copy of the database, use immediate charging database 
new_db_path = 'wtz.sqlite'
shutil.copy('xlv.sqlite', new_db_path)

with sqlite3.connect(new_db_path) as conn:
    cursor = conn.cursor()
    # insert tables: Technology, Efficiency, CostVariable, LimitActivity
    technology_df.to_sql('Technology', conn, if_exists='append', index=False)
    efficiency_df.to_sql('Efficiency', conn, if_exists='append', index=False)
    costvariable_df.to_sql('CostVariable', conn, if_exists='append', index=False)
    limitactivity_df.to_sql('LimitActivity', conn, if_exists='append', index=False)
    lifetimetech_df.to_sql('LifetimeTech', conn, if_exists='append', index=False)
    conn.commit()
    cursor.execute("VACUUM")
    conn.commit()
conn.close()

# %%
# another version without e-diesel
new_db_path = 'izo.sqlite'
shutil.copy('wtz.sqlite', new_db_path)

with sqlite3.connect(new_db_path) as conn:
    cursor = conn.cursor()
    # insert into LimitCapacity, set to 0 for all periods, all regions, tech_or_group = I_FT_RWGS, operator=le, capacity=0
    period_list = [row[0] for row in cursor.execute("SELECT DISTINCT period FROM LimitCapacity").fetchall()]
    for period in period_list:
        cursor.execute("""INSERT INTO LimitCapacity (region, period, tech_or_group, operator, capacity)
                       VALUES ('ON', ?, 'I_FT_RWGS', 'le', 0)""", (period,))
    conn.commit()
    cursor.execute("VACUUM")
    conn.commit()
conn.close()

# %%
# another version with e-diesel, but without eRoads
new_db_path = 'xnc.sqlite'
shutil.copy('wtz.sqlite', new_db_path)

with sqlite3.connect(new_db_path) as conn:
    cursor = conn.cursor()
    # UPDATE LimitCapacity, set to 0 WHERE tech_or_group LIKE 'T_HDV_T_LH_CHRG_ERDS%'
    cursor.execute("UPDATE LimitCapacity SET capacity = 0 WHERE tech_or_group LIKE 'T_HDV_T_LH_CHRG_ERDS%'")
    conn.commit()
    cursor.execute("VACUUM")
    conn.commit()
conn.close()

# %% [markdown]
# ### Create database to extract upstream commodity costs
# - Use dummy technologies and unit dummy demand
# - For each commodity to target, create a demand version with unit demand (e.g. 1 PJ)
# - Just copy rows with target tech in all tables that have output_comm? (e.g. Efficiency, Input/OutputSplit, ...)
# - Link existing technologies to also supply the dummy unit demand
# - Create $n$ dummy technologies with $n$ variable cost levels to also supply the dummy unit demand
#
# Commodities to target:
# - Electricity before charging infra: T_elc, supplied by E_T_ELC
# - Electricity after charging infra: T_elc_hdv_t_lh_chrg_%, supplied by T_HDV_T_LH_CHRG_% respectively
# - Electricity going to electrolyzers: I_elc_dc, supplied by I_ELC_AC_DC
# - H2 after electrolyzers: I_h2, supplied by I_H2_ELC_%
# - H2 after distribution, compression: T_h2_700, supplied by I_H2_COMP_100_700
# - H2 at the refueling station nozzle: T_h2_ldv, T_h2_mdv, T_h2_hdv, T_h2_hdv_t_lh,
#     - Supplied by T_H2_LDV_REFUEL, T_H2_MDV_REFUEL, T_H2_HDV_REFUEL, T_H2_HDV_T_LH_REFUEL respectively
# - E-diesel at the plant gate: T_dsl, supplied by I_FT_RWGS
#     - Note: How to handle multiple input_comm? TechInputSplit?
#
# Tables:
# - Commodity: to add dummy unit demand
# - Demand: to add dummy unit demand
# - Technology: to add $n$ dummy techs
# - Efficiency: to link $n$ dummy techs, existing tech
# - CostVariable: add range of costs for $n$ dummy techs
# - LimitActivity: set limit activity for dummy techs ($1/n$)

# %%
# This version creates a transfer technology linking output_comm to the dummy unit demand.
# It does not duplicate the target technology.

def create_database_transfer_tech(old_db_path, new_db_path, df_target_tech, bins, create_dummy_techs=True, print_messages=False):
    """
    Creates a new database based on old_db_path, adding dummy technologies for each technology in df_target_tech.

    Inputs:
    - old_db_path: path to existing database to copy and modify
    - new_db_path: path to new database to create
    - df_target_tech: DataFrame. Should have columns 'target_techs' and 'fuel'. Target_techs can contain exact tech names or patterns with '%'. Fuel should be one of the keys in bins.
    - bins: dictionary with fuel as key, and values as a dictionary with keys 'cost' (array of costs for each bin), 'conversion' (multiplier to convert cost to $/PJ), and 'common_units' (string for units to put in notes).
    - create_dummy_techs: if True, creates n_bins dummy technologies for each target technology. If False, only creates the transfer technology without creating dummy technologies.
    - print_messages: if True, prints messages about the process.
    
    Returns nothing.
    """

    shutil.copy(old_db_path, new_db_path)
    print(f"Copied {old_db_path} to {new_db_path}")

    with sqlite3.connect(new_db_path) as conn:
        cursor = conn.cursor()

        # get all periods in Demand table
        periods = [row[0] for row in cursor.execute("SELECT DISTINCT period FROM Demand").fetchall()]            

        # turn target_techs into a list of technologies. If an item contains '%', treat it as a LIKE pattern, otherwise exact match
        print("Processing target technologies:", df_target_tech['target_techs'].tolist())
        tech_fuel_list = []
        for item, fuel in df_target_tech.itertuples(index=False):
            if '%' in item:
                new_techs = [row[0] for row in cursor.execute("SELECT tech FROM Technology WHERE tech LIKE ?", (item,)).fetchall()]
                tech_fuel_list += [(tech, fuel) for tech in new_techs]
            else: tech_fuel_list.append((item, fuel))
        
        # get Efficiency table
        df_eff_all = pd.read_sql_query("SELECT * FROM Efficiency", conn)

        # For each tech in tech_list, and each table in tables_output_comm, check the efficiency table if the tech has a unique output_comm.
        # If there are multiple output_comms, print a warning and skip.
        for tech, fuel in tech_fuel_list:
            df_eff = df_eff_all[df_eff_all['tech'] == tech]
            if len(df_eff) == 0: continue
            output_comms = df_eff['output_comm'].unique()
            if len(output_comms) > 1: 
                if print_messages: 
                    print(f"Warning: {tech} has multiple output_comms: {output_comms}. Skipping {table}.")
                    continue
            else: 
                if print_messages: print(f"{tech} has unique output_comm: {output_comms[0]}")
                
                output_comm_dummy = output_comms[0] + '_dummy'
                tech_transfer = output_comms[0] + '_transfer'

                # For output_comm_dummy, add Commodity and Demand tables
                if print_messages: print('Adding Commodity and Demand for output_comm_dummy:', output_comm_dummy)
                # if output_comm_dummy not in Commodity table,
                if cursor.execute("SELECT COUNT(*) FROM Commodity WHERE name = ?", (output_comm_dummy,)).fetchone()[0] == 0:
                    cursor.execute("INSERT INTO Commodity (name, flag) VALUES (?, 'd')", (output_comm_dummy,))
                    for period in periods: cursor.execute("INSERT INTO Demand (region, period, commodity, demand) VALUES ('ON', ?, ?, 1)", (period, output_comm_dummy))
                
                    # Create the transfer technology
                    if print_messages: print('Adding transfer technology for tech:', tech, 'with input_comm:', output_comms[0], 'and output_comm:', output_comm_dummy)
                    cursor.execute("INSERT INTO Technology (tech, flag, sector, unlim_cap, annual) VALUES (?, 'p', 'dummy', 1, 1)", (tech_transfer,))
                    cursor.execute("INSERT INTO Efficiency (region, input_comm, tech, vintage, output_comm, efficiency) VALUES ('ON', ?, ?, 2025, ?, 1)", 
                                (output_comms[0], tech_transfer, output_comm_dummy))
                conn.commit()

                if create_dummy_techs:
                    # Create a range of n dummy technologies with different costs, add to CostVariable, and set LimitActivity to 1/n_bins for each. Use the same output_comm_dummy for all dummy techs.
                    # check if dummy tech already exists in Technology table
                    if cursor.execute("SELECT COUNT(*) FROM Technology WHERE tech LIKE ?", (f"{output_comm_dummy}_%",)).fetchone()[0] == 0:
                        print('Adding dummy technologies for output_comm_dummy:', output_comm_dummy)
                        # extract number of bins from bins dictionary for the fuel
                        n_bins = len(bins[fuel]['cost'])
                        for i in range(n_bins):
                            tech_dummy = output_comm_dummy + f"_{i}"
                            cost = bins[fuel]['cost'][i] * bins[fuel]['conversion']
                            notes = f"{bins[fuel]['cost'][i]:.2f} {bins[fuel]['common_units']}"
                            cursor.execute("INSERT INTO Technology (tech, flag, sector, unlim_cap, annual) VALUES (?, 'p', 'dummy', 1, 1)", (tech_dummy,))
                            cursor.execute("INSERT INTO Efficiency (region, input_comm, tech, vintage, output_comm, efficiency) VALUES ('ON', ?, ?, 2025, ?, 1)",
                                        ('F_ethos', tech_dummy, output_comm_dummy))
                            for period in periods:
                                cursor.execute("INSERT INTO CostVariable (region, period, tech, vintage, cost, notes) VALUES ('ON', ?, ?, 2025, ?, ?)", (period, tech_dummy, cost, notes))
                                cursor.execute("INSERT INTO LimitActivity (region, period, tech_or_group, operator, activity) VALUES ('ON', ?, ?, 'le', ?)", (period, tech_dummy, 1/n_bins))
                        conn.commit()
                    else: print(f"Dummy technologies for {output_comm_dummy} already exist. Skipping creation.")
        conn.commit()
        cursor.execute("VACUUM")
        conn.commit()
    conn.close()

# %%
# define target technologies and their corresponding fuels
df = pd.DataFrame({'target_techs': ['E_T_ELC', 'T_HDV_T_LH_CHRG_%', 'I_ELC_AC_DC', 'I_H2_ELC_%', 'I_H2_COMP_100_700', '%_REFUEL', 'I_FT_RWGS'],
                   'fuel': ['elc', 'elc', 'elc', 'h2', 'h2', 'h2', 'ediesel']})

n_bins = 21    # number of cost bins for each fuel
bins = {'elc': {'cost': np.linspace(0, 0.6, n_bins), # in $/kWh
                'conversion': 1000/3.6, 'common_units': '$/kWh'},
        'h2': {'cost': np.linspace(0, 10, n_bins), # in $/kgH2
                'conversion': 1000/120, 'common_units': '$/kgH2'},
        'ediesel': {'cost': np.linspace(0, 4, n_bins), # in $/litre
                'conversion': 1000/36.1, 'common_units': '$/litre'},
}

# %%
# Immediate
create_database_transfer_tech(old_db_path='xlv.sqlite', new_db_path='lii.sqlite', 
                              df_target_tech=df, bins=bins, create_dummy_techs=True, print_messages=True)
# Flat
create_database_transfer_tech(old_db_path='roa.sqlite', new_db_path='kki.sqlite', 
                              df_target_tech=df, bins=bins, create_dummy_techs=True, print_messages=True)

# Immediate without dummy techs, for inspecting duals
create_database_transfer_tech(old_db_path='xlv.sqlite', new_db_path='oqh.sqlite', 
                              df_target_tech=df, bins=bins, create_dummy_techs=False, print_messages=True)
# Out:
# Copied xlv.sqlite to lii.sqlite
# Processing target technologies: ['E_T_ELC', 'T_HDV_T_LH_CHRG_%', 'I_ELC_AC_DC', 'I_H2_ELC_%', 'I_H2_COMP_100_700', '%_REFUEL', 'I_FT_RWGS']
# E_T_ELC has unique output_comm: T_elc
# Adding Commodity and Demand for output_comm_dummy: T_elc_dummy
# Adding transfer technology for tech: E_T_ELC with input_comm: T_elc and output_comm: T_elc_dummy
# Adding dummy technologies for output_comm_dummy: T_elc_dummy
# T_HDV_T_LH_CHRG_ERDS1 has unique output_comm: T_elc_hdv_t_lh_chrg_erds1
# Adding Commodity and Demand for output_comm_dummy: T_elc_hdv_t_lh_chrg_erds1_dummy
# Adding transfer technology for tech: T_HDV_T_LH_CHRG_ERDS1 with input_comm: T_elc_hdv_t_lh_chrg_erds1 and output_comm: T_elc_hdv_t_lh_chrg_erds1_dummy
# Adding dummy technologies for output_comm_dummy: T_elc_hdv_t_lh_chrg_erds1_dummy
# T_HDV_T_LH_CHRG_ERDS2 has unique output_comm: T_elc_hdv_t_lh_chrg_erds2
# Adding Commodity and Demand for output_comm_dummy: T_elc_hdv_t_lh_chrg_erds2_dummy
# ...

# %%
# This version makes a duplicate of each target technology.

#df_dummy_tech = []

# with sqlite3.connect(new_db_path) as conn:
#     cursor = conn.cursor()

#     # get all periods in Demand table
#     periods = [row[0] for row in cursor.execute("SELECT DISTINCT period FROM Demand").fetchall()]            

#     # turn target_techs into a list of technologies. If an item contains '%', treat it as a LIKE pattern, otherwise exact match
#     tech_fuel_list = []
#     for item, fuel in df.itertuples(index=False):
#         if '%' in item:
#             new_techs = [row[0] for row in cursor.execute("SELECT tech FROM Technology WHERE tech LIKE ?", (item,)).fetchall()]
#             tech_fuel_list += [(tech, fuel) for tech in new_techs]
#         else: tech_fuel_list.append((item, fuel))

#     # Search all tables, get those with column 'output_comm'
#     tables_output_comm = []
#     for table in [row[0] for row in cursor.execute("SELECT name FROM sqlite_master WHERE type='table'").fetchall()]:
#         columns = [row[1] for row in cursor.execute(f"PRAGMA table_info({table});").fetchall()]
#         # if ('output_comm' in columns) and not table.startswith('Output'):
#         if ('tech' in columns or 'tech_or_group' in columns) and not table.startswith('Output'): 
#             tables_output_comm.append(table)
    
#     # get Efficiency table
#     df_eff_all = pd.read_sql_query("SELECT * FROM Efficiency", conn)

#     # For each tech in tech_list, and each table in tables_output_comm, check the efficiency table if the tech has a unique output_comm.
#     # If there are multiple output_comms, print a warning and skip.
#     for tech, fuel in tech_fuel_list:
#         df_eff = df_eff_all[df_eff_all['tech'] == tech]
#         if len(df_eff) == 0: continue
#         output_comms = df_eff['output_comm'].unique()
#         if len(output_comms) > 1: 
#             if print_messages: 
#                 print(f"Warning: {tech} has multiple output_comms: {output_comms}. Skipping {table}.")
#                 continue
#         else: 
#             if print_messages: 
#                 print(f"{tech} has unique output_comm: {output_comms[0]}")
#                 print('Duplicating rows for tech:', tech, 'in tables:', tables_output_comm)
#             # for each table in tables_output_comm, duplicate rows where tech = tech, change output_comm to output_comms[0] + 'dummy', and insert back into the same table
#             output_comm_dummy = output_comms[0] + '_dummy'
#             tech_duplicated = tech + '_duplicated'
#             for table in tables_output_comm:
#                 try:
#                     df_table = pd.read_sql_query(f"SELECT * FROM {table}", conn)
#                     if len(df_table) == 0: continue
#                     if 'tech' in df_table.columns: 
#                         df_table = df_table[df_table['tech'] == tech]
#                         df_table['tech'] = tech_duplicated
#                     if 'tech_or_group' in df_table.columns: 
#                         df_table = df_table[df_table['tech_or_group'] == tech]
#                         df_table['tech_or_group'] = tech_duplicated
#                     if 'output_comm' in df_table.columns: df_table['output_comm'] = output_comm_dummy
#                     df_table.to_sql(table, conn, if_exists='append', index=False)
#                 except Exception as e: print(f"Skipping {table} for {tech}: {e}")
#             conn.commit()

#             # For output_comm_dummy, add Commodity and Demand tables
#             if print_messages: print('Adding Commodity and Demand for output_comm_dummy:', output_comm_dummy)
#             # if output_comm_dummy not in Commodity table,
#             if cursor.execute("SELECT COUNT(*) FROM Commodity WHERE name = ?", (output_comm_dummy,)).fetchone()[0] == 0:
#                 cursor.execute("INSERT INTO Commodity (name, flag) VALUES (?, 'd')", (output_comm_dummy,))
#                 for period in periods: cursor.execute("INSERT INTO Demand (region, period, commodity, demand) VALUES ('ON', ?, ?, 1)", (period, output_comm_dummy))
#             conn.commit()
            
#             # Create a range of n dummy technologies with different costs, add to CostVariable, and set LimitActivity to 1/n_bins for each. Use the same output_comm_dummy for all dummy techs.
#             # check if dummy tech already exists in Technology table
#             if cursor.execute("SELECT COUNT(*) FROM Technology WHERE tech LIKE ?", (f"{output_comm_dummy}_%",)).fetchone()[0] == 0:
#                 print('Adding dummy technologies for output_comm_dummy:', output_comm_dummy)
#                 for i in range(n_bins):
#                     tech_dummy = output_comm_dummy + f"_{i}"
#                     cost = bins[fuel]['cost'][i] * bins[fuel]['conversion']
#                     notes = f"{bins[fuel]['cost'][i]:.2f} {bins[fuel]['common_units']}"
#                     cursor.execute("INSERT INTO Technology (tech, flag, sector, unlim_cap, annual) VALUES (?, 'p', 'transportation', 1, 1)", (tech_dummy,))
#                     cursor.execute("INSERT INTO Efficiency (region, input_comm, tech, vintage, output_comm, efficiency) VALUES ('ON', ?, ?, 2025, ?, 1)", 
#                                 ('F_ethos', tech_dummy, output_comm_dummy))
#                     for period in periods:
#                         cursor.execute("INSERT INTO CostVariable (region, period, tech, vintage, cost, notes) VALUES ('ON', ?, ?, 2025, ?, ?)", (period, tech_dummy, cost, notes))
#                         cursor.execute("INSERT INTO LimitActivity (region, period, tech_or_group, operator, activity) VALUES ('ON', ?, ?, 'le', ?)", (period, tech_dummy, 1/n_bins))
#                 conn.commit()
#             else: print(f"Dummy technologies for {output_comm_dummy} already exist. Skipping creation.")

#             # get efficiency where output_comm = output_comm_dummy
#             #df_dummy_tech += [(pd.read_sql_query("SELECT * FROM Efficiency WHERE output_comm = ?", conn, params=(output_comm_dummy,))
#             #                   .assign(fuel=fuel))]
            
#     conn.commit()
#     cursor.execute("VACUUM")
#     conn.commit()
# conn.close()

# #df_dummy_tech = pd.concat(df_dummy_tech, ignore_index=True)
# Out:
# Adding dummy technologies for output_comm_dummy: T_elc_dummy
# Adding dummy technologies for output_comm_dummy: T_elc_hdv_t_lh_chrg_erds1_dummy
# Adding dummy technologies for output_comm_dummy: T_elc_hdv_t_lh_chrg_erds2_dummy
# Adding dummy technologies for output_comm_dummy: T_elc_hdv_t_lh_chrg_erds3_dummy
# Adding dummy technologies for output_comm_dummy: T_elc_hdv_t_lh_chrg_erds4_dummy
# Adding dummy technologies for output_comm_dummy: T_elc_hdv_t_lh_chrg_erds5_dummy
# Adding dummy technologies for output_comm_dummy: T_elc_hdv_t_lh_chrg_fstchrg_dummy
# Adding dummy technologies for output_comm_dummy: T_elc_hdv_t_lh_chrg_lrgbatt_dummy
# Adding dummy technologies for output_comm_dummy: I_elc_dc_dummy
# Adding dummy technologies for output_comm_dummy: I_h2_dummy
# Dummy technologies for I_h2_dummy already exist. Skipping creation.
# Adding dummy technologies for output_comm_dummy: T_h2_700_dummy
# Adding dummy technologies for output_comm_dummy: T_h2_hdv_dummy
# ...

# %% [markdown]
# ### [unused] Remove annual capacity factor constraints, capfactech to test
# Don't need this any more since rescaling helped achieve optimal termination

# %%
'''
db_path = 'canoe_on_16d_baseline_newtech_atriprofiles_v3_1.sqlite'

with sqlite3.connect(db_path) as conn:
    cursor = conn.cursor()
    cursor.execute("""
        DELETE FROM LimitAnnualCapacityFactor
        WHERE tech LIKE 'T_HDV_T_LH_CHRG_%' OR tech LIKE 'T_H2_HDV_T_LH_REFUEL'
    """)

    cursor.execute("""
        DELETE FROM CapacityFactorTech
        WHERE tech LIKE 'T_HDV_T_LH_CHRG_%' OR tech LIKE 'T_H2_HDV_T_LH_REFUEL'
    """)

    conn.commit()
'''
# Out:
# '\ndb_path = \'canoe_on_16d_baseline_newtech_atriprofiles_v3_1.sqlite\'\n\nwith sqlite3.connect(db_path) as conn:\n    cursor = conn.cursor()\n    cursor.execute("""\n        DELETE FROM LimitAnnualCapacityFactor\n        WHERE tech LIKE \'T_HDV_T_LH_CHRG_%\' OR tech LIKE \'T_H2_HDV_T_LH_REFUEL\'\n    """)\n\n    cursor.execute("""\n        DELETE FROM CapacityFactorTech\n        WHERE tech LIKE \'T_HDV_T_LH_CHRG_%\' OR tech LIKE \'T_H2_HDV_T_LH_REFUEL\'\n    """)\n\n    conn.commit()\n'

# %% [markdown]
# ### [unused] Force eRoads bin 2 for flat profile

# %%
'''
db_path = 'canoe_on_12d_baseline_newtech_flat.sqlite'
with sqlite3.connect(db_path) as conn:
    cursor = conn.cursor()

    cursor.execute("""
            INSERT OR IGNORE INTO MinCapacity (region, period, tech, min_cap, units) 
            VALUES ('ON', 2050, 'T_HDV_T_LH_CHRG_ERDS2', 838, 'km')
        """)
    conn.commit()
conn.close()
'''
# Out:
# '\ndb_path = \'canoe_on_12d_baseline_newtech_flat.sqlite\'\nwith sqlite3.connect(db_path) as conn:\n    cursor = conn.cursor()\n\n    cursor.execute("""\n            INSERT OR IGNORE INTO MinCapacity (region, period, tech, min_cap, units) \n            VALUES (\'ON\', 2050, \'T_HDV_T_LH_CHRG_ERDS2\', 838, \'km\')\n        """)\n    conn.commit()\nconn.close()\n'

# %% [markdown]
# ###  [unused] Ethos for transportation electricity (T_elc) for testing, isolating electricity system effects
# - Create a source commodity: T_elc_ethos
# - Create a technology (T_IMP_T_ELC) supplying T_elc_ethos -> T_elc
# - unlim_cap = 1, annual = 0
# - Tech T_IMP_T_ELC, Efficiency = 1

# %%
'''
for db_path in db_path_list:
    with sqlite3.connect(db_path) as conn:
        cursor = conn.cursor()
        
        # Add T_elc_ethos to Commodity table
        cursor.execute("""
            INSERT OR IGNORE INTO Commodity (name, flag) 
            VALUES ('T_elc_ethos', 's')
        """)

        # Add technology to import from ethos
        cursor.execute("""
            INSERT OR IGNORE INTO Technology (tech, flag, sector, unlim_cap, annual) 
            VALUES ('T_IMP_T_ELC', 'r', 'Transport', 1, 0)
        """)

        # Add efficiency for T_IMP_T_ELC
        cursor.execute("""
            INSERT OR IGNORE INTO Efficiency (region, input_comm, tech, vintage, output_comm, efficiency) 
            VALUES ('ON', 'T_elc_ethos', 'T_IMP_T_ELC', 2021, 'T_elc', 1)
        """)
        conn.commit()
    conn.close()
conn.close()
'''
# Out:
# '\nfor db_path in db_path_list:\n    with sqlite3.connect(db_path) as conn:\n        cursor = conn.cursor()\n\n        # Add T_elc_ethos to Commodity table\n        cursor.execute("""\n            INSERT OR IGNORE INTO Commodity (name, flag) \n            VALUES (\'T_elc_ethos\', \'s\')\n        """)\n\n        # Add technology to import from ethos\n        cursor.execute("""\n            INSERT OR IGNORE INTO Technology (tech, flag, sector, unlim_cap, annual) \n            VALUES (\'T_IMP_T_ELC\', \'r\', \'Transport\', 1, 0)\n        """)\n\n        # Add efficiency for T_IMP_T_ELC\n        cursor.execute("""\n            INSERT OR IGNORE INTO Efficiency (region, input_comm, tech, vintage, output_comm, efficiency) \n            VALUES (\'ON\', \'T_elc_ethos\', \'T_IMP_T_ELC\', 2021, \'T_elc\', 1)\n        """)\n        conn.commit()\n    conn.close()\nconn.close()\n'

# %% [markdown]
# ### [unused] Set fast charger cost invest to zero

# %%
'''
for db_path in db_path_list:
    with sqlite3.connect(db_path) as conn:
        cursor = conn.cursor()

        # set cf_fixed to NULL for technologies with HDV_T_LH in their name
        cursor.execute("""
            UPDATE CostInvest
            SET cost = 0
            WHERE tech LIKE 'T_HDV_T_LH_CHRG_FSTCHRG'
            """)
        conn.commit()
    conn.close()
conn.close()
'''
# Out:
# '\nfor db_path in db_path_list:\n    with sqlite3.connect(db_path) as conn:\n        cursor = conn.cursor()\n\n        # set cf_fixed to NULL for technologies with HDV_T_LH in their name\n        cursor.execute("""\n            UPDATE CostInvest\n            SET cost = 0\n            WHERE tech LIKE \'T_HDV_T_LH_CHRG_FSTCHRG\'\n            """)\n        conn.commit()\n    conn.close()\nconn.close()\n'

# %% [markdown]
# ### [unused] Make database compatible with CANOE-main/temoa branch 1.0.0-dev-operator

# %%
# Compare databases: existing vs. v3.1
'''
db_path_list = ['canoe_on_16d_baseline_newtech_flat.sqlite', '../../temoa-canoe-nlp/temoa_v3_1.sqlite']

for i in range(len(db_path_list)):
    for j in range(i+1, len(db_path_list)):
        print(f"\n🔄 Comparing {db_path_list[i]} vs {db_path_list[j]}")
        results = lihwei_db_edits.compare_sqlite_databases(db_path_list[i], db_path_list[j])
        lihwei_db_edits.print_comparison_summary(results)
'''
# Out:
# '\ndb_path_list = [\'canoe_on_16d_baseline_newtech_flat.sqlite\', \'../../temoa-canoe-nlp/temoa_v3_1.sqlite\']\n\nfor i in range(len(db_path_list)):\n    for j in range(i+1, len(db_path_list)):\n        print(f"\n🔄 Comparing {db_path_list[i]} vs {db_path_list[j]}")\n        results = lihwei_db_edits.compare_sqlite_databases(db_path_list[i], db_path_list[j])\n        lihwei_db_edits.print_comparison_summary(results)\n'

# %%
# find differences in columns across databases
'''
for table, schema in results['schema_differences'].items():
    db1_cols = set([col[1] for col in schema['db1_schema']])
    db2_cols = set([col[1] for col in schema['db2_schema']])
    
    if db2_cols - db1_cols:
        print(f"{table} Columns in db2 but not in db1: {db2_cols - db1_cols}") 
'''
# Out:
# PlanningReserveMargin Columns in db2 but not in db1: {'notes'}
# CapacityFactorTech Columns in db2 but not in db1: {'notes'}
# OutputRetiredCapacity Columns in db2 but not in db1: {'cap_eol', 'cap_early'}
# TimeSeason Columns in db2 but not in db1: {'notes'}
# SectorLabel Columns in db2 but not in db1: {'notes'}
# Region Columns in db2 but not in db1: {'notes'}
# OutputCost Columns in db2 but not in db1: {'sector'}

# %%
# Add missing columns to the database
"""
db_path_list = ['canoe_on_16d_baseline_newtech_atriprofiles.sqlite',
                'canoe_on_16d_baseline_newtech_flat.sqlite',
                'canoe_on_16d_baseline_newtech_simplemiddaypeak.sqlite',
                'canoe_on_16d_baseline_newtech_solarflip.sqlite'
                ]
"""

'''
db_path_list = ['canoe_on_16d_baseline_newtech_solarfreeflip.sqlite']

for db_path in db_path_list:
    with sqlite3.connect(db_path) as conn:
        cursor = conn.cursor()

        # Add column seas_stor and set all to 0
        # Check if seas_stor column exists in Technology table
        cursor.execute("PRAGMA table_info(Technology)")
        columns = [row[1] for row in cursor.fetchall()]
        
        if 'seas_stor' not in columns:
            cursor.execute("ALTER TABLE Technology ADD COLUMN seas_stor INTEGER NOT NULL DEFAULT 0;")
            cursor.execute("UPDATE Technology SET seas_stor = 0;")
            
        # ==========
        # remove rows in Efficiency table where input_comm='R_elc' and output_comm='R_elc' and notes='arbitrarily small non-zero efficiency'
        cursor.execute("""
                DELETE FROM Efficiency WHERE 
                       input_comm='R_elc' AND output_comm='R_elc' AND notes='arbitrarily small non-zero efficiency';
                """)
        
        # ==========
        # Set all demand techs where output_comm are demand commodities, set annual=1
        cursor.execute("""UPDATE Technology SET annual = 1 WHERE tech IN 
                       (SELECT DISTINCT tech FROM Efficiency WHERE output_comm IN
                       (SELECT name FROM Commodity WHERE flag='d'))
                       """)
        # Also set annual=1 for specific technologies
        tech_exact = ["H2_distribution", "I_H2_SMR", "I_H2_SMR_CCS", "T_LDV_M_BEV_N"]
        tech_like = ["T_LDV_C_BEV%", "T_LDV_LTF_BEV%", "T_LDV_LTP_BEV%"]
        # Update for exact matches
        cursor.execute(f"UPDATE Technology SET annual = 1 WHERE tech IN ({','.join(['?'] * len(tech_exact))})", tech_exact)
        # Update for LIKE patterns
        for pattern in tech_like: cursor.execute("UPDATE Technology SET annual = 1 WHERE tech LIKE ?", (pattern,))
        conn.commit()
        
        # ==========
        # Moving rows from TechInputSplit to TechInputSplitAverage for annual and demand technologies
        # List of additional techs to move
        extra_techs = ["I_PULPPAPER_GEN","I_SMELTING_GEN", "I_STEEL_GEN", "I_MANUF-OTH_GEN", "I_CHEMICAL_GEN",
                       "I_CEMENT_GEN", "I_MINING_GEN", "C_OTHER", "I_REFINERY"]
        placeholders = ','.join(['?'] * len(extra_techs))

        # Move annual technologies (Technology WHERE annual=1) in TechInputSplit to TechInputSplitAverage
        cursor.execute("""
            INSERT INTO TechInputSplitAverage
            SELECT tis.* FROM TechInputSplit tis
            JOIN Technology t ON tis.tech = t.tech WHERE t.annual = 1;
        """)
        # Also move rows where tech is in extra_techs
        cursor.execute(f"INSERT INTO TechInputSplitAverage SELECT * FROM TechInputSplit WHERE tech IN ({placeholders});", extra_techs)

        # Remove those rows from TechInputSplit
        cursor.execute("DELETE FROM TechInputSplit WHERE tech IN (SELECT tech FROM Technology WHERE annual = 1);")
        cursor.execute(f"DELETE FROM TechInputSplit WHERE tech IN ({placeholders});", extra_techs)

        conn.commit()
        
        # ==========
        # Switch commodities to annual commodities that are produced by annual technologies AND are orginally flag = 'p'
        cursor.execute("""UPDATE Commodity SET flag = 'a' WHERE name IN 
                       (SELECT DISTINCT output_comm FROM Efficiency WHERE tech IN (SELECT tech FROM Technology WHERE annual=1))
                       AND flag = 'p'
                       """)
        # also switch "T_elc_ldv_bev_chrg", "h2" to annual
        cursor.execute("""UPDATE Commodity SET flag = 'a' WHERE name IN ('T_elc_ldv_bev_chrg', 'h2')""")
        
        
        # # Get unique periods from Demand table
        # unique_periods = pd.read_sql_query("SELECT DISTINCT period FROM Demand", conn)
        
        # # Add periods for TimeSegmentFraction, TimeSeason, CapacityFactorTech', 'CapacityFactorProcess', 'DemandSpecificDistribution'
        # for table_name in ['TimeSegmentFraction', 'TimeSeason', 'CapacityFactorTech', 'CapacityFactorProcess', 'DemandSpecificDistribution']:
        #     # Check if period column exists in table
        #     cursor.execute(f"PRAGMA table_info({table_name})")
        #     columns = [row[1] for row in cursor.fetchall()]
        #     print(f"{table_name}: {columns}")
        #     if 'period' not in columns:
        #         # If not, add the period column
        #         print(f"Adding period column to {table_name}")
        #         # Get existing data
        #         existing_data = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)
        #         # Clear existing data
        #         cursor.execute(f"DELETE FROM {table_name}")
        #         # Add period column
        #         cursor.execute(f"ALTER TABLE {table_name} ADD COLUMN period INTEGER;")

        #         # Create copies for each period
        #         df_with_period = existing_data.merge(unique_periods, how='cross')
        #         df_with_period.to_sql(table_name, conn, if_exists='append', index=False)
        
        # # No more resource technologies, change all resource technologies to production technologies
        # cursor.execute("""
        #     UPDATE Technology SET flag='p' WHERE flag='r'
        #     """)
        
    
        conn.commit()
    conn.close()
conn.close()
'''

# %%
# Use db_migration_v3_to_v3_1.py to convert databases to v3.1. Uses the 'temoa' conda environment

# temoa working directory
'''
temoa_wd = "C:/Users/yeowl/OneDrive - University of Toronto/1UofT/PhD Research/CANOE/temoa-1.0.0-dev-operator/temoa"

script_path = "temoa/utilities/db_migration_v3_to_v3_1.py"

for db_path in db_path_list:
    full_db_path = os.path.join(os.getcwd(), db_path)
    print(f"Running migration for {full_db_path}...")
    result = subprocess.run(f"conda run -n temoa python {script_path} --source \"{full_db_path}\"",
                            cwd=temoa_wd, capture_output=True, text=True, shell=True)
    print(result.stdout)
    if result.stderr:
        print("Error:", result.stderr)
'''
# Out:
# Running migration for c:\Users\yeowl\OneDrive - University of Toronto\1UofT\PhD Research\CANOE\CANOE-transportation\lihwei_db_edits\canoe_on_16d_baseline_newtech_solarfreeflip.sqlite...
#
#  --- Collapsing Max/Min tables and adding operators ---
# No data for: EmissionLimit
# No data for: TechOutputSplit
# TABLE NOT FOUND: TechInputSplitAnnual
# Transfered 833 rows from TechInputSplitAverage to LimitTechInputSplitAnnual
# Transfered 14 rows from TechInputSplit to LimitTechInputSplit
# Transfered 21 rows from MinNewCapacityShare to LimitNewCapacityShare
# Transfered 5 rows from MinNewCapacityGroupShare to LimitNewCapacityShare
# No data for: MinNewCapacityGroup
# No data for: MinNewCapacity
# No data for: MinCapacityShare
# No data for: MinCapacityGroup
# No data for: MinCapacity
# Transfered 1000 rows from MinAnnualCapacityFactor to LimitAnnualCapacityFactor
# No data for: MinActivityShare
# No data for: MinActivityGroup
# No data for: MinActivity
# No data for: MaxNewCapacityShare
# ...

# %% [markdown]
# # Create database for Method of Morris (MM) analysis
# - Use database with ATRI profiles
# - Add column 'MMAnalysis'
# - Test: perturb CostInvest for plug-in fast chargers by +/- 50%

# %%
# Make a copy of 'canoe_on_16d_baseline_newtech_atriprofiles_v3_1.sqlite' database
new_db_path = 'canoe_on_16d_baseline_newtech_atriprofiles_v3_1_MM.sqlite'
shutil.copy('canoe_on_16d_baseline_newtech_atriprofiles_v3_1.sqlite', new_db_path)    # Make a copy

with sqlite3.connect(new_db_path) as conn:
    cursor = conn.cursor()

    # add column MMAnalysis (TEXT, allow NULL) to CostInvest, CostVariable, Efficiency tables
    tables_to_modify = ['CostInvest', 'CostVariable', 'Efficiency']
    for table in tables_to_modify:
        # Check if MMAnalysis column exists
        cursor.execute(f"PRAGMA table_info({table})")
        columns = [row[1] for row in cursor.fetchall()]
        if 'MMAnalysis' not in columns:
            cursor.execute(f"ALTER TABLE {table} ADD COLUMN MMAnalysis TEXT;")

    # for tech LIKE '%_FSTCHRG', set MMAnalysis = 'CostInvest' + tech
    cursor.execute("""
        UPDATE CostInvest 
        SET MMAnalysis = 'CostInvest_' || tech 
        WHERE tech LIKE '%_FSTCHRG%'
        """)
    
    conn.commit()

# %% [markdown]
# # Compare sqlite databases

# %%
# Compare specific databases from your db_path_list
db_path_list = ['canoe_on_16d_baseline_newtech_flat_v3_1.sqlite',
                'canoe_on_16d_baseline_newtech_flat_v3_1_solved_20250829.sqlite']

# Compare all combinations of databases
for i in range(len(db_path_list)):
    for j in range(i+1, len(db_path_list)):
        print(f"\n🔄 Comparing {db_path_list[i]} vs {db_path_list[j]}")
        results = lihwei_db_edits.compare_sqlite_databases(db_path_list[i], db_path_list[j])
        lihwei_db_edits.print_comparison_summary(results)
# Out:
# 🔄 Comparing canoe_on_16d_baseline_newtech_flat_v3_1.sqlite vs canoe_on_16d_baseline_newtech_flat_v3_1_solved_20250829.sqlite
# Comparing table: ConstructionInput
# Comparing table: TimePeriod
# Comparing table: LifetimeProcess
# Comparing table: OutputNetCapacity
# Comparing table: TechGroup
# Comparing table: LimitDegrowthCapacity
# Comparing table: LimitEmission
# Comparing table: CapacityCredit
# Comparing table: LimitActivity
# Comparing table: SectorLabel
# Comparing table: LimitGrowthNewCapacityDelta
# Comparing table: LimitAnnualCapacityFactor
# Comparing table: Efficiency
# Comparing table: LimitNewCapacity
# Comparing table: CostVariable
# Comparing table: OutputDualVariable
# Comparing table: OutputEmission
# Comparing table: TimeSeasonSequential
# Comparing table: LifetimeSurvivalCurve
# Comparing table: TimeOfDay
# Comparing table: EndOfLifeOutput
# Comparing table: EmissionEndOfLife
# Comparing table: StorageDuration
# Comparing table: LimitActivityShare
# ...

# %%
print(results.keys())
results['data_differences'].keys()
print([_ for _ in results['data_differences'].keys() if 'Output' not in _])
# [_ for _ in results['data_differences']['Demand']['sample_differences'] if _['column'] == 'demand']
#[_ for _ in results['data_differences']['Efficiency']['sample_differences']]
#[_ for _ in results['data_differences']['LimitAnnualCapacityFactor']['sample_differences']]
#results['data_differences']['CapacityToActivity']['sample_differences']
# Out:
# dict_keys(['database_summary', 'table_differences', 'schema_differences', 'data_differences'])
# ['LimitAnnualCapacityFactor', 'CapacityToActivity', 'CostInvest', 'LimitCapacity', 'Technology', 'CostFixed', 'Commodity']
