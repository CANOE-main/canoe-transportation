# %% [markdown]
# # Create input data
# This notebook does all processing to turn input-data.xlsx, all other input data into a format to put into insertions.xlsx

# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
# read input data
input_data_filename = '../../../Paper 3 - Charging profiles/input_data/input-data.xlsx'
# Read all sheets into a dictionary
input_data_dict = pd.read_excel(input_data_filename, sheet_name=None)

input_params = input_data_dict['inputs'].set_index('parameter')['value'].to_dict()

truck_specs = input_data_dict['truck_specs']

# %%
# join eRoads bins to get AADTT and length
eRoads_data = (input_data_dict['MTO iCorridor AADTT']
               .dropna(axis='columns', how='any')
               .rename(columns = {'LENGTH': 'eRoads_length_km'}))
eRoads_data_summary = (eRoads_data
                       .groupby('Bin').agg({'eRoads_length_km':'sum', 'AADTT19xLength':'sum'})
                       .assign(eRoads_length_weighted_aadtt19 = lambda x: x['AADTT19xLength'] / x['eRoads_length_km']).reset_index()
                       .drop(columns='AADTT19xLength')
)
eRoads_data_summary

truck_specs = truck_specs.merge(eRoads_data_summary, how='left')

# %% [markdown]
# # Define truck specifications
# - From input-data.xlsx
# - Truck data from Islam et al (2023) Autonomie
# - Prepare truck specs, weights, energy consumption, costs with Autonomie Islam 2023 for each long-haul truck config
# - Filter to Purpose=Longhaul only
# - Output: data for each technology to construct tables 'MaxAnnualCapacityFactor', 'CostInvest'
# - Efficiency doesnt need to be recalculated, just reuse existing spreadsheet, but separate into non long-haul and long-haul
# - 'CostVariable' just reuse existing spreadsheet
#
# To be appended in sheet 'Autonomie 2023 MHDV', with column names:
# - Vehicle Manufacturing Cost ($ 2023USD)

# %% [markdown]
# ### Analyze Autonomie data

# %%
# Read the Excel file and select the relevant sheet
file_path = 'Autonomie HDT.xlsx'
autonomie_df = pd.read_excel(file_path, sheet_name='class8_longhaul_regional')

# Convert mpgde to kWh/km
# 1 gallon diesel = 37.656 kWh, 1 mile = 1.60934 km
# 128,488 Btu/gal Low Sulfur Diesel https://afdc.energy.gov/fuels/properties
autonomie_df['kWh_per_km'] = 37.656 / (autonomie_df['mpgde'] * 1.60934)

autonomie_df = autonomie_df[autonomie_df['Purpose'] == "Longhaul"]

# %%
# Function to compute scaled vehicle cost and weight based on desired range
def compute_scaled_attributes(df, Powertrain, Year, Case, Purpose, RegCode, desired_range_km, 
                              eRoads_equipment_kg = 0, eRoads_equipment_cost = 0,
                              **kwargs):
    subset = df[(df['Powertrain'] == Powertrain) &
                (df['Year'] == Year) &
                (df['Case'] == Case) &
                (df['Purpose'] == Purpose) &
                (df['RegCode'] == RegCode)]

    if subset.empty:
        raise ValueError("No matching data found for the provided filters.")
    if subset.shape[0] > 1:
        raise ValueError("Multiple matches found for filter conditions.")

    row = subset.iloc[0].to_dict()
    desired_range_miles = desired_range_km / 1.60934
    scale_factor = desired_range_miles / row['Range']

    Pack_Energy_kWh = row['Pack_Energy_kWh']  # Default value
    H2_Mass_kg = row['H2_Mass_kg']  # Default value

    if Powertrain == 'BEV':
        scaled_battery_kg = row['Battery_kg'] * scale_factor
        scaled_battery_cost = row['Battery_Cost'] * scale_factor
        
        weight_minus_battery = row['CurbWeight'] - row['Battery_kg']
        cost_minus_battery = row['VehicleCost'] - row['Battery_Cost']

        vehicle_weight = weight_minus_battery + scaled_battery_kg + eRoads_equipment_kg
        vehicle_cost = cost_minus_battery + scaled_battery_cost + eRoads_equipment_cost

        Pack_Energy_kWh *= scale_factor

    elif Powertrain == 'FCEV':
        scaled_h2_tank_kg = row['H2_Tank_kg'] * scale_factor
        scaled_h2_storage_cost = row['H2_Storage_Cost'] * scale_factor

        weight_minus_tank = row['CurbWeight'] - row['H2_Tank_kg']
        cost_minus_tank = row['VehicleCost'] - row['H2_Storage_Cost']
        
        vehicle_weight = weight_minus_tank + scaled_h2_tank_kg
        vehicle_cost = cost_minus_tank + scaled_h2_storage_cost

        H2_Mass_kg *= scale_factor

    else:
        raise ValueError("Powertrain must be 'BEV' or 'FCEV'.")
    return {
            'CurbWeight': vehicle_weight,
            'VehicleCost': vehicle_cost,
            'PayloadCapacity': row['GVWR'] - vehicle_weight,
            'kWh_per_km': row['kWh_per_km'],
            'Pack_Energy_kWh': Pack_Energy_kWh, 
            'H2_Mass_kg': H2_Mass_kg,
        }

# %%
compute_scaled_attributes(autonomie_df, **autonomie_df.iloc[0].to_dict(), desired_range_km=1000)
# Out:
# {'CurbWeight': 20522.365678874936,
#  'VehicleCost': 382209.7582772525,
#  'PayloadCapacity': 15764.994321125065,
#  'kWh_per_km': 1.4867290445304828,
#  'Pack_Energy_kWh': 1473.4512285386477,
#  'H2_Mass_kg': 0.0}

# %% [markdown]
# ### Get average payload from CFAF

# %%
region = 'ON'
long_haul_threshold = 600

mean_weight_abvthreshold = (pd.read_csv('cfaf_province_longhaul_threshold_stats.csv').query(f'region == "{region}" and long_haul_threshold=={long_haul_threshold}')
                            ['mean_weight_abvthreshold'].iloc[0])
print(f"Mean weight above threshold for {region} with long haul threshold {long_haul_threshold} km: {round(mean_weight_abvthreshold)} kg")
# Out:
# Mean weight above threshold for ON with long haul threshold 600 km: 8181 kg

# %% [markdown]
# ### Get energy consumption, battery, H2 size

# %%
# expand 'Year', add 'Case'
truck_specs = (truck_specs.merge(autonomie_df[['Year']].drop_duplicates(), how='cross')
            .assign(Case=input_params['autonomie_tech_case'])
            )
truck_specs = truck_specs.assign(Purpose = "Longhaul", RegCode = "Sleeper")

# compute scaled attributes
truck_specs = pd.concat([truck_specs, 
                      truck_specs.apply(lambda x: compute_scaled_attributes(df=autonomie_df, **x), axis='columns', result_type='expand')], 
                      axis='columns')

# Add payload capacity penalty relative to mean_weight_abvthreshold
truck_specs['PayloadCapacityPenalty'] = np.clip(mean_weight_abvthreshold / truck_specs['PayloadCapacity'], a_min=1, a_max=999)

truck_specs#.drop(columns='notes').query('Year==2030')
# Out:
#                     tech_veh              tech_supply  Bin Powertrain  \
# 0   T_HDV_T_LH_BEV_LRGBATT_N  T_HDV_T_LH_CHRG_LRGBATT  NaN        BEV
# 1   T_HDV_T_LH_BEV_LRGBATT_N  T_HDV_T_LH_CHRG_LRGBATT  NaN        BEV
# 2   T_HDV_T_LH_BEV_LRGBATT_N  T_HDV_T_LH_CHRG_LRGBATT  NaN        BEV
# 3   T_HDV_T_LH_BEV_LRGBATT_N  T_HDV_T_LH_CHRG_LRGBATT  NaN        BEV
# 4   T_HDV_T_LH_BEV_LRGBATT_N  T_HDV_T_LH_CHRG_LRGBATT  NaN        BEV
# 5   T_HDV_T_LH_BEV_FSTCHRG_N  T_HDV_T_LH_CHRG_FSTCHRG  NaN        BEV
# 6   T_HDV_T_LH_BEV_FSTCHRG_N  T_HDV_T_LH_CHRG_FSTCHRG  NaN        BEV
# 7   T_HDV_T_LH_BEV_FSTCHRG_N  T_HDV_T_LH_CHRG_FSTCHRG  NaN        BEV
# 8   T_HDV_T_LH_BEV_FSTCHRG_N  T_HDV_T_LH_CHRG_FSTCHRG  NaN        BEV
# 9   T_HDV_T_LH_BEV_FSTCHRG_N  T_HDV_T_LH_CHRG_FSTCHRG  NaN        BEV
# 10    T_HDV_T_LH_BEV_ERDS1_N    T_HDV_T_LH_CHRG_ERDS1  1.0        BEV
# 11    T_HDV_T_LH_BEV_ERDS1_N    T_HDV_T_LH_CHRG_ERDS1  1.0        BEV
# 12    T_HDV_T_LH_BEV_ERDS1_N    T_HDV_T_LH_CHRG_ERDS1  1.0        BEV
# 13    T_HDV_T_LH_BEV_ERDS1_N    T_HDV_T_LH_CHRG_ERDS1  1.0        BEV
# 14    T_HDV_T_LH_BEV_ERDS1_N    T_HDV_T_LH_CHRG_ERDS1  1.0        BEV
# 15    T_HDV_T_LH_BEV_ERDS2_N    T_HDV_T_LH_CHRG_ERDS2  2.0        BEV
# 16    T_HDV_T_LH_BEV_ERDS2_N    T_HDV_T_LH_CHRG_ERDS2  2.0        BEV
# 17    T_HDV_T_LH_BEV_ERDS2_N    T_HDV_T_LH_CHRG_ERDS2  2.0        BEV
# 18    T_HDV_T_LH_BEV_ERDS2_N    T_HDV_T_LH_CHRG_ERDS2  2.0        BEV
# 19    T_HDV_T_LH_BEV_ERDS2_N    T_HDV_T_LH_CHRG_ERDS2  2.0        BEV
# 20    T_HDV_T_LH_BEV_ERDS3_N    T_HDV_T_LH_CHRG_ERDS3  3.0        BEV
# 21    T_HDV_T_LH_BEV_ERDS3_N    T_HDV_T_LH_CHRG_ERDS3  3.0        BEV
# 22    T_HDV_T_LH_BEV_ERDS3_N    T_HDV_T_LH_CHRG_ERDS3  3.0        BEV
# 23    T_HDV_T_LH_BEV_ERDS3_N    T_HDV_T_LH_CHRG_ERDS3  3.0        BEV
# 24    T_HDV_T_LH_BEV_ERDS3_N    T_HDV_T_LH_CHRG_ERDS3  3.0        BEV
# 25    T_HDV_T_LH_BEV_ERDS4_N    T_HDV_T_LH_CHRG_ERDS4  4.0        BEV
# 26    T_HDV_T_LH_BEV_ERDS4_N    T_HDV_T_LH_CHRG_ERDS4  4.0        BEV
# 27    T_HDV_T_LH_BEV_ERDS4_N    T_HDV_T_LH_CHRG_ERDS4  4.0        BEV
# 28    T_HDV_T_LH_BEV_ERDS4_N    T_HDV_T_LH_CHRG_ERDS4  4.0        BEV
# 29    T_HDV_T_LH_BEV_ERDS4_N    T_HDV_T_LH_CHRG_ERDS4  4.0        BEV
# 30    T_HDV_T_LH_BEV_ERDS5_N    T_HDV_T_LH_CHRG_ERDS5  5.0        BEV
# 31    T_HDV_T_LH_BEV_ERDS5_N    T_HDV_T_LH_CHRG_ERDS5  5.0        BEV
# 32    T_HDV_T_LH_BEV_ERDS5_N    T_HDV_T_LH_CHRG_ERDS5  5.0        BEV
# 33    T_HDV_T_LH_BEV_ERDS5_N    T_HDV_T_LH_CHRG_ERDS5  5.0        BEV
# 34    T_HDV_T_LH_BEV_ERDS5_N    T_HDV_T_LH_CHRG_ERDS5  5.0        BEV
# 35         T_HDV_T_LH_FCEV_N     T_H2_HDV_T_LH_REFUEL  NaN       FCEV
# 36         T_HDV_T_LH_FCEV_N     T_H2_HDV_T_LH_REFUEL  NaN       FCEV
# 37         T_HDV_T_LH_FCEV_N     T_H2_HDV_T_LH_REFUEL  NaN       FCEV
# 38         T_HDV_T_LH_FCEV_N     T_H2_HDV_T_LH_REFUEL  NaN       FCEV
# 39         T_HDV_T_LH_FCEV_N     T_H2_HDV_T_LH_REFUEL  NaN       FCEV
#
#     desired_range_km  eRoads_equipment_kg  eRoads_equipment_cost  \
# 0            1206.75                    0                      0
# 1            1206.75                    0                      0
# 2            1206.75                    0                      0
# 3            1206.75                    0                      0
# 4            1206.75                    0                      0
# 5             804.50                    0                      0
# 6             804.50                    0                      0
# 7             804.50                    0                      0
# 8             804.50                    0                      0
# 9             804.50                    0                      0
# 10            402.25                  100                   7500
# 11            402.25                  100                   7500
# 12            402.25                  100                   7500
# 13            402.25                  100                   7500
# 14            402.25                  100                   7500
# 15            402.25                  100                   7500
# 16            402.25                  100                   7500
# 17            402.25                  100                   7500
# 18            402.25                  100                   7500
# 19            402.25                  100                   7500
# 20            402.25                  100                   7500
# 21            402.25                  100                   7500
# 22            402.25                  100                   7500
# 23            402.25                  100                   7500
# 24            402.25                  100                   7500
# 25            402.25                  100                   7500
# 26            402.25                  100                   7500
# 27            402.25                  100                   7500
# 28            402.25                  100                   7500
# 29            402.25                  100                   7500
# 30            402.25                  100                   7500
# 31            402.25                  100                   7500
# 32            402.25                  100                   7500
# 33            402.25                  100                   7500
# 34            402.25                  100                   7500
# 35            804.50                    0                      0
# 36            804.50                    0                      0
# 37            804.50                    0                      0
# 38            804.50                    0                      0
# 39            804.50                    0                      0
#
#     charger_standard_kW  charger_fast_kW  \
# 0                 350.0            350.0
# 1                 350.0            350.0
# 2                 350.0            350.0
# 3                 350.0            350.0
# 4                 350.0            350.0
# 5                 350.0           3000.0
# 6                 350.0           3000.0
# 7                 350.0           3000.0
# 8                 350.0           3000.0
# 9                 350.0           3000.0
# 10                  NaN              NaN
# 11                  NaN              NaN
# 12                  NaN              NaN
# 13                  NaN              NaN
# 14                  NaN              NaN
# 15                  NaN              NaN
# 16                  NaN              NaN
# 17                  NaN              NaN
# 18                  NaN              NaN
# 19                  NaN              NaN
# 20                  NaN              NaN
# 21                  NaN              NaN
# 22                  NaN              NaN
# 23                  NaN              NaN
# 24                  NaN              NaN
# 25                  NaN              NaN
# 26                  NaN              NaN
# 27                  NaN              NaN
# 28                  NaN              NaN
# 29                  NaN              NaN
# 30                  NaN              NaN
# 31                  NaN              NaN
# 32                  NaN              NaN
# 33                  NaN              NaN
# 34                  NaN              NaN
# 35              26400.0          26400.0
# 36              26400.0          26400.0
# 37              26400.0          26400.0
# 38              26400.0          26400.0
# 39              26400.0          26400.0
#
#                                                 notes  ...  Case   Purpose  \
# 0   desired range: 1.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 1   desired range: 1.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 2   desired range: 1.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 3   desired range: 1.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 4   desired range: 1.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 5   desired range: same as Autonomie range (500 mi...  ...   Low  Longhaul
# 6   desired range: same as Autonomie range (500 mi...  ...   Low  Longhaul
# 7   desired range: same as Autonomie range (500 mi...  ...   Low  Longhaul
# 8   desired range: same as Autonomie range (500 mi...  ...   Low  Longhaul
# 9   desired range: same as Autonomie range (500 mi...  ...   Low  Longhaul
# 10  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 11  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 12  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 13  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 14  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 15  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 16  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 17  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 18  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 19  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 20  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 21  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 22  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 23  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 24  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 25  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 26  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 27  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 28  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 29  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 30  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 31  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 32  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 33  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 34  desired range: 0.5x of Autonomie range (500 mi...  ...   Low  Longhaul
# 35  desired range: same as Autonomie range (500 mi...  ...   Low  Longhaul
# 36  desired range: same as Autonomie range (500 mi...  ...   Low  Longhaul
# 37  desired range: same as Autonomie range (500 mi...  ...   Low  Longhaul
# 38  desired range: same as Autonomie range (500 mi...  ...   Low  Longhaul
# 39  desired range: same as Autonomie range (500 mi...  ...   Low  Longhaul
#
#     RegCode    CurbWeight    VehicleCost PayloadCapacity  kWh_per_km  \
# 0   Sleeper  26055.151419  817170.316581    10232.208581    1.774878
# 1   Sleeper  23886.756398  636636.174090    12400.603602    1.596685
# 2   Sleeper  21336.847100  454936.731562    14950.512900    1.440349
# 3   Sleeper  19289.266037  362307.990210    16998.093963    1.288763
# 4   Sleeper  16530.916384  236516.208615    19756.443616    1.128199
# 5   Sleeper  21353.478350  579474.544387    14933.881650    1.774878
# 6   Sleeper  19800.538255  458658.782726    16486.821745    1.596685
# 7   Sleeper  18019.686804  336993.154375    18267.673196    1.440349
# 8   Sleeper  16639.299952  274743.993473    19648.060048    1.288763
# 9   Sleeper  14743.535495  190310.472410    21543.824505    1.128199
# 10  Sleeper  16751.805280  349278.772194    19535.554720    1.774878
# 11  Sleeper  15814.320112  288181.391363    20473.039888    1.596685
# 12  Sleeper  14802.526507  226549.577187    21484.833493    1.440349
# 13  Sleeper  14089.333867  194679.996737    22198.026133    1.288763
# 14  Sleeper  13056.154605  151604.736205    23231.205395    1.128199
# 15  Sleeper  16751.805280  349278.772194    19535.554720    1.774878
# 16  Sleeper  15814.320112  288181.391363    20473.039888    1.596685
# 17  Sleeper  14802.526507  226549.577187    21484.833493    1.440349
# 18  Sleeper  14089.333867  194679.996737    22198.026133    1.288763
# 19  Sleeper  13056.154605  151604.736205    23231.205395    1.128199
# 20  Sleeper  16751.805280  349278.772194    19535.554720    1.774878
# 21  Sleeper  15814.320112  288181.391363    20473.039888    1.596685
# 22  Sleeper  14802.526507  226549.577187    21484.833493    1.440349
# 23  Sleeper  14089.333867  194679.996737    22198.026133    1.288763
# 24  Sleeper  13056.154605  151604.736205    23231.205395    1.128199
# 25  Sleeper  16751.805280  349278.772194    19535.554720    1.774878
# 26  Sleeper  15814.320112  288181.391363    20473.039888    1.596685
# 27  Sleeper  14802.526507  226549.577187    21484.833493    1.440349
# 28  Sleeper  14089.333867  194679.996737    22198.026133    1.288763
# 29  Sleeper  13056.154605  151604.736205    23231.205395    1.128199
# 30  Sleeper  16751.805280  349278.772194    19535.554720    1.774878
# 31  Sleeper  15814.320112  288181.391363    20473.039888    1.596685
# 32  Sleeper  14802.526507  226549.577187    21484.833493    1.440349
# 33  Sleeper  14089.333867  194679.996737    22198.026133    1.288763
# 34  Sleeper  13056.154605  151604.736205    23231.205395    1.128199
# 35  Sleeper  14889.026608  326090.295008    21398.333392    2.938667
# 36  Sleeper  14234.848846  276845.430267    22052.511154    2.580527
# 37  Sleeper  13695.417741  240462.180325    22591.942259    2.291819
# 38  Sleeper  13445.730291  217235.423343    22841.629709    2.052065
# 39  Sleeper  12998.374561  180532.654245    23288.985439    1.759978
#
#     Pack_Energy_kWh  H2_Mass_kg  PayloadCapacityPenalty
# 0       2037.391664    0.000000                     1.0
# 1       1906.901800    0.000000                     1.0
# 2       1769.152158    0.000000                     1.0
# 3       1641.826813    0.000000                     1.0
# 4       1540.189915    0.000000                     1.0
# 5       1358.261109    0.000000                     1.0
# 6       1271.267867    0.000000                     1.0
# 7       1179.434772    0.000000                     1.0
# 8       1094.551209    0.000000                     1.0
# 9       1026.793277    0.000000                     1.0
# 10       679.130555    0.000000                     1.0
# 11       635.633933    0.000000                     1.0
# 12       589.717386    0.000000                     1.0
# 13       547.275604    0.000000                     1.0
# 14       513.396638    0.000000                     1.0
# 15       679.130555    0.000000                     1.0
# 16       635.633933    0.000000                     1.0
# 17       589.717386    0.000000                     1.0
# 18       547.275604    0.000000                     1.0
# 19       513.396638    0.000000                     1.0
# 20       679.130555    0.000000                     1.0
# 21       635.633933    0.000000                     1.0
# 22       589.717386    0.000000                     1.0
# 23       547.275604    0.000000                     1.0
# 24       513.396638    0.000000                     1.0
# 25       679.130555    0.000000                     1.0
# 26       635.633933    0.000000                     1.0
# 27       589.717386    0.000000                     1.0
# 28       547.275604    0.000000                     1.0
# 29       513.396638    0.000000                     1.0
# 30       679.130555    0.000000                     1.0
# 31       635.633933    0.000000                     1.0
# 32       589.717386    0.000000                     1.0
# 33       547.275604    0.000000                     1.0
# 34       513.396638    0.000000                     1.0
# 35        17.962560   83.786095                     1.0
# 36        17.962560   74.355488                     1.0
# 37        16.632000   66.451958                     1.0
# 38        16.632000   59.758872                     1.0
# 39        16.156800   51.412936                     1.0
#
# [40 rows x 23 columns]

# %% [markdown]
# ### Calculate CapacityToActivity for infra

# %%
def calc_CapacityToActvity_infra(tech_supply, charger_standard_kW, charger_fast_kW, eRoads_length_weighted_aadtt19, kWh_per_km, **kwargs):
    if (tech_supply == 'T_HDV_T_LH_CHRG_LRGBATT'): # or (tech_supply == 'T_H2_HDV_T_LH_REFUEL'):
        return charger_standard_kW*60*60*24*365/1e12    # 60 seconds * 60 minutes * 24 hours * 365 days / 1e12 to convert to PJ
    elif tech_supply == 'T_HDV_T_LH_CHRG_FSTCHRG':
        return charger_fast_kW*60*60*24*365/1e12    # 60 seconds * 60 minutes * 24 hours * 365 days / 1e12 to convert to PJ
        # skip this
        # return ((charger_standard_kW*input_params['overnight_charging_share']) + (charger_fast_kW*(1-input_params['overnight_charging_share'])))*60*60*24*365/1e12
    elif 'CHRG_ERDS' in tech_supply:
        return eRoads_length_weighted_aadtt19 * 365 * kWh_per_km * 3.6 / 1e9  # convert to PJ
    else:
        return np.nan  # Default case if no conditions are met

# %%
# apply the function to calculate CapacityToActivity_infra and keep original columns
truck_specs['CapacityToActivity_infra'] = (truck_specs.apply(lambda x: calc_CapacityToActvity_infra(**x), axis='columns', result_type='expand'))

# %% [markdown]
# # Output data for insertions.xlsx

# %%
# output costs for CostInvest
(truck_specs.query('Case=="Low"').pivot(index='tech_veh', columns='Year', values='VehicleCost')
 .reset_index().style.hide())
# Out:
# <style type="text/css">
# </style>
# <table id="T_eee41">
#   <thead>
#     <tr>
#       <th id="T_eee41_level0_col0" class="col_heading level0 col0" >tech_veh</th>
#       <th id="T_eee41_level0_col1" class="col_heading level0 col1" >2023</th>
#       <th id="T_eee41_level0_col2" class="col_heading level0 col2" >2025</th>
#       <th id="T_eee41_level0_col3" class="col_heading level0 col3" >2030</th>
#       <th id="T_eee41_level0_col4" class="col_heading level0 col4" >2035</th>
#       <th id="T_eee41_level0_col5" class="col_heading level0 col5" >2050</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_eee41_row0_col0" class="data row0 col0" >T_HDV_T_LH_BEV_ERDS1_N</td>
#       <td id="T_eee41_row0_col1" class="data row0 col1" >349278.772194</td>
#       <td id="T_eee41_row0_col2" class="data row0 col2" >288181.391363</td>
#       <td id="T_eee41_row0_col3" class="data row0 col3" >226549.577187</td>
#       <td id="T_eee41_row0_col4" class="data row0 col4" >194679.996737</td>
#       <td id="T_eee41_row0_col5" class="data row0 col5" >151604.736205</td>
#     </tr>
#     <tr>
#       <td id="T_eee41_row1_col0" class="data row1 col0" >T_HDV_T_LH_BEV_ERDS2_N</td>
#       <td id="T_eee41_row1_col1" class="data row1 col1" >349278.772194</td>
#       <td id="T_eee41_row1_col2" class="data row1 col2" >288181.391363</td>
#       <td id="T_eee41_row1_col3" class="data row1 col3" >226549.577187</td>
#       <td id="T_eee41_row1_col4" class="data row1 col4" >194679.996737</td>
#       <td id="T_eee41_row1_col5" class="data row1 col5" >151604.736205</td>
#     </tr>
#     <tr>
#       <td id="T_eee41_row2_col0" class="data row2 col0" >T_HDV_T_LH_BEV_ERDS3_N</td>
#       <td id="T_eee41_row2_col1" class="data row2 col1" >349278.772194</td>
#       <td id="T_eee41_row2_col2" class="data row2 col2" >288181.391363</td>
#       <td id="T_eee41_row2_col3" class="data row2 col3" >226549.577187</td>
#       <td id="T_eee41_row2_col4" class="data row2 col4" >194679.996737</td>
#       <td id="T_eee41_row2_col5" class="data row2 col5" >151604.736205</td>
#     </tr>
#     <tr>
#       <td id="T_eee41_row3_col0" class="data row3 col0" >T_HDV_T_LH_BEV_ERDS4_N</td>
#       <td id="T_eee41_row3_col1" class="data row3 col1" >349278.772194</td>
#       <td id="T_eee41_row3_col2" class="data row3 col2" >288181.391363</td>
#       <td id="T_eee41_row3_col3" class="data row3 col3" >226549.577187</td>
#       <td id="T_eee41_row3_col4" class="data row3 col4" >194679.996737</td>
#       <td id="T_eee41_row3_col5" class="data row3 col5" >151604.736205</td>
#     </tr>
#     <tr>
#       <td id="T_eee41_row4_col0" class="data row4 col0" >T_HDV_T_LH_BEV_ERDS5_N</td>
#       <td id="T_eee41_row4_col1" class="data row4 col1" >349278.772194</td>
#       <td id="T_eee41_row4_col2" class="data row4 col2" >288181.391363</td>
#       <td id="T_eee41_row4_col3" class="data row4 col3" >226549.577187</td>
#       <td id="T_eee41_row4_col4" class="data row4 col4" >194679.996737</td>
#       <td id="T_eee41_row4_col5" class="data row4 col5" >151604.736205</td>
#     </tr>
#     <tr>
#       <td id="T_eee41_row5_col0" class="data row5 col0" >T_HDV_T_LH_BEV_FSTCHRG_N</td>
#       <td id="T_eee41_row5_col1" class="data row5 col1" >579474.544387</td>
#       <td id="T_eee41_row5_col2" class="data row5 col2" >458658.782726</td>
#       <td id="T_eee41_row5_col3" class="data row5 col3" >336993.154375</td>
#       <td id="T_eee41_row5_col4" class="data row5 col4" >274743.993473</td>
#       <td id="T_eee41_row5_col5" class="data row5 col5" >190310.472410</td>
#     </tr>
#     <tr>
#       <td id="T_eee41_row6_col0" class="data row6 col0" >T_HDV_T_LH_BEV_LRGBATT_N</td>
#       <td id="T_eee41_row6_col1" class="data row6 col1" >817170.316581</td>
#       <td id="T_eee41_row6_col2" class="data row6 col2" >636636.174090</td>
#       <td id="T_eee41_row6_col3" class="data row6 col3" >454936.731562</td>
#       <td id="T_eee41_row6_col4" class="data row6 col4" >362307.990210</td>
#       <td id="T_eee41_row6_col5" class="data row6 col5" >236516.208615</td>
#     </tr>
#     <tr>
#       <td id="T_eee41_row7_col0" class="data row7 col0" >T_HDV_T_LH_FCEV_N</td>
#       <td id="T_eee41_row7_col1" class="data row7 col1" >326090.295008</td>
#       <td id="T_eee41_row7_col2" class="data row7 col2" >276845.430267</td>
#       <td id="T_eee41_row7_col3" class="data row7 col3" >240462.180325</td>
#       <td id="T_eee41_row7_col4" class="data row7 col4" >217235.423343</td>
#       <td id="T_eee41_row7_col5" class="data row7 col5" >180532.654245</td>
#     </tr>
#   </tbody>
# </table>

# %%
# get payload penalty factors
(truck_specs.query('Case=="Low"').pivot(index='tech_veh', columns='Year', values='PayloadCapacityPenalty')
 .reset_index().style.hide())
# Out:
# <style type="text/css">
# </style>
# <table id="T_377d4">
#   <thead>
#     <tr>
#       <th id="T_377d4_level0_col0" class="col_heading level0 col0" >tech_veh</th>
#       <th id="T_377d4_level0_col1" class="col_heading level0 col1" >2023</th>
#       <th id="T_377d4_level0_col2" class="col_heading level0 col2" >2025</th>
#       <th id="T_377d4_level0_col3" class="col_heading level0 col3" >2030</th>
#       <th id="T_377d4_level0_col4" class="col_heading level0 col4" >2035</th>
#       <th id="T_377d4_level0_col5" class="col_heading level0 col5" >2050</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_377d4_row0_col0" class="data row0 col0" >T_HDV_T_LH_BEV_ERDS1_N</td>
#       <td id="T_377d4_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_377d4_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_377d4_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_377d4_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_377d4_row0_col5" class="data row0 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_377d4_row1_col0" class="data row1 col0" >T_HDV_T_LH_BEV_ERDS2_N</td>
#       <td id="T_377d4_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_377d4_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_377d4_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_377d4_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_377d4_row1_col5" class="data row1 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_377d4_row2_col0" class="data row2 col0" >T_HDV_T_LH_BEV_ERDS3_N</td>
#       <td id="T_377d4_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_377d4_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_377d4_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_377d4_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_377d4_row2_col5" class="data row2 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_377d4_row3_col0" class="data row3 col0" >T_HDV_T_LH_BEV_ERDS4_N</td>
#       <td id="T_377d4_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_377d4_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_377d4_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_377d4_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_377d4_row3_col5" class="data row3 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_377d4_row4_col0" class="data row4 col0" >T_HDV_T_LH_BEV_ERDS5_N</td>
#       <td id="T_377d4_row4_col1" class="data row4 col1" >1.000000</td>
#       <td id="T_377d4_row4_col2" class="data row4 col2" >1.000000</td>
#       <td id="T_377d4_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_377d4_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_377d4_row4_col5" class="data row4 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_377d4_row5_col0" class="data row5 col0" >T_HDV_T_LH_BEV_FSTCHRG_N</td>
#       <td id="T_377d4_row5_col1" class="data row5 col1" >1.000000</td>
#       <td id="T_377d4_row5_col2" class="data row5 col2" >1.000000</td>
#       <td id="T_377d4_row5_col3" class="data row5 col3" >1.000000</td>
#       <td id="T_377d4_row5_col4" class="data row5 col4" >1.000000</td>
#       <td id="T_377d4_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_377d4_row6_col0" class="data row6 col0" >T_HDV_T_LH_BEV_LRGBATT_N</td>
#       <td id="T_377d4_row6_col1" class="data row6 col1" >1.000000</td>
#       <td id="T_377d4_row6_col2" class="data row6 col2" >1.000000</td>
#       <td id="T_377d4_row6_col3" class="data row6 col3" >1.000000</td>
#       <td id="T_377d4_row6_col4" class="data row6 col4" >1.000000</td>
#       <td id="T_377d4_row6_col5" class="data row6 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_377d4_row7_col0" class="data row7 col0" >T_HDV_T_LH_FCEV_N</td>
#       <td id="T_377d4_row7_col1" class="data row7 col1" >1.000000</td>
#       <td id="T_377d4_row7_col2" class="data row7 col2" >1.000000</td>
#       <td id="T_377d4_row7_col3" class="data row7 col3" >1.000000</td>
#       <td id="T_377d4_row7_col4" class="data row7 col4" >1.000000</td>
#       <td id="T_377d4_row7_col5" class="data row7 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# CapacityToActivity for infrastructure
(truck_specs.groupby('tech_supply')['CapacityToActivity_infra']
 .max()    # take the maximum value observed
 .reset_index()
 .style.hide())
# Out:
# <style type="text/css">
# </style>
# <table id="T_594f4">
#   <thead>
#     <tr>
#       <th id="T_594f4_level0_col0" class="col_heading level0 col0" >tech_supply</th>
#       <th id="T_594f4_level0_col1" class="col_heading level0 col1" >CapacityToActivity_infra</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_594f4_row0_col0" class="data row0 col0" >T_H2_HDV_T_LH_REFUEL</td>
#       <td id="T_594f4_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_594f4_row1_col0" class="data row1 col0" >T_HDV_T_LH_CHRG_ERDS1</td>
#       <td id="T_594f4_row1_col1" class="data row1 col1" >0.036925</td>
#     </tr>
#     <tr>
#       <td id="T_594f4_row2_col0" class="data row2 col0" >T_HDV_T_LH_CHRG_ERDS2</td>
#       <td id="T_594f4_row2_col1" class="data row2 col1" >0.013693</td>
#     </tr>
#     <tr>
#       <td id="T_594f4_row3_col0" class="data row3 col0" >T_HDV_T_LH_CHRG_ERDS3</td>
#       <td id="T_594f4_row3_col1" class="data row3 col1" >0.003662</td>
#     </tr>
#     <tr>
#       <td id="T_594f4_row4_col0" class="data row4 col0" >T_HDV_T_LH_CHRG_ERDS4</td>
#       <td id="T_594f4_row4_col1" class="data row4 col1" >0.001391</td>
#     </tr>
#     <tr>
#       <td id="T_594f4_row5_col0" class="data row5 col0" >T_HDV_T_LH_CHRG_ERDS5</td>
#       <td id="T_594f4_row5_col1" class="data row5 col1" >0.000204</td>
#     </tr>
#     <tr>
#       <td id="T_594f4_row6_col0" class="data row6 col0" >T_HDV_T_LH_CHRG_FSTCHRG</td>
#       <td id="T_594f4_row6_col1" class="data row6 col1" >0.094608</td>
#     </tr>
#     <tr>
#       <td id="T_594f4_row7_col0" class="data row7 col0" >T_HDV_T_LH_CHRG_LRGBATT</td>
#       <td id="T_594f4_row7_col1" class="data row7 col1" >0.011038</td>
#     </tr>
#   </tbody>
# </table>

# %%
# MaxCapacity for eRoads
(truck_specs[['tech_supply', 'eRoads_length_km']].drop_duplicates().dropna()
 # expand over all periods
 #.merge(pd.DataFrame({'period': [2021, 2025, 2030, 2035, 2040, 2045, 2050]}), how='cross')
 .style.format(precision=2).hide()
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b5daa">
#   <thead>
#     <tr>
#       <th id="T_b5daa_level0_col0" class="col_heading level0 col0" >tech_supply</th>
#       <th id="T_b5daa_level0_col1" class="col_heading level0 col1" >eRoads_length_km</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b5daa_row0_col0" class="data row0 col0" >T_HDV_T_LH_CHRG_ERDS1</td>
#       <td id="T_b5daa_row0_col1" class="data row0 col1" >838.85</td>
#     </tr>
#     <tr>
#       <td id="T_b5daa_row1_col0" class="data row1 col0" >T_HDV_T_LH_CHRG_ERDS2</td>
#       <td id="T_b5daa_row1_col1" class="data row1 col1" >838.87</td>
#     </tr>
#     <tr>
#       <td id="T_b5daa_row2_col0" class="data row2 col0" >T_HDV_T_LH_CHRG_ERDS3</td>
#       <td id="T_b5daa_row2_col1" class="data row2 col1" >2499.47</td>
#     </tr>
#     <tr>
#       <td id="T_b5daa_row3_col0" class="data row3 col0" >T_HDV_T_LH_CHRG_ERDS4</td>
#       <td id="T_b5daa_row3_col1" class="data row3 col1" >4176.97</td>
#     </tr>
#     <tr>
#       <td id="T_b5daa_row4_col0" class="data row4 col0" >T_HDV_T_LH_CHRG_ERDS5</td>
#       <td id="T_b5daa_row4_col1" class="data row4 col1" >8426.22</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Create profiles for CapacityFactorTech

# %%
def create_CapacityFactorTech_single_day(profile_name, input_data_dict, season_list):
    """
    Create a DataFrame with technology-specific capacity factors for each season.
    Only for a single day profile which is repeated across all seasons in season_list.
    Returns a DataFrame to be inserted into CapacityFactorTech.
    """
    hourly_profile = input_data_dict['sample_profiles'].set_index('tod')[profile_name]
    hourly_profile.name = 'factor'

    df = (hourly_profile.reset_index()
        .merge(pd.DataFrame({'season': season_list}), how='cross')
        .merge(input_data_dict['truck_specs']['tech_supply'].rename('tech'), how='cross')
        .assign(region='ON', cf_tech_notes=profile_name)
        )
    return df

# %%
season_list = ["D222", "D007", "D185", "D217", "D295", "D248", "D332", "D214", "D160", "D067", "D290", "D054"]
create_CapacityFactorTech_single_day('flat', input_data_dict, season_list)
# Out:
#       tod  factor season                     tech region cf_tech_notes
# 0     H01       1   D222  T_HDV_T_LH_CHRG_LRGBATT     ON          flat
# 1     H01       1   D222  T_HDV_T_LH_CHRG_FSTCHRG     ON          flat
# 2     H01       1   D222    T_HDV_T_LH_CHRG_ERDS1     ON          flat
# 3     H01       1   D222    T_HDV_T_LH_CHRG_ERDS2     ON          flat
# 4     H01       1   D222    T_HDV_T_LH_CHRG_ERDS3     ON          flat
# ...   ...     ...    ...                      ...    ...           ...
# 2299  H24       1   D054    T_HDV_T_LH_CHRG_ERDS2     ON          flat
# 2300  H24       1   D054    T_HDV_T_LH_CHRG_ERDS3     ON          flat
# 2301  H24       1   D054    T_HDV_T_LH_CHRG_ERDS4     ON          flat
# 2302  H24       1   D054    T_HDV_T_LH_CHRG_ERDS5     ON          flat
# 2303  H24       1   D054     T_H2_HDV_T_LH_REFUEL     ON          flat
#
# [2304 rows x 6 columns]

# %%
from lihwei_db_edits import insert_profiles_CapacityFactorTech

# %%
insert_profiles_CapacityFactorTech('canoe_on_12d_baseline_newtech.sqlite', 
                                   profiles_df=create_CapacityFactorTech_single_day('flat', input_data_dict, season_list),
                                   new_db_path='canoe_on_12d_baseline_newtech_flat.sqlite')
# Out:
# Copying database from canoe_on_12d_baseline_newtech.sqlite to canoe_on_12d_baseline_newtech_flat.sqlite for insertion of profiles.
